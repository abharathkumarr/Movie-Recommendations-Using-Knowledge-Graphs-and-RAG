# %% [markdown]
# <h1>Step 1: Data Exploration</h1>

# %%
import networkx as nx
print(nx.__version__)
# Out:
# 3.4.2

# %%
import matplotlib.pyplot as plt
import certifi
import ssl

context = ssl.create_default_context(cafile=certifi.where())
print("SSL context created from certifi CA bundle")
# Out:
# SSL context created from certifi CA bundle

# %%
from langchain_community.graphs import Neo4jGraph
import certifi
import ssl

# Create custom SSL context
ssl_context = ssl.create_default_context(cafile=certifi.where())

kg = Neo4jGraph(
    url="bolt://demo.neo4jlabs.com:7687",  # 🔁 Use plain scheme
    username="recommendations",
    password="recommendations",
    database="recommendations",
    driver_config={
        "encrypted": True,                # 🔒 Enable encryption manually
        "ssl_context": ssl_context        # ✅ Pass trusted CA bundle
    }
)

print(kg.query("CALL db.labels()"))
# Out:
# [{'label': 'Movie'}, {'label': 'Genre'}, {'label': 'User'}, {'label': 'Actor'}, {'label': 'Director'}, {'label': 'Person'}, {'label': '_Bloom_Perspective_'}, {'label': '_Bloom_Scene_'}]

# %%
kg.query("MATCH (n) RETURN COUNT(n) AS total_nodes")
# Out:
# [{'total_nodes': 28865}]

# %%
kg.query("MATCH ()-[r]->() RETURN COUNT(r) AS total_relationships")
# Out:
# [{'total_relationships': 166262}]

# %%
# Get all distinct node labels to understand the types of entities in the graph (Movie, Actor, Genre, etc.)
kg.query("CALL db.labels()")
# Out:
# [{'label': 'Movie'},
#  {'label': 'Genre'},
#  {'label': 'User'},
#  {'label': 'Actor'},
#  {'label': 'Director'},
#  {'label': 'Person'},
#  {'label': '_Bloom_Perspective_'},
#  {'label': '_Bloom_Scene_'}]

# %%
kg.query("""
CALL db.labels() YIELD label
WITH label, 'MATCH (n:`' + label + '`) RETURN count(n)' AS query
CALL apoc.cypher.run(query, {}) YIELD value
RETURN label, value['count(n)'] AS count
""")
# Out:
# [{'label': 'Movie', 'count': 9125},
#  {'label': 'Genre', 'count': 20},
#  {'label': 'User', 'count': 671},
#  {'label': 'Actor', 'count': 15443},
#  {'label': 'Director', 'count': 4091},
#  {'label': 'Person', 'count': 19047},
#  {'label': '_Bloom_Perspective_', 'count': 1},
#  {'label': '_Bloom_Scene_', 'count': 1}]

# %% [markdown]
# ## View All Relationship Types

# %%
# View all relationship types (e.g., ACTED_IN, RATED) to understand how entities are connected
kg.query("CALL db.relationshipTypes()")
# Out:
# [{'relationshipType': 'IN_GENRE'},
#  {'relationshipType': 'RATED'},
#  {'relationshipType': 'ACTED_IN'},
#  {'relationshipType': 'DIRECTED'},
#  {'relationshipType': '_Bloom_HAS_SCENE_'}]

# %%
# List all property keys available in the graph, such as title, plot, plotEmbedding, etc.

kg.query("CALL db.propertyKeys()")
# Out:
# [{'propertyKey': 'movieId'},
#  {'propertyKey': 'name'},
#  {'propertyKey': 'userId'},
#  {'propertyKey': 'imdbId'},
#  {'propertyKey': 'title'},
#  {'propertyKey': 'rating'},
#  {'propertyKey': 'timestamp'},
#  {'propertyKey': 'tmdbId'},
#  {'propertyKey': 'year'},
#  {'propertyKey': 'countries'},
#  {'propertyKey': 'languages'},
#  {'propertyKey': 'plot'},
#  {'propertyKey': 'imdbRating'},
#  {'propertyKey': 'imdbVotes'},
#  {'propertyKey': 'released'},
#  {'propertyKey': 'runtime'},
#  {'propertyKey': 'poster'},
#  {'propertyKey': 'revenue'},
#  {'propertyKey': 'budget'},
#  {'propertyKey': 'tagline'},
#  {'propertyKey': 'role'},
#  {'propertyKey': 'born'},
#  {'propertyKey': 'died'},
#  {'propertyKey': 'bornIn'},
#  {'propertyKey': 'bio'},
#  {'propertyKey': 'url'},
#  {'propertyKey': 'plotEmbedding'},
#  {'propertyKey': 'posterEmbedding'},
#  {'propertyKey': 'id'},
#  {'propertyKey': 'data'},
#  {'propertyKey': 'nodes'},
#  {'propertyKey': 'relationships'},
#  {'propertyKey': 'style'},
#  {'propertyKey': 'visualisation'},
#  {'propertyKey': 'version'},
#  {'propertyKey': 'roles'},
#  {'propertyKey': 'numOfNodes'},
#  {'propertyKey': 'numOfRels'},
#  {'propertyKey': 'createdBy'},
#  {'propertyKey': 'createdAt'},
#  {'propertyKey': 'lastModified'},
#  {'propertyKey': 'filters'},
#  {'propertyKey': 'ranges'},
#  {'propertyKey': 'gds'}]

# %%
# Visualize the graph schema — shows how node types and relationships are structured

kg.query("CALL db.schema.visualization()")
# Out:
# [{'nodes': [{'name': '_Bloom_Perspective_',
#     'indexes': [],
#     'constraints': ["Constraint( id=3, name='constraint_f7832722', type='UNIQUENESS', schema=(:_Bloom_Perspective_ {id}), ownedIndex=1 )"]},
#    {'name': 'Movie',
#     'indexes': ['year',
#      'imdbRating',
#      'released',
#      'imdbId',
#      'title',
#      'tagline',
#      'title,plot',
#      'plotEmbedding',
#      'posterEmbedding'],
#     'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#      "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]},
#    {'name': 'User',
#     'indexes': ['name'],
#     'constraints': ["Constraint( id=76, name='constraint_3b27b0', type='UNIQUENESS', schema=(:User {userId}), ownedIndex=64 )"]},
#    {'name': 'Actor', 'indexes': [], 'constraints': []},
#    {'name': 'Director', 'indexes': [], 'constraints': []},
#    {'name': 'Genre',
#     'indexes': [],
#     'constraints': ["Constraint( id=74, name='constraint_f8689281', type='UNIQUENESS', schema=(:Genre {name}), ownedIndex=62 )"]},
#    {'name': 'Person',
#     'indexes': ['name,bio', 'name'],
#     'constraints': ["Constraint( id=73, name='constraint_4499eae9', type='UNIQUENESS', schema=(:Person {tmdbId}), ownedIndex=63 )"]},
#    {'name': '_Bloom_Scene_', 'indexes': [], 'constraints': []}],
#   'relationships': [({'name': 'Actor', 'indexes': [], 'constraints': []},
#     'ACTED_IN',
#     {'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]}),
#    ({'name': 'Person',
#      'indexes': ['name,bio', 'name'],
#      'constraints': ["Constraint( id=73, name='constraint_4499eae9', type='UNIQUENESS', schema=(:Person {tmdbId}), ownedIndex=63 )"]},
#     'ACTED_IN',
#     {'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]}),
#    ({'name': 'Director', 'indexes': [], 'constraints': []},
#     'ACTED_IN',
#     {'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]}),
#    ({'name': 'User',
#      'indexes': ['name'],
#      'constraints': ["Constraint( id=76, name='constraint_3b27b0', type='UNIQUENESS', schema=(:User {userId}), ownedIndex=64 )"]},
#     'RATED',
#     {'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]}),
#    ({'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]},
#     'IN_GENRE',
#     {'name': 'Genre',
#      'indexes': [],
#      'constraints': ["Constraint( id=74, name='constraint_f8689281', type='UNIQUENESS', schema=(:Genre {name}), ownedIndex=62 )"]}),
#    ({'name': 'Actor', 'indexes': [], 'constraints': []},
#     'DIRECTED',
#     {'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]}),
#    ({'name': 'Director', 'indexes': [], 'constraints': []},
#     'DIRECTED',
#     {'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]}),
#    ({'name': 'Person',
#      'indexes': ['name,bio', 'name'],
#      'constraints': ["Constraint( id=73, name='constraint_4499eae9', type='UNIQUENESS', schema=(:Person {tmdbId}), ownedIndex=63 )"]},
#     'DIRECTED',
#     {'name': 'Movie',
#      'indexes': ['year',
#       'imdbRating',
#       'released',
#       'imdbId',
#       'title',
#       'tagline',
#       'title,plot',
#       'plotEmbedding',
#       'posterEmbedding'],
#      'constraints': ["Constraint( id=77, name='constraint_737d9c1d', type='UNIQUENESS', schema=(:Movie {tmdbId}), ownedIndex=61 )",
#       "Constraint( id=75, name='constraint_3d5fcb7f', type='UNIQUENESS', schema=(:Movie {movieId}), ownedIndex=59 )"]}),
#    ({'name': '_Bloom_Perspective_',
#      'indexes': [],
#      'constraints': ["Constraint( id=3, name='constraint_f7832722', type='UNIQUENESS', schema=(:_Bloom_Perspective_ {id}), ownedIndex=1 )"]},
#     '_Bloom_HAS_SCENE_',
#     {'name': '_Bloom_Scene_', 'indexes': [], 'constraints': []})]}]

# %%
# Return a few Movie nodes with all their properties to preview the movie data (title, plot, embedding, etc.)
#plotEmbedding → a numerical vector representing the movie's plot
#posterEmbedding → a numerical vector representing the movie's poster image
kg.query("MATCH (m:Movie) RETURN m LIMIT 5")
# Out:
# [{'m': {'languages': ['English'],
#    'plotEmbedding': [-0.026989128440618515,
#     -0.024155009537935257,
#     0.006058253347873688,
#     -0.024324016645550728,
#     -0.022516941651701927,
#     -0.0050864629447460175,
#     -0.013442561961710453,
#     -0.004462436772882938,
#     0.001889954088255763,
#     -0.017147717997431755,
#     0.00504421116784215,
#     -0.007975833490490913,
#     0.03221534565091133,
#     -0.012272513471543789,
#     0.01178499311208725,
#     0.02133389189839363,
#     0.028627198189496994,
#     -0.0005025522550567985,
#     0.014040587469935417,
#     -0.014157592318952084,
#     0.0014495606301352382,
#     0.008027835749089718,
#     -0.0222049281001091,
#     -0.025013046339154243,
#     0.004394183866679668,
#     -0.00825534574687481,
#     0.023660989478230476,
#     -0.025416063144803047,
#     0.037181556224823,
#     0.00314450659789145,
#     0.008619360625743866,
#     -0.012064504437148571,
#     0.006025752052664757,
#     -0.006955291144549847,
kg.query("MATCH (a:Actor) RETURN a LIMIT 5")
# Out:
# [{'a': {'bornIn': 'France',
#    'tmdbId': '1271225',
#    'imdbId': '2083046',
#    'born': neo4j.time.Date(1877, 2, 4),
#    'name': 'François Lallement',
#    'died': neo4j.time.Date(1954, 1, 1),
#    'url': 'https://themoviedb.org/person/1271225'}},
#  {'a': {'tmdbId': '1602569',
#    'imdbId': '6170115',
#    'born': neo4j.time.Date(1862, 1, 1),
#    'name': 'Jules-Eugène Legris',
#    'died': neo4j.time.Date(1926, 1, 1),
#    'url': 'https://themoviedb.org/person/1602569'}},
#  {'a': {'bornIn': 'Springfield, Ohio, USA',
#    'tmdbId': '8828',
#    'imdbId': '0001273',
#    'born': neo4j.time.Date(1893, 10, 14),
#    'name': 'Lillian Gish',
#    'bio': "\u200bFrom Wikipedia, the free encyclopedia\n\nLillian Diana Gish (October 14, 1893 – February 27, 1993) was an American stage, screen and television actress whose film acting career spanned 75 years, from 1912 to 1987. \n\nShe was a prominent film star of the 1910s and 1920s, particularly associated with the films of director D. W.  Griffith, including her leading role in Griffith's seminal Birth of a Nation (1915)...",
#    'died': neo4j.time.Date(1993, 2, 27),
#    'poster': 'https://image.tmdb.org/t/p/w440_and_h660_face/6DCWtvv654sc8p2OPnxGbKvl2qC.jpg',
#    'url': 'https://themoviedb.org/person/8828'}},
#  {'a': {'bornIn': 'Madrid, New Mexico Territory , USA',
#    'tmdbId': '8829',
#    'imdbId': '0550615',
#    'born': neo4j.time.Date(1894, 11, 9),
#    'name': 'Mae Marsh',
#    'bio': 'Mae Marsh (born Mary Wayne Marsh, November 9, 1894 – February 13, 1968) was an American film actress with a career spanning over 50 years...',
#    'died': neo4j.time.Date(1968, 2, 13),
#    'poster': 'https://image.tmdb.org/t/p/w440_and_h660_face/wEHHFF2Tq2Z1BlRRr27SOcUW3pu.jpg',
#    'url': 'https://themoviedb.org/person/8829'}},
#  {'a': {'bornIn': 'Shelby County, Alabama, USA',
#    'tmdbId': '8830',
#    'imdbId': '0910400',
#    'born': neo4j.time.Date(1878, 3, 16),
#    'name': 'Henry B. Walthall',
#    'bio': "\u200bFrom Wikipedia, the free encyclopedia\n\nHenry Brazeale Walthall (March 16, 1878 – June 17, 1936) was an American stage and film actor.  He appeared as the Little Colonel in D.  W.  Griffith's The Birth of a Nation (1915).   In New York in 1901, Walthall won a role in Under Southern Skies by Charlotte Blair Parker.  He performed in the play for three years, in New York and on tour...",
#    'died': neo4j.time.Date(1936, 6, 17),
#    'poster': 'https://image.tmdb.org/t/p/w440_and_h660_face/5RZtgV7iFQFvVijQJzNFzViAEu8.jpg',
#    'url': 'https://themoviedb.org/person/8830'}}]

# %% [markdown]
# ## Visualisation

# %%
from pyvis.network import Network
import networkx as nx
from IPython.display import IFrame

query = """
MATCH (m:Movie)-[r:IN_GENRE]->(g:Genre)
RETURN elementId(m) AS source, elementId(g) AS target,
       type(r) AS rel, r,
       COALESCE(m.title, 'Movie') AS source_name,
       COALESCE(g.name, 'Genre') AS target_name
LIMIT 100
"""
results = kg.query(query)

G = nx.DiGraph()
for row in results:
    G.add_node(row['source'], label=row['source_name'])
    G.add_node(row['target'], label=row['target_name'])
    G.add_edge(row['source'], row['target'], label=row['rel'])

net = Network(notebook=True, directed=True, cdn_resources="in_line")
for node in G.nodes(data=True):
    net.add_node(node[0], label=node[1]['label'])
for edge in G.edges(data=True):
    net.add_edge(edge[0], edge[1], title=edge[2]['label'])

net.show("knowledge_graph_IN_GENRE.html")
IFrame("knowledge_graph_IN_GENRE.html", width=1000, height=1000)
# Out:
# knowledge_graph_IN_GENRE.html
#         <iframe
#             width="1000"
#             height="1000"
#             src="knowledge_graph_IN_GENRE.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
query = """
MATCH (u:User)-[r:RATED]->(m:Movie)
RETURN elementId(u) AS source, elementId(m) AS target,
       type(r) AS rel, r,
       COALESCE(u.name, 'User') AS source_name,
       COALESCE(m.title, 'Movie') AS target_name
LIMIT 800
"""
results = kg.query(query)

G = nx.DiGraph()
for row in results:
    G.add_node(row['source'], label=row['source_name'])
    G.add_node(row['target'], label=row['target_name'])

    edge_label = row['rel']
    if isinstance(row['r'], dict) and 'rating' in row['r']:
        edge_label += f" ({row['r']['rating']})"
    G.add_edge(row['source'], row['target'], label=edge_label)

net = Network(notebook=True, directed=True, cdn_resources="in_line")
for node in G.nodes(data=True):
    net.add_node(node[0], label=node[1]['label'])
for edge in G.edges(data=True):
    net.add_edge(edge[0], edge[1], title=edge[2]['label'])

net.show("knowledge_graph_RATED.html")
IFrame("knowledge_graph_RATED.html", width=1000, height=1000)
# Out:
# knowledge_graph_RATED.html
#         <iframe
#             width="1000"
#             height="1000"
#             src="knowledge_graph_RATED.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
query = """
MATCH (a:Actor)-[r:ACTED_IN]->(m:Movie)
RETURN elementId(a) AS source, elementId(m) AS target,
       type(r) AS rel, r,
       COALESCE(a.name, 'Actor') AS source_name,
       COALESCE(m.title, 'Movie') AS target_name
LIMIT 800
"""
results = kg.query(query)

G = nx.DiGraph()
for row in results:
    G.add_node(row['source'], label=row['source_name'])
    G.add_node(row['target'], label=row['target_name'])
    G.add_edge(row['source'], row['target'], label=row['rel'])

net = Network(notebook=True, directed=True, cdn_resources="in_line")
for node in G.nodes(data=True):
    net.add_node(node[0], label=node[1]['label'])
for edge in G.edges(data=True):
    net.add_edge(edge[0], edge[1], title=edge[2]['label'])

net.show("knowledge_graph_ACTED_IN.html")
IFrame("knowledge_graph_ACTED_IN.html", width=1000, height=1000)
# Out:
# knowledge_graph_ACTED_IN.html
#         <iframe
#             width="1000"
#             height="1000"
#             src="knowledge_graph_ACTED_IN.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
query = """
MATCH (d:Director)-[r:DIRECTED]->(m:Movie)
RETURN elementId(d) AS source, elementId(m) AS target,
       type(r) AS rel, r,
       COALESCE(d.name, 'Director') AS source_name,
       COALESCE(m.title, 'Movie') AS target_name
LIMIT 800
"""
results = kg.query(query)

G = nx.DiGraph()
for row in results:
    G.add_node(row['source'], label=row['source_name'])
    G.add_node(row['target'], label=row['target_name'])
    G.add_edge(row['source'], row['target'], label=row['rel'])

net = Network(notebook=True, directed=True, cdn_resources="in_line")
for node in G.nodes(data=True):
    net.add_node(node[0], label=node[1]['label'])
for edge in G.edges(data=True):
    net.add_edge(edge[0], edge[1], title=edge[2]['label'])

net.show("knowledge_graph_DIRECTED.html")
IFrame("knowledge_graph_DIRECTED.html", width=1000, height=1000)
# Out:
# knowledge_graph_DIRECTED.html
#         <iframe
#             width="1000"
#             height="1000"
#             src="knowledge_graph_DIRECTED.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
query = """
MATCH (p:Person)-[r:ACTED_IN|DIRECTED]->(m:Movie)
RETURN elementId(p) AS source, elementId(m) AS target,
       type(r) AS rel, r,
       COALESCE(p.name, 'Person') AS source_name,
       COALESCE(m.title, 'Movie') AS target_name
LIMIT 800
"""
results = kg.query(query)

G = nx.DiGraph()
for row in results:
    G.add_node(row['source'], label=row['source_name'])
    G.add_node(row['target'], label=row['target_name'])
    G.add_edge(row['source'], row['target'], label=row['rel'])

net = Network(notebook=True, directed=True, cdn_resources="in_line")
for node in G.nodes(data=True):
    net.add_node(node[0], label=node[1]['label'])
for edge in G.edges(data=True):
    net.add_edge(edge[0], edge[1], title=edge[2]['label'])

net.show("knowledge_graph_PERSON_COMBINED.html")
IFrame("knowledge_graph_PERSON_COMBINED.html", width=1000, height=1000)
# Out:
# knowledge_graph_PERSON_COMBINED.html
#         <iframe
#             width="1000"
#             height="1000"
#             src="knowledge_graph_PERSON_COMBINED.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install pandas numpy scikit-learn matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (2.2.5)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (3.10.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.11/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 10.2 MB/s eta 0:00:00a 0:00:01
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed pandas-2.2.3 tzdata-2025.2

# %% [markdown]
# #### Checking embedding from online neo4j and created embedding

# %%
kg.query("""
MATCH (m:Movie {title: "Toy Story"})
RETURN m.plotEmbedding AS plotEmbedding
""")
# Out:
# [{'plotEmbedding': [-0.026989128440618515,
#    -0.024155009537935257,
#    0.006058253347873688,
#    -0.024324016645550728,
#    -0.022516941651701927,
#    -0.0050864629447460175,
#    -0.013442561961710453,
#    -0.004462436772882938,
#    0.001889954088255763,
#    -0.017147717997431755,
#    0.00504421116784215,
#    -0.007975833490490913,
#    0.03221534565091133,
#    -0.012272513471543789,
#    0.01178499311208725,
#    0.02133389189839363,
#    0.028627198189496994,
#    -0.0005025522550567985,
#    0.014040587469935417,
#    -0.014157592318952084,
#    0.0014495606301352382,
#    0.008027835749089718,
#    -0.0222049281001091,
#    -0.025013046339154243,
#    0.004394183866679668,
#    -0.00825534574687481,
#    0.023660989478230476,
#    -0.025416063144803047,
#    0.037181556224823,
#    0.00314450659789145,
#    0.008619360625743866,
#    -0.012064504437148571,
#    0.006025752052664757,
#    -0.006955291144549847,
#    -0.03286537528038025,
#    -0.024545026943087578,
#    0.004871953744441271,
#    -0.028627198189496994,
#    0.012103506363928318,
#    -0.005560982506722212,
#    0.011414477601647377,
#    0.03746756538748741,
#    -0.029381228610873222,
-0.035023465752601624, 0.01804475486278534, -0.0011009835870936513, -0.023608988150954247, 0.01116096694022417, 0.010426436550915241, -0.009067879058420658, 0.0016543192323297262, -0.003490645904093981, 0.023504983633756638, 0.02029384858906269, 0.018850788474082947, -0.01340356096625328, 0.019734825938940048, 0.007280304562300444, 0.003679153975099325, -0.00035467109410092235, -0.01596466824412346, 0.008378850296139717, 0.0049792081117630005, -0.011927998624742031, 0.0034321434795856476, -0.0012927416246384382, -0.020631862804293633, -0.0011472980258986354, 0.006935790181159973, 0.02691112644970417, 0.0027447398751974106, 0.02024184726178646, 0.020267847925424576, 0.010452437214553356, -0.0008913498022593558, 0.0067212809808552265, 0.01375457551330328, 0.002058961195871234, 0.021138884127140045, -0.019513815641403198, 0.036791540682315826, -0.012844537384808064, 0.01192149892449379, -0.005232718773186207, 0.03632351756095886, -0.024870039895176888, - ...

# %%
print(df.columns)
# Out:
# Index(['title', 'embedding'], dtype='object')

# %% [markdown]
# # New Implementation after loading all data

# %%
import pandas as pd

# List your CSV file names
csv_files = [
    'movies.csv', 'movieembed.csv', 'ratings.csv', 'users.csv',
    'genre.csv', 'in_genre.csv', 'actor.csv', 'acted_in.csv',
    'directors.csv', 'directed.csv'
]

# Load and inspect each one
for file in csv_files:
    print(f"\n==== {file} ====")
    df = pd.read_csv(file)
    print(df.columns.tolist())   # Show column names
    print(df.head(2))             # Show first 2 rows as sample
# Out:
# ==== movies.csv ====
# ['title', 'plot', 'year', 'runtime', 'budget', 'revenue', 'imdbRating', 'imdbVotes', 'imdbId', 'tmdbId', 'poster', 'countries', 'languages', 'url', 'embedding', 'movieId']
#        title                                               plot    year  \
# 0  Toy Story  A cowboy doll is profoundly threatened and jea...  1995.0
# 1    Jumanji  When two kids find and play a magical board ga...  1995.0
#
#    runtime      budget      revenue  imdbRating  imdbVotes  imdbId  tmdbId  \
# 0     81.0  30000000.0  373554033.0         8.3   591836.0  114709   862.0
# 1    104.0  65000000.0  262797249.0         6.9   198355.0  113497  8844.0
#
#                                               poster countries  \
# 0  https://image.tmdb.org/t/p/w440_and_h660_face/...     [USA]
# 1  https://image.tmdb.org/t/p/w440_and_h660_face/...     [USA]
#
#             languages                                url  \
# 0           [English]   https://themoviedb.org/movie/862
# 1  [English,  French]  https://themoviedb.org/movie/8844
#
#                                            embedding  movieId
# 0  [-0.026989128440618515, -0.024155009537935257,...        1
# 1  [-0.0016367682255804539, -0.02242148295044899,...        2
#
# ==== movieembed.csv ====
# ['title', 'embedding']
#        title                                          embedding
# 0  Toy Story  [-0.026989128440618515, -0.024155009537935257,...
# 1    Jumanji  [-0.0016367682255804539, -0.02242148295044899,...
#
# ==== ratings.csv ====
# ['userId', 'movieTitle', 'rating', 'timestamp']
#    userId movieTitle  rating   timestamp
# 0       1       Antz     2.0  1260759108
# 1       1   Fly, The     2.5  1260759113
#
# ==== users.csv ====
# ['userId']
#    userId
# 0       1
# 1       2
#
# ==== genre.csv ====
# ['name']
#         name
# 0  Adventure
# 1  Animation
#
# ==== in_genre.csv ====
# ['movie_title', 'genre_name']
#         movie_title genre_name
# 0    Boxtrolls, The  Adventure
# 1  The Book of Life  Adventure
#
# ==== actor.csv ====
# ['name']
#                   name
# 0   François Lallement
# 1  Jules-Eugène Legris
#
# ==== acted_in.csv ====
# ['actor_name', 'movie_title']
#    actor_name movie_title
# 0  Jim Varney   Toy Story
# 1   Tim Allen   Toy Story
#
# ==== directors.csv ====
# ['name']
#            name
# 0  Harold Lloyd
# 1  Paul Wegener
#
# ==== directed.csv ====
# ['director_name', 'movie_title']
#   director_name                                      movie_title
# 0  Harold Lloyd                                 Kid Brother, The
# 1  Paul Wegener  Golem, The (Golem, wie er in die Welt kam, Der)

# %% [markdown]
# ## Step 1: Load all CSV files into Pandas DataFrames

# %%
import pandas as pd

# Load nodes
movies_df = pd.read_csv('movies.csv')
users_df = pd.read_csv('users.csv')
genres_df = pd.read_csv('genre.csv')
actors_df = pd.read_csv('actor.csv')
directors_df = pd.read_csv('directors.csv')

# Load relationships
ratings_df = pd.read_csv('ratings.csv')
in_genre_df = pd.read_csv('in_genre.csv')
acted_in_df = pd.read_csv('acted_in.csv')
directed_df = pd.read_csv('directed.csv')

print("✅ All CSV files loaded!")
# Out:
# ✅ All CSV files loaded!

# %% [markdown]
# ## Step 2: Check basic info about each DataFrame

# %%
print("Movies:", movies_df.shape, movies_df.columns.tolist())
print("Users:", users_df.shape, users_df.columns.tolist())
print("Genres:", genres_df.shape, genres_df.columns.tolist())
print("Actors:", actors_df.shape, actors_df.columns.tolist())
print("Directors:", directors_df.shape, directors_df.columns.tolist())

print("Ratings:", ratings_df.shape, ratings_df.columns.tolist())
print("In Genre:", in_genre_df.shape, in_genre_df.columns.tolist())
print("Acted In:", acted_in_df.shape, acted_in_df.columns.tolist())
print("Directed:", directed_df.shape, directed_df.columns.tolist())
# Out:
# Movies: (9083, 16) ['title', 'plot', 'year', 'runtime', 'budget', 'revenue', 'imdbRating', 'imdbVotes', 'imdbId', 'tmdbId', 'poster', 'countries', 'languages', 'url', 'embedding', 'movieId']
# Users: (671, 1) ['userId']
# Genres: (20, 1) ['name']
# Actors: (15443, 1) ['name']
# Directors: (4091, 1) ['name']
# Ratings: (100004, 4) ['userId', 'movieTitle', 'rating', 'timestamp']
# In Genre: (20340, 2) ['movie_title', 'genre_name']
# Acted In: (35910, 2) ['actor_name', 'movie_title']
# Directed: (10007, 2) ['director_name', 'movie_title']

# %% [markdown]
# # NEW TRIPLETS WITH COMPLETE USE OF DATA

# %%
import pandas as pd
import ast

# 1. Load all CSVs
movies_df = pd.read_csv('movies.csv')
ratings_df = pd.read_csv('ratings.csv')
in_genre_df = pd.read_csv('in_genre.csv')
acted_in_df = pd.read_csv('acted_in.csv')
directed_df = pd.read_csv('directed.csv')

# 2. Create triplets separately
triplets = []

## Movie properties
for idx, row in movies_df.iterrows():
    title = row['title']
    if pd.notnull(row['year']):
        triplets.append((title, "was released in year", str(int(row['year']))))
    if pd.notnull(row['runtime']):
        triplets.append((title, "has a runtime of", f"{int(row['runtime'])} minutes"))
    if pd.notnull(row['budget']) and row['budget'] > 0:
        triplets.append((title, "had a budget of", f"${int(row['budget'])}"))
    if pd.notnull(row['revenue']) and row['revenue'] > 0:
        triplets.append((title, "earned revenue of", f"${int(row['revenue'])}"))
    if pd.notnull(row['imdbRating']):
        triplets.append((title, "has IMDb rating", str(row['imdbRating'])))
    if pd.notnull(row['countries']):
        try:
            countries = ast.literal_eval(row['countries']) if isinstance(row['countries'], str) else row['countries']
            for country in countries:
                triplets.append((title, "was produced in", country))
        except:
            pass
    if pd.notnull(row['languages']):
        try:
            languages = ast.literal_eval(row['languages']) if isinstance(row['languages'], str) else row['languages']
            for language in languages:
                triplets.append((title, "is in language", language))
        except:
            pass

## Ratings (User rated Movie)
for idx, row in ratings_df.iterrows():
    triplets.append((f"User {row['userId']}", f"rated {row['movieTitle']}", f"{row['rating']}"))

## In Genre (Movie belongs to Genre)
for idx, row in in_genre_df.iterrows():
    triplets.append((row['movie_title'], "is in genre", row['genre_name']))

## Acted In (Actor acted in Movie)
for idx, row in acted_in_df.iterrows():
    triplets.append((row['actor_name'], "acted in", row['movie_title']))

## Directed (Director directed Movie)
for idx, row in directed_df.iterrows():
    triplets.append((row['director_name'], "directed", row['movie_title']))

# 3. Confirm total
print(f"✅ Total Triplets Created: {len(triplets)}")

# 4. Peek a few
for t in triplets[:10]:
    print(t)
# Out:
# ✅ Total Triplets Created: 203572
# ('Toy Story', 'was released in year', '1995')
# ('Toy Story', 'has a runtime of', '81 minutes')
# ('Toy Story', 'had a budget of', '$30000000')
# ('Toy Story', 'earned revenue of', '$373554033')
# ('Toy Story', 'has IMDb rating', '8.3')
# ('Jumanji', 'was released in year', '1995')
# ('Jumanji', 'has a runtime of', '104 minutes')
# ('Jumanji', 'had a budget of', '$65000000')
# ('Jumanji', 'earned revenue of', '$262797249')
# ('Jumanji', 'has IMDb rating', '6.9')

# %% [markdown]
# ## Turn Triplets into Natural Language Sentences

# %%
triplet_sentences = []

for subj, rel, obj in triplets:
    sentence = f"{subj} {rel} {obj}"
    triplet_sentences.append(sentence)

print(f" Total Sentences: {len(triplet_sentences)}")
for s in triplet_sentences[:5]:
    print(s)
# Out:
# ✅ Total Sentences: 203572
# Toy Story was released in year 1995
# Toy Story has a runtime of 81 minutes
# Toy Story had a budget of $30000000
# Toy Story earned revenue of $373554033
# Toy Story has IMDb rating 8.3

# %% [markdown]
# ## Encode these Sentences into Embeddings

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

# Encode all sentences
triplet_embeddings = model.encode(triplet_sentences, batch_size=64, show_progress_bar=True)

print(triplet_embeddings.shape)  # Should be (203572, 384)
# Out:
# Batches: 100%|██████████| 3181/3181 [01:00<00:00, 52.33it/s]
# (203572, 384)

# %% [markdown]
# ## Store embeddings in FAISS Index

# %%
import faiss
import numpy as np

dimension = triplet_embeddings.shape[1]  # 384
index = faiss.IndexFlatL2(dimension)
index.add(np.array(triplet_embeddings).astype('float32'))

print(f"✅ FAISS Index Created. Total vectors: {index.ntotal}")
# Out:
# ✅ FAISS Index Created. Total vectors: 203572

# %% [markdown]
# ## Build Retriever Function

# %%
def retrieve_top_triplets(query, model, index, sentences, top_k=5000):
    query_embedding = model.encode([query])
    D, I = index.search(np.array(query_embedding).astype('float32'), top_k)
    results = []
    for idx, dist in zip(I[0], D[0]):
        if idx < len(sentences):
            results.append((sentences[idx], dist))
    return results

# %% [markdown]
# ### Test Retriever

# %%
sample_queries = [
    "Find adventure movies released after 2000",
    "Movies acted by Tim Allen",
    "Movies directed by Steven Spielberg",
    "Movies produced in USA",
    "Find English language movies",
    "Find movies rated more than 4 by User 1"
]

for query in sample_queries:
    results = retrieve_top_triplets(query, model, index, triplet_sentences, top_k=5)
    print(f"\nQuery: {query}")
    for sentence, dist in results:
        print(f" - {sentence} (Distance: {dist:.4f})")
# Out:
# Query: Find adventure movies released after 2000
#  - Adventureland was released in year 2009 (Distance: 0.8231)
#  - Back to the Future Part II is in genre Adventure (Distance: 0.8522)
#  - Adventures of Rocky and Bullwinkle, The was released in year 2000 (Distance: 0.8528)
#  - Back to the Future is in genre Adventure (Distance: 0.8568)
#  - Year One is in genre Adventure (Distance: 0.8693)
#
# Query: Movies acted by Tim Allen
#  - Tim Allen acted in Toy Story (Distance: 0.4307)
#  - Tim Allen acted in Zoom (Distance: 0.4566)
#  - Tim Allen acted in Toy Story 3 (Distance: 0.4921)
#  - Tim Allen acted in Big Trouble (Distance: 0.4972)
#  - Tim Allen acted in Toy Story 2 (Distance: 0.5048)
#
# Query: Movies directed by Steven Spielberg
#  - Steven Spielberg directed 1941 (Distance: 0.2879)
#  - Steven Spielberg directed Munich (Distance: 0.4188)
#  - Steven Spielberg directed Always (Distance: 0.4402)
#  - Steven Spielberg directed Duel (Distance: 0.4550)
#  - Steven Spielberg directed Jurassic Park (Distance: 0.4676)
#
# Query: Movies produced in USA
#  - American Movie is in genre Documentary (Distance: 0.5359)
#  - Made in America has IMDb rating 4.9 (Distance: 0.6052)
#  - Made in America is in genre Comedy (Distance: 0.6305)
#  - America, America has IMDb rating 7.9 (Distance: 0.6934)
#  - Richard Benjamin directed Made in America (Distance: 0.7428)
#
# Query: Find English language movies
#  - This Is England is in genre Drama (Distance: 0.8060)
#  - Johnny English is in genre Comedy (Distance: 0.8540)
#  - English Teacher, The has IMDb rating 5.8 (Distance: 0.8661)
#  - Searchers, The has IMDb rating 8.0 (Distance: 0.8735)
#  - This Is England has IMDb rating 7.7 (Distance: 0.8972)
#
# Query: Find movies rated more than 4 by User 1
#  - User 15 rated This Film Is Not Yet Rated 4.0 (Distance: 0.7493)
#  - User 234 rated This Film Is Not Yet Rated 4.0 (Distance: 0.7807)
#  - User 624 rated Inbetweeners Movie, The 4.0 (Distance: 0.7842)
#  - User 407 rated American Movie 4.0 (Distance: 0.8059)
#  - User 15 rated Movie 43 0.5 (Distance: 0.8142)

# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Using cached langchain_groq-0.3.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.49 in ./.venv/lib/python3.11/site-packages (from langchain-groq) (0.3.56)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Using cached groq-0.23.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.11/site-packages (from groq<1,>=0.4.1->langchain-groq) (4.9.0)
# Collecting distro<2,>=1.7.0 (from groq<1,>=0.4.1->langchain-groq)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.11/site-packages (from groq<1,>=0.4.1->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.11/site-packages (from groq<1,>=0.4.1->langchain-groq) (2.11.3)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.11/site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in ./.venv/lib/python3.11/site-packages (from groq<1,>=0.4.1->langchain-groq) (4.13.2)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.10)
# Requirement already satisfied: certifi in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.16.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.3.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.4.0)
# Using cached langchain_groq-0.3.2-py3-none-any.whl (15 kB)
# Using cached groq-0.23.1-py3-none-any.whl (127 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Installing collected packages: distro, groq, langchain-groq
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [langchain-groq]
# Successfully installed distro-1.9.0 groq-0.23.1 langchain-groq-0.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.vectorstores import FAISS
from langchain.schema import Document
from langchain_groq import ChatGroq

# %% [markdown]
# ## Build a Simple Retriever Class

# %%
from langchain.schema import Document
from langchain.docstore import InMemoryDocstore
from langchain.vectorstores import FAISS

llm = ChatGroq(
    temperature=0,
    model_name="llama3-70b-8192",
    groq_api_key="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"
)


# Fix mapping: Make sure keys are Python int not np.int64
index_to_docstore_id = {int(i): str(i) for i in range(len(triplet_texts))}

# Rebuild docstore correctly
docstore = InMemoryDocstore({str(i): Document(page_content=triplet_texts[i]) for i in range(len(triplet_texts))})

# Rebuild FAISS vectorstore
vectorstore = FAISS(
    embedding_function=model.encode,
    index=index,
    docstore=docstore,
    index_to_docstore_id=index_to_docstore_id
)

# Rebuild retriever
retriever = vectorstore.as_retriever(search_kwargs={"k": 500})


# 4. Build QA chain
from langchain.chains import RetrievalQA
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="stuff"
)
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
#Find adventure movies released after 2000.
query = "Find adventure movies released after 2000."
result = qa_chain.invoke(query)

print("Answer:", result['result'])


kg.query("""
MATCH (m:Movie)-[:IN_GENRE]->(g:Genre)
WHERE g.name = "Adventure" AND m.year > 2000
RETURN m.title, m.year
ORDER BY m.year ASC
""")
# Out:
# Answer: Based on the provided data, here are the adventure movies released after 2000:
#
# 1. Hero (Ying xiong) (2002) - genre: Adventure
# 2. Indiana Jones and the Last Crusade (2008) - genre: Action (note: this is a re-release, the original release was in 1989)
# 3. 3:10 to Yuma (2007) - genre: Adventure
# 4. Yes, Madam (a.k.a. Police Assassins) (a.k.a. In the Line of Duty 2) (Huang gu shi jie) (2000) - genre: Action
# 5. All Is Lost (2013) - genre: Action
# 6. The Raid 2: Berandal (2014) - genre: Action
# 7. Jet Li's Fearless (Huo Yuan Jia) (2006) - genre: Action
# 8. Knight's Tale, A (2001) - genre: Action
#
# Please note that the list might not be exhaustive, as the provided data is limited.
# [{'m.title': 'Spy Kids', 'm.year': 2001},
#  {'m.title': 'Joe Dirt', 'm.year': 2001},
#  {'m.title': 'Mummy Returns, The', 'm.year': 2001},
#  {'m.title': 'Shrek', 'm.year': 2001},
#  {'m.title': 'Atlantis: The Lost Empire', 'm.year': 2001},
#  {'m.title': 'Lara Croft: Tomb Raider', 'm.year': 2001},
#  {'m.title': 'A.I. Artificial Intelligence', 'm.year': 2001},
#  {'m.title': 'Final Fantasy: The Spirits Within', 'm.year': 2001},
#  {'m.title': 'Jurassic Park III', 'm.year': 2001},
#  {'m.title': 'Planet of the Apes', 'm.year': 2001},
#  {'m.title': 'Jay and Silent Bob Strike Back', 'm.year': 2001},
#  {'m.title': 'Musketeer, The', 'm.year': 2001},
#  {'m.title': 'Extreme Days', 'm.year': 2001},
#  {'m.title': 'Joy Ride', 'm.year': 2001},
#  {'m.title': 'Monsters, Inc.', 'm.year': 2001},
#  {'m.title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'm.year': 2001},
#  {'m.title': 'Black Knight', 'm.year': 2001},
#  {'m.title': 'Baran', 'm.year': 2001},
#  {'m.title': 'Jimmy Neutron: Boy Genius', 'm.year': 2001},
#  {'m.title': 'Lord of the Rings: The Fellowship of the Ring, The',
#   'm.year': 2001},
#  {'m.title': 'Spirited Away (Sen to Chihiro no kamikakushi)', 'm.year': 2001},
#  {'m.title': 'Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie)', 'm.year': 2001},
#  {'m.title': 'Suriyothai (a.k.a. Legend of Suriyothai, The)', 'm.year': 2001},
#  {'m.title': 'Samsara', 'm.year': 2001},
#  {'m.title': 'Musa the Warrior (Musa)', 'm.year': 2001},
#  {'m.title': 'Zenon: The Zequel', 'm.year': 2001},
#  {'m.title': 'Snow Dogs', 'm.year': 2002},
#  {'m.title': 'The Count of Monte Cristo', 'm.year': 2002},
#  {'m.title': 'Return to Never Land', 'm.year': 2002},
#  {'m.title': 'Time Machine, The', 'm.year': 2002},
#  {'m.title': 'Ice Age', 'm.year': 2002},
#  {'m.title': 'The Scorpion King', 'm.year': 2002},
#  {'m.title': 'Spider-Man', 'm.year': 2002},
#  {'m.title': 'Star Wars: Episode II - Attack of the Clones', 'm.year': 2002},
#  {'m.title': 'Spirit: Stallion of the Cimarron', 'm.year': 2002},
#  {'m.title': 'Scooby-Doo', 'm.year': 2002},
#  {'m.title': 'Lilo & Stitch', 'm.year': 2002},
#  {'m.title': 'Rabbit-Proof Fence', 'm.year': 2002},
#  {'m.title': 'Hey Arnold! The Movie', 'm.year': 2002},
#  {'m.title': 'Crocodile Hunter: Collision Course, The', 'm.year': 2002},
#  {'m.title': 'Reign of Fire', 'm.year': 2002},
#  {'m.title': 'K-19: The Widowmaker', 'm.year': 2002},
#  {'m.title': 'Spy Kids 2: The Island of Lost Dreams', 'm.year': 2002},
#  {'m.title': 'Adventures of Pluto Nash, The', 'm.year': 2002},
#  {'m.title': 'Blue Crush', 'm.year': 2002},
#  {'m.title': 'Four Feathers, The', 'm.year': 2002},
#  {'m.title': 'I Spy', 'm.year': 2002},
#  {'m.title': 'Harry Potter and the Chamber of Secrets', 'm.year': 2002},
#  {'m.title': 'Die Another Day', 'm.year': 2002},
#  {'m.title': 'Extreme Ops', 'm.year': 2002},
#  {'m.title': 'Treasure Planet', 'm.year': 2002},
#  {'m.title': 'Lord of the Rings: The Two Towers, The', 'm.year': 2002},
#  {'m.title': 'City of God (Cidade de Deus)', 'm.year': 2002},
#  {'m.title': 'Gerry', 'm.year': 2002},
#  {'m.title': 'In This World', 'm.year': 2002},
#  {'m.title': 'Interstate 60', 'm.year': 2002},
#  {'m.title': 'Hero (Ying xiong)', 'm.year': 2002},
#  {'m.title': 'Cat Returns, The (Neko no ongaeshi)', 'm.year': 2002},
#  {'m.title': 'Shanghai Knights', 'm.year': 2003},
#  {'m.title': 'Bulletproof Monk', 'm.year': 2003},
#  {'m.title': 'Holes', 'm.year': 2003},
#  {'m.title': 'X2: X-Men United', 'm.year': 2003},
#  {'m.title': 'Matrix Reloaded, The', 'm.year': 2003},
#  {'m.title': 'Finding Nemo', 'm.year': 2003},
#  {'m.title': "Charlie's Angels: Full Throttle", 'm.year': 2003},
#  {'m.title': 'Hulk', 'm.year': 2003},
#  {'m.title': 'Sinbad: Legend of the Seven Seas', 'm.year': 2003},
#  {'m.title': 'Terminator 3: Rise of the Machines', 'm.year': 2003},
#  {'m.title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'm.year': 2003},
#  {'m.title': 'Lara Croft Tomb Raider: The Cradle of Life', 'm.year': 2003},
#  {'m.title': 'Spy Kids 3-D: Game Over', 'm.year': 2003},
#  {'m.title': 'Agent Cody Banks', 'm.year': 2003},
#  {'m.title': 'Once Upon a Time in Mexico', 'm.year': 2003},
#  {'m.title': 'Rundown, The', 'm.year': 2003},
#  {'m.title': 'Brother Bear', 'm.year': 2003},
#  {'m.title': 'Matrix Revolutions, The', 'm.year': 2003},
#  {'m.title': 'Master and Commander: The Far Side of the World',
#   'm.year': 2003},
#  {'m.title': 'Missing, The', 'm.year': 2003},
#  {'m.title': 'Timeline', 'm.year': 2003},
#  {'m.title': 'Last Samurai, The', 'm.year': 2003},
#  {'m.title': 'Lord of the Rings: The Return of the King, The', 'm.year': 2003},
#  {'m.title': 'Peter Pan', 'm.year': 2003},
#  {'m.title': 'Touching the Void', 'm.year': 2003},
#  {'m.title': 'Kaena: The Prophecy (Kaena: La prophétie)', 'm.year': 2003},
#  {'m.title': 'Tokyo Godfathers', 'm.year': 2003},
#  {'m.title': 'Warriors of Heaven and Earth (Tian di ying xiong)',
#   'm.year': 2003},
#  {'m.title': 'Interstella 5555: The 5tory of the 5ecret 5tar 5ystem',
#   'm.year': 2003},
#  {'m.title': 'Saints and Soldiers', 'm.year': 2003},
#  {'m.title': 'Snow Walker, The', 'm.year': 2003},
#  {'m.title': 'EuroTrip', 'm.year': 2004},
#  {'m.title': 'Hidalgo', 'm.year': 2004},
#  {'m.title': 'Scooby-Doo 2: Monsters Unleashed', 'm.year': 2004},
#  {'m.title': 'Hellboy', 'm.year': 2004},
#  {'m.title': 'New York Minute', 'm.year': 2004},
#  {'m.title': 'Van Helsing', 'm.year': 2004},
#  {'m.title': 'Troy', 'm.year': 2004},
#  {'m.title': 'Shrek 2', 'm.year': 2004},
#  {'m.title': 'Day After Tomorrow, The', 'm.year': 2004},
#  {'m.title': 'Harry Potter and the Prisoner of Azkaban', 'm.year': 2004},
#  {'m.title': 'Around the World in 80 Days', 'm.year': 2004},
#  {'m.title': 'Two Brothers (Deux frères)', 'm.year': 2004},
#  {'m.title': 'Spider-Man 2', 'm.year': 2004},
#  {'m.title': 'King Arthur', 'm.year': 2004},
#  {'m.title': 'I, Robot', 'm.year': 2004},
#  {'m.title': 'Harold and Kumar Go to White Castle', 'm.year': 2004},
#  {'m.title': 'Yu-Gi-Oh!', 'm.year': 2004},
#  {'m.title': 'Anacondas: The Hunt for the Blood Orchid', 'm.year': 2004},
#  {'m.title': 'Sky Captain and the World of Tomorrow', 'm.year': 2004},
#  {'m.title': 'Motorcycle Diaries, The (Diarios de motocicleta)',
#   'm.year': 2004},
#  {'m.title': 'Team America: World Police', 'm.year': 2004},
#  {'m.title': 'Incredibles, The', 'm.year': 2004},
#  {'m.title': 'Polar Express, The', 'm.year': 2004},
#  {'m.title': 'After the Sunset', 'm.year': 2004},
#  {'m.title': 'National Treasure', 'm.year': 2004},
#  {'m.title': 'SpongeBob SquarePants Movie, The', 'm.year': 2004},
#  {'m.title': 'Alexander', 'm.year': 2004},
#  {'m.title': "Lemony Snicket's A Series of Unfortunate Events",
#   'm.year': 2004},
#  {'m.title': 'Flight of the Phoenix', 'm.year': 2004},
#  {'m.title': 'Life Aquatic with Steve Zissou, The', 'm.year': 2004},
#  {'m.title': "Howl's Moving Castle (Hauru no ugoku shiro)", 'm.year': 2004},
#  {'m.title': 'Palindromes', 'm.year': 2004},
#  {'m.title': 'Mind Game', 'm.year': 2004},
#  {'m.title': 'G.O.R.A.', 'm.year': 2004},
#  {'m.title': 'Dead Leaves', 'm.year': 2004},
#  {'m.title': "'Hellboy': The Seeds of Creation", 'm.year': 2004},
#  {'m.title': 'Zenon: Z3', 'm.year': 2004},
#  {'m.title': 'Charlie and the Chocolate Factory', 'm.year': 2005},
#  {'m.title': 'Elektra', 'm.year': 2005},
#  {'m.title': 'Robots', 'm.year': 2005},
#  {'m.title': 'Miss Congeniality 2: Armed and Fabulous', 'm.year': 2005},
#  {'m.title': 'Sahara', 'm.year': 2005},
#  {'m.title': "Hitchhiker's Guide to the Galaxy, The", 'm.year': 2005},
#  {'m.title': 'Star Wars: Episode III - Revenge of the Sith', 'm.year': 2005},
#  {'m.title': 'Madagascar', 'm.year': 2005},
#  {'m.title': 'Sisterhood of the Traveling Pants, The', 'm.year': 2005},
#  {'m.title': 'Mr. & Mrs. Smith', 'm.year': 2005},
#  {'m.title': 'Adventures of Sharkboy and Lavagirl 3-D, The', 'm.year': 2005},
#  {'m.title': 'Herbie: Fully Loaded', 'm.year': 2005},
#  {'m.title': 'War of the Worlds', 'm.year': 2005},
#  {'m.title': 'Fantastic Four', 'm.year': 2005},
#  {'m.title': 'Sky High', 'm.year': 2005},
#  {'m.title': 'Stealth', 'm.year': 2005},
#  {'m.title': 'Serenity', 'm.year': 2005},
#  {'m.title': 'Dukes of Hazzard, The', 'm.year': 2005},
#  {'m.title': 'Valiant', 'm.year': 2005},
#  {'m.title': 'Cave, The', 'm.year': 2005},
#  {'m.title': 'Family Guy Presents Stewie Griffin: The Untold Story',
#   'm.year': 2005},
#  {'m.title': 'Final Fantasy VII: Advent Children', 'm.year': 2005},
#  {'m.title': 'Into the Blue', 'm.year': 2005},
#  {'m.title': 'MirrorMask', 'm.year': 2005},
#  {'m.title': 'Wallace & Gromit in The Curse of the Were-Rabbit',
#   'm.year': 2005},
#  {'m.title': 'Legend of Zorro, The', 'm.year': 2005},
#  {'m.title': 'Chicken Little', 'm.year': 2005},
#  {'m.title': 'Descent, The', 'm.year': 2005},
#  {'m.title': 'Harry Potter and the Goblet of Fire', 'm.year': 2005},
#  {'m.title': 'Zathura', 'm.year': 2005},
#  {'m.title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#   'm.year': 2005},
#  {'m.title': 'King Kong', 'm.year': 2005},
#  {'m.title': 'Three Burials of Melquiades Estrada, The', 'm.year': 2005},
#  {'m.title': 'Transamerica', 'm.year': 2005},
#  {'m.title': 'Cheaper by the Dozen 2', 'm.year': 2005},
#  {'m.title': 'Casanova', 'm.year': 2005},
#  {'m.title': 'New World, The', 'm.year': 2005},
#  {'m.title': 'Fullmetal Alchemist the Movie: Conqueror of Shamballa (Gekijô-ban hagane no renkinjutsushi: Shanbara wo yuku mono)',
#   'm.year': 2005},
#  {'m.title': 'Jack-Jack Attack', 'm.year': 2005},
#  {'m.title': 'Survival Island (Three)', 'm.year': 2005},
#  {'m.title': 'Pink Panther, The', 'm.year': 2006},
#  {'m.title': 'Curious George', 'm.year': 2006},
#  {'m.title': 'Eight Below', 'm.year': 2006},
#  {'m.title': 'Ice Age 2: The Meltdown', 'm.year': 2006},
#  {'m.title': 'Mission: Impossible III', 'm.year': 2006},
#  {'m.title': 'RV', 'm.year': 2006},
#  {'m.title': 'Over the Hedge', 'm.year': 2006},
#  {'m.title': 'Poseidon', 'm.year': 2006},
#  {'m.title': 'Click', 'm.year': 2006},
#  {'m.title': "Pirates of the Caribbean: Dead Man's Chest", 'm.year': 2006},
#  {'m.title': 'Superman Returns', 'm.year': 2006},
#  {'m.title': 'Little Miss Sunshine', 'm.year': 2006},
#  {'m.title': 'Ant Bully, The', 'm.year': 2006},
#  {'m.title': 'Zoom', 'm.year': 2006},
#  {'m.title': 'Idiocracy', 'm.year': 2006},
#  {'m.title': "Everyone's Hero", 'm.year': 2006},
#  {'m.title': 'Apocalypto', 'm.year': 2006},
#  {'m.title': 'Flyboys', 'm.year': 2006},
#  {'m.title': 'Open Season', 'm.year': 2006},
#  {'m.title': 'Children of Men', 'm.year': 2006},
#  {'m.title': 'Casino Royale', 'm.year': 2006},
#  {'m.title': 'Happy Feet', 'm.year': 2006},
#  {'m.title': 'Tenacious D in The Pick of Destiny', 'm.year': 2006},
#  {'m.title': 'Turistas', 'm.year': 2006},
#  {'m.title': 'Blood Diamond', 'm.year': 2006},
#  {'m.title': 'Eragon', 'm.year': 2006},
#  {'m.title': "Librarian: Return to King Solomon's Mines, The", 'm.year': 2006},
#  {'m.title': 'Rescue Dawn', 'm.year': 2006},
#  {'m.title': 'Tekkonkinkreet (Tekkon kinkurîto)', 'm.year': 2006},
#  {'m.title': 'Fall, The', 'm.year': 2006},
#  {'m.title': 'Death Note', 'm.year': 2006},
#  {'m.title': 'Asterix and the Vikings (Astérix et les Vikings)',
#   'm.year': 2006},
#  {'m.title': 'Bridge to Terabithia', 'm.year': 2007},
#  {'m.title': 'Epic Movie', 'm.year': 2007},
#  {'m.title': 'Wild Hogs', 'm.year': 2007},
#  {'m.title': 'Last Mimzy, The', 'm.year': 2007},
#  {'m.title': 'TMNT (Teenage Mutant Ninja Turtles)', 'm.year': 2007},
#  {'m.title': 'Meet the Robinsons', 'm.year': 2007},
#  {'m.title': 'Sunshine', 'm.year': 2007},
#  {'m.title': 'Pathfinder', 'm.year': 2007},
#  {'m.title': 'Aqua Teen Hunger Force Colon Movie Film for Theaters',
#   'm.year': 2007},
#  {'m.title': 'Condemned, The', 'm.year': 2007},
#  {'m.title': 'Spider-Man 3', 'm.year': 2007},
#  {'m.title': 'Shrek the Third', 'm.year': 2007},
#  {'m.title': "Pirates of the Caribbean: At World's End", 'm.year': 2007},
#  {'m.title': 'Fantastic Four: Rise of the Silver Surfer', 'm.year': 2007},
#  {'m.title': 'Nancy Drew', 'm.year': 2007},
#  {'m.title': 'Death Proof', 'm.year': 2007},
#  {'m.title': 'Live Free or Die Hard', 'm.year': 2007},
#  {'m.title': 'Harry Potter and the Order of the Phoenix', 'm.year': 2007},
#  {'m.title': 'Stardust', 'm.year': 2007},
#  {'m.title': 'Hunting Party, The', 'm.year': 2007},
#  {'m.title': 'Into the Wild', 'm.year': 2007},
#  {'m.title': 'Seeker: The Dark Is Rising, The', 'm.year': 2007},
#  {'m.title': 'Darjeeling Limited, The', 'm.year': 2007},
#  {'m.title': 'Silk', 'm.year': 2007},
#  {'m.title': 'Beowulf', 'm.year': 2007},
#  {'m.title': 'Enchanted', 'm.year': 2007},
#  {'m.title': 'Golden Compass, The', 'm.year': 2007},
#  {'m.title': 'National Treasure: Book of Secrets', 'm.year': 2007},
#  {'m.title': 'Water Horse: Legend of the Deep, The', 'm.year': 2007},
#  {'m.title': 'D-War (Dragon Wars)', 'm.year': 2007},
#  {'m.title': 'In the Name of the King: A Dungeon Siege Tale', 'm.year': 2007},
#  {'m.title': 'Rogue', 'm.year': 2007},
#  {'m.title': 'Shrek the Halls', 'm.year': 2007},
#  {'m.title': 'Sword of the Stranger (Sutorejia: Mukô hadan)', 'm.year': 2007},
#  {'m.title': 'Terra (a.k.a. Battle for Terra)', 'm.year': 2007},
#  {'m.title': 'Afro Samurai', 'm.year': 2007},
#  {'m.title': 'Hellboy II: The Golden Army', 'm.year': 2008},
#  {'m.title': "Fool's Gold", 'm.year': 2008},
#  {'m.title': 'Jumper', 'm.year': 2008},
#  {'m.title': 'Spiderwick Chronicles, The', 'm.year': 2008},
#  {'m.title': '10,000 BC', 'm.year': 2008},
#  {'m.title': 'Horton Hears a Who!', 'm.year': 2008},
#  {'m.title': "Nim's Island", 'm.year': 2008},
#  {'m.title': 'Harold & Kumar Escape from Guantanamo Bay', 'm.year': 2008},
#  {'m.title': 'Forbidden Kingdom, The', 'm.year': 2008},
#  {'m.title': 'Iron Man', 'm.year': 2008},
#  {'m.title': 'Chronicles of Narnia: Prince Caspian, The', 'm.year': 2008},
#  {'m.title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'm.year': 2008},
#  {'m.title': 'WALL·E', 'm.year': 2008},
#  {'m.title': 'Hancock', 'm.year': 2008},
#  {'m.title': 'Journey to the Center of the Earth', 'm.year': 2008},
#  {'m.title': 'Meet Dave', 'm.year': 2008},
#  {'m.title': 'Space Chimps', 'm.year': 2008},
#  {'m.title': 'Mummy: Tomb of the Dragon Emperor, The', 'm.year': 2008},
#  {'m.title': 'Red Cliff (Chi bi)', 'm.year': 2008},
#  {'m.title': 'Sisterhood of the Traveling Pants 2, The', 'm.year': 2008},
#  {'m.title': 'Tropic Thunder', 'm.year': 2008},
#  {'m.title': 'Star Wars: The Clone Wars', 'm.year': 2008},
#  {'m.title': 'Mutant Chronicles', 'm.year': 2008},
#  {'m.title': 'Death Race', 'm.year': 2008},
#  {'m.title': 'Babylon A.D.', 'm.year': 2008},
#  {'m.title': 'City of Ember', 'm.year': 2008},
#  {'m.title': "Futurama: Bender's Game", 'm.year': 2008},
#  {'m.title': 'Madagascar: Escape 2 Africa', 'm.year': 2008},
#  {'m.title': 'Quantum of Solace', 'm.year': 2008},
#  {'m.title': 'Beverly Hills Chihuahua', 'm.year': 2008},
#  {'m.title': 'Australia', 'm.year': 2008},
#  {'m.title': 'Bolt', 'm.year': 2008},
#  {'m.title': 'Transporter 3', 'm.year': 2008},
#  {'m.title': 'Bedtime Stories', 'm.year': 2008},
#  {'m.title': 'Ponyo (Gake no ue no Ponyo)', 'm.year': 2008},
#  {'m.title': 'Tale of Despereaux, The', 'm.year': 2008},
#  {'m.title': 'Inkheart', 'm.year': 2008},
#  {'m.title': 'Outlander', 'm.year': 2008},
#  {'m.title': 'Good, the Bad, the Weird, The (Joheunnom nabbeunnom isanghannom)',
#   'm.year': 2008},
#  {'m.title': 'Far Cry', 'm.year': 2008},
#  {'m.title': 'Were the World Mine', 'm.year': 2008},
#  {'m.title': 'Brothers Bloom, The', 'm.year': 2008},
#  {'m.title': 'Librarian, The: The Curse of the Judas Chalice', 'm.year': 2008},
#  {'m.title': 'Dragon Hunters (Chasseurs de dragons)', 'm.year': 2008},
#  {'m.title': 'North Face (Nordwand)', 'm.year': 2008},
#  {'m.title': '24: Redemption', 'm.year': 2008},
#  {'m.title': 'BURN-E', 'm.year': 2008},
#  {'m.title': 'The Scorpion King: Rise of a Warrior', 'm.year': 2008},
#  {'m.title': 'Road, The', 'm.year': 2009},
#  {'m.title': 'Pink Panther 2, The', 'm.year': 2009},
#  {'m.title': 'Dragonball Evolution', 'm.year': 2009},
#  {'m.title': 'Star Trek', 'm.year': 2009},
#  {'m.title': 'Fanboys', 'm.year': 2009},
#  {'m.title': 'Terminator Salvation', 'm.year': 2009},
#  {'m.title': 'Up', 'm.year': 2009},
#  {'m.title': 'Dead Snow (Død snø)', 'm.year': 2009},
#  {'m.title': 'Land of the Lost', 'm.year': 2009},
#  {'m.title': 'Year One', 'm.year': 2009},
#  {'m.title': 'Transformers: Revenge of the Fallen', 'm.year': 2009},
#  {'m.title': 'Ice Age: Dawn of the Dinosaurs', 'm.year': 2009},
#  {'m.title': 'Watchmen: Tales of the Black Freighter', 'm.year': 2009},
#  {'m.title': 'Harry Potter and the Half-Blood Prince', 'm.year': 2009},
#  {'m.title': 'Aliens in the Attic', 'm.year': 2009},
#  {'m.title': 'Race to Witch Mountain', 'm.year': 2009},
#  {'m.title': 'G.I. Joe: The Rise of Cobra', 'm.year': 2009},
#  {'m.title': 'G-Force', 'm.year': 2009},
#  {'m.title': '9', 'm.year': 2009},
#  {'m.title': 'Where the Wild Things Are', 'm.year': 2009},
#  {'m.title': "Cirque du Freak: The Vampire's Assistant", 'm.year': 2009},
#  {'m.title': 'Fantastic Mr. Fox', 'm.year': 2009},
#  {'m.title': 'Battlestar Galactica: The Plan', 'm.year': 2009},
#  {'m.title': 'Planet 51', 'm.year': 2009},
#  {'m.title': 'Avatar', 'm.year': 2009},
#  {'m.title': 'Agora', 'm.year': 2009},
#  {'m.title': 'Bunny and the Bull', 'm.year': 2009},
#  {'m.title': 'Summer Wars (Samâ wôzu)', 'm.year': 2009},
#  {'m.title': 'One Piece Film: Strong World', 'm.year': 2009},
#  {'m.title': 'Wonder Woman', 'm.year': 2009},
#  {'m.title': 'Book of Eli, The', 'm.year': 2010},
#  {'m.title': 'Percy Jackson & the Olympians: The Lightning Thief',
#   'm.year': 2010},
#  {'m.title': 'Alice in Wonderland', 'm.year': 2010},
#  {'m.title': 'How to Train Your Dragon', 'm.year': 2010},
#  {'m.title': 'Clash of the Titans', 'm.year': 2010},
#  {'m.title': 'Losers, The', 'm.year': 2010},
#  {'m.title': 'Iron Man 2', 'm.year': 2010},
#  {'m.title': 'Robin Hood', 'm.year': 2010},
#  {'m.title': 'Prince of Persia: The Sands of Time', 'm.year': 2010},
#  {'m.title': 'Toy Story 3', 'm.year': 2010},
#  {'m.title': 'Shrek Forever After (a.k.a. Shrek: The Final Chapter)',
#   'm.year': 2010},
#  {'m.title': 'Last Airbender, The', 'm.year': 2010},
#  {'m.title': "Sorcerer's Apprentice, The", 'm.year': 2010},
#  {'m.title': 'Expendables, The', 'm.year': 2010},
#  {'m.title': 'Centurion', 'm.year': 2010},
#  {'m.title': 'Machete', 'm.year': 2010},
#  {'m.title': "Legend of the Guardians: The Owls of Ga'Hoole", 'm.year': 2010},
#  {'m.title': 'Secretariat', 'm.year': 2010},
#  {'m.title': 'Rubber', 'm.year': 2010},
#  {'m.title': 'Black Death', 'm.year': 2010},
#  {'m.title': '127 Hours', 'm.year': 2010},
#  {'m.title': 'Harry Potter and the Deathly Hallows: Part 1', 'm.year': 2010},
#  {'m.title': 'Chronicles of Narnia: The Voyage of the Dawn Treader, The',
#   'm.year': 2010},
#  {'m.title': 'Tron: Legacy', 'm.year': 2010},
#  {'m.title': "Gulliver's Travels", 'm.year': 2010},
#  {'m.title': 'Disappearance of Haruhi Suzumiya, The (Suzumiya Haruhi no shôshitsu)',
#   'm.year': 2010},
#  {'m.title': 'The Pacific', 'm.year': 2010},
#  {'m.title': 'Season of the Witch', 'm.year': 2011},
#  {'m.title': 'All-Star Superman', 'm.year': 2011},
#  {'m.title': 'Gnomeo & Juliet', 'm.year': 2011},
#  {'m.title': 'Paul', 'm.year': 2011},
#  {'m.title': 'Rango', 'm.year': 2011},
#  {'m.title': 'Eagle, The', 'm.year': 2011},
#  {'m.title': 'Mars Needs Moms', 'm.year': 2011},
#  {'m.title': 'Hobo with a Shotgun', 'm.year': 2011},
#  {'m.title': 'Hanna', 'm.year': 2011},
#  {'m.title': 'Rio', 'm.year': 2011},
#  {'m.title': 'Thor', 'm.year': 2011},
#  {'m.title': 'African Cats', 'm.year': 2011},
#  {'m.title': 'Pirates of the Caribbean: On Stranger Tides', 'm.year': 2011},
#  {'m.title': 'Kung Fu Panda 2', 'm.year': 2011},
#  {'m.title': 'X-Men: First Class', 'm.year': 2011},
#  {'m.title': 'Green Lantern', 'm.year': 2011},
#  {'m.title': 'Transformers: Dark of the Moon', 'm.year': 2011},
#  {'m.title': 'Your Highness', 'm.year': 2011},
#  {'m.title': 'Cars 2', 'm.year': 2011},
#  {'m.title': 'Harry Potter and the Deathly Hallows: Part 2', 'm.year': 2011},
#  {'m.title': 'Captain America: The First Avenger', 'm.year': 2011},
#  {'m.title': 'Colombiana', 'm.year': 2011},
#  {'m.title': 'Inbetweeners Movie, The', 'm.year': 2011},
#  {'m.title': 'Three Musketeers, The', 'm.year': 2011},
#  {'m.title': 'Johnny English Reborn', 'm.year': 2011},
#  {'m.title': 'Puss in Boots', 'm.year': 2011},
#  {'m.title': 'Twilight Saga: Breaking Dawn - Part 1, The', 'm.year': 2011},
#  {'m.title': 'Sherlock Holmes: A Game of Shadows', 'm.year': 2011},
#  {'m.title': 'Mission: Impossible - Ghost Protocol', 'm.year': 2011},
#  {'m.title': 'Fullmetal Alchemist: The Sacred Star of Milos', 'm.year': 2011},
#  {'m.title': 'Avengers, The', 'm.year': 2012},
#  {'m.title': 'Expendables 2, The', 'm.year': 2012},
#  {'m.title': 'The Hunger Games', 'm.year': 2012},
#  {'m.title': 'Dark Knight Rises, The', 'm.year': 2012},
#  {'m.title': 'Bourne Legacy, The', 'm.year': 2012},
#  {'m.title': 'Red Tails', 'm.year': 2012},
#  {'m.title': 'Journey 2: The Mysterious Island', 'm.year': 2012},
#  {'m.title': 'John Carter', 'm.year': 2012},
#  {'m.title': 'Wrath of the Titans', 'm.year': 2012},
#  {'m.title': 'Mirror Mirror', 'm.year': 2012},
#  {'m.title': 'Snow White and the Huntsman', 'm.year': 2012},
#  {'m.title': 'Pirates! Band of Misfits, The', 'm.year': 2012},
#  {'m.title': "Madagascar 3: Europe's Most Wanted", 'm.year': 2012},
#  {'m.title': 'Brave', 'm.year': 2012},
#  {'m.title': 'Amazing Spider-Man, The', 'm.year': 2012},
#  {'m.title': 'Ice Age 4: Continental Drift', 'm.year': 2012},
#  {'m.title': 'Skyfall', 'm.year': 2012},
#  {'m.title': 'ParaNorman', 'm.year': 2012},
#  {'m.title': 'Kon-Tiki', 'm.year': 2012},
#  {'m.title': 'Life of Pi', 'm.year': 2012},
#  {'m.title': 'Rise of the Guardians', 'm.year': 2012},
#  {'m.title': 'Hobbit: An Unexpected Journey, The', 'm.year': 2012},
#  {'m.title': 'Maximum Conviction', 'm.year': 2012},
#  {'m.title': 'Dark Tide', 'm.year': 2012},
#  {'m.title': 'Mud', 'm.year': 2012},
#  {'m.title': 'One Piece Film Z', 'm.year': 2012},
#  {'m.title': 'Jack the Giant Slayer', 'm.year': 2013},
#  {'m.title': 'G.I. Joe: Retaliation', 'm.year': 2013},
#  {'m.title': 'Oz the Great and Powerful', 'm.year': 2013},
#  {'m.title': 'Croods, The', 'm.year': 2013},
#  {'m.title': 'Host, The', 'm.year': 2013},
#  {'m.title': 'Oblivion', 'm.year': 2013},
#  {'m.title': 'Star Trek Into Darkness', 'm.year': 2013},
#  {'m.title': 'Epic', 'm.year': 2013},
#  {'m.title': 'After Earth', 'm.year': 2013},
#  {'m.title': 'Man of Steel', 'm.year': 2013},
#  {'m.title': 'Monsters University', 'm.year': 2013},
#  {'m.title': 'Pacific Rim', 'm.year': 2013},
#  {'m.title': 'Lone Ranger, The', 'm.year': 2013},
#  {'m.title': 'Justice League: The Flashpoint Paradox', 'm.year': 2013},
#  {'m.title': 'Turbo', 'm.year': 2013},
#  {'m.title': 'Wolverine, The', 'm.year': 2013},
#  {'m.title': 'Percy Jackson: Sea of Monsters', 'm.year': 2013},
#  {'m.title': 'Planes', 'm.year': 2013},
#  {'m.title': 'Mortal Instruments: City of Bones, The', 'm.year': 2013},
#  {'m.title': 'Nebraska', 'm.year': 2013},
#  {'m.title': 'Crystal Fairy & the Magical Cactus and 2012', 'm.year': 2013},
#  {'m.title': 'Captain Phillips', 'm.year': 2013},
#  {'m.title': 'All Is Lost', 'm.year': 2013},
#  {'m.title': "Ender's Game", 'm.year': 2013},
#  {'m.title': 'Thor: The Dark World', 'm.year': 2013},
#  {'m.title': 'The Hunger Games: Catching Fire', 'm.year': 2013},
#  {'m.title': 'Hobbit: The Desolation of Smaug, The', 'm.year': 2013},
#  {'m.title': '47 Ronin', 'm.year': 2013},
#  {'m.title': 'Frozen', 'm.year': 2013},
#  {'m.title': 'Secret Life of Walter Mitty, The', 'm.year': 2013},
#  {'m.title': 'Other Shore, The', 'm.year': 2013},
#  {'m.title': 'Knights of Badassdom', 'm.year': 2013},
#  {'m.title': 'Centenarian Who Climbed Out the Window and Vanished, The (Hundraåringen som klev ut genom fönstret och försvann)',
#   'm.year': 2013},
#  {'m.title': 'Divergent', 'm.year': 2014},
#  {'m.title': 'The Lego Movie', 'm.year': 2014},
#  {'m.title': 'Mr. Peabody & Sherman', 'm.year': 2014},
#  {'m.title': 'Captain America: The Winter Soldier', 'm.year': 2014},
#  {'m.title': 'Noah', 'm.year': 2014},
#  {'m.title': 'Muppets Most Wanted', 'm.year': 2014},
#  {'m.title': 'Rio 2', 'm.year': 2014},
#  {'m.title': 'X-Men: Days of Future Past', 'm.year': 2014},
#  {'m.title': 'Godzilla', 'm.year': 2014},
#  {'m.title': 'Maleficent', 'm.year': 2014},
#  {'m.title': 'How to Train Your Dragon 2', 'm.year': 2014},
#  {'m.title': 'Transformers: Age of Extinction', 'm.year': 2014},
#  {'m.title': 'Planes: Fire & Rescue', 'm.year': 2014},
#  {'m.title': 'Guardians of the Galaxy', 'm.year': 2014},
#  {'m.title': 'The Expendables 3', 'm.year': 2014},
#  {'m.title': 'Hercules', 'm.year': 2014},
#  {'m.title': 'Teenage Mutant Ninja Turtles', 'm.year': 2014},
#  {'m.title': 'Boxtrolls, The', 'm.year': 2014},
#  {'m.title': 'The Book of Life', 'm.year': 2014},
#  {'m.title': 'The Hunger Games: Mockingjay - Part 1', 'm.year': 2014},
#  {'m.title': 'Exodus: Gods and Kings', 'm.year': 2014},
#  {'m.title': 'Penguins of Madagascar', 'm.year': 2014},
#  {'m.title': 'The Hobbit: The Battle of the Five Armies', 'm.year': 2014},
#  {'m.title': 'Kingsman: The Secret Service', 'm.year': 2014},
#  {'m.title': 'Night at the Museum: Secret of the Tomb', 'm.year': 2014},
#  {'m.title': 'Seventh Son', 'm.year': 2014},
#  {'m.title': 'Robot Overlords', 'm.year': 2014},
#  {'m.title': 'Mission: Impossible - Rogue Nation', 'm.year': 2015},
#  {'m.title': 'Jupiter Ascending', 'm.year': 2015},
#  {'m.title': 'Jurassic World', 'm.year': 2015},
#  {'m.title': 'Terminator Genisys', 'm.year': 2015},
#  {'m.title': 'Mad Max: Fury Road', 'm.year': 2015},
#  {'m.title': 'Star Wars: Episode VII - The Force Awakens', 'm.year': 2015},
#  {'m.title': 'Avengers: Age of Ultron', 'm.year': 2015},
#  {'m.title': 'Ant-Man', 'm.year': 2015},
#  {'m.title': 'Fantastic Four', 'm.year': 2015},
#  {'m.title': 'Pan', 'm.year': 2015},
#  {'m.title': 'Home', 'm.year': 2015},
#  {'m.title': 'Last Knights', 'm.year': 2015},
#  {'m.title': 'Tomorrowland', 'm.year': 2015},
#  {'m.title': 'Sword of Vengeance', 'm.year': 2015},
#  {'m.title': 'The Martian', 'm.year': 2015},
#  {'m.title': 'Inside Out', 'm.year': 2015},
#  {'m.title': 'The Hunger Games: Mockingjay - Part 2', 'm.year': 2015},
#  {'m.title': 'The Last Witch Hunter', 'm.year': 2015},
#  {'m.title': 'Minions', 'm.year': 2015},
#  {'m.title': 'The Good Dinosaur', 'm.year': 2015},
#  {'m.title': 'Spectre', 'm.year': 2015},
#  {'m.title': 'Vacation', 'm.year': 2015},
#  {'m.title': 'The Man from U.N.C.L.E.', 'm.year': 2015},
#  {'m.title': 'The Walk', 'm.year': 2015},
#  {'m.title': 'The Revenant', 'm.year': 2015},
#  {'m.title': 'Everest', 'm.year': 2015},
#  {'m.title': 'Goosebumps', 'm.year': 2015},
#  {'m.title': 'Peanuts Movie, The', 'm.year': 2015},
#  {'m.title': 'The Boy and the Beast', 'm.year': 2015},
#  {'m.title': 'Warcraft', 'm.year': 2016},
#  {'m.title': 'Deadpool', 'm.year': 2016},
#  {'m.title': 'X-Men: Apocalypse', 'm.year': 2016},
#  {'m.title': 'Independence Day: Resurgence', 'm.year': 2016},
#  {'m.title': 'Star Trek 3', 'm.year': 2016},
#  {'m.title': 'Batman v Superman: Dawn of Justice', 'm.year': 2016},
#  {'m.title': 'The Jungle Book', 'm.year': 2016},
#  {'m.title': 'Kung Fu Panda 3', 'm.year': 2016},
#  {'m.title': 'Zootopia', 'm.year': 2016},
#  {'m.title': 'Ice Age: The Great Egg-Scapade', 'm.year': 2016},
#  {'m.title': "The Huntsman Winter's War", 'm.year': 2016},
#  {'m.title': 'Finding Dory', 'm.year': 2016},
#  {'m.title': 'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   'm.year': 2016},
#  {'m.title': 'The Legend of Tarzan', 'm.year': 2016},
#  {'m.title': 'Sharknado 4: The 4th Awakens', 'm.year': 2016},
#  {'m.title': 'Mohenjo Daro', 'm.year': 2016},
#  {'m.title': 'Shin Godzilla', 'm.year': 2016}]

# %% [markdown]
# ## Recall@K Checking

# %%
from langchain.vectorstores import FAISS
from langchain.schema import Document
from langchain.docstore import InMemoryDocstore

# 1. Prepare documents
documents = [Document(page_content=text) for text in triplet_texts]

# 2. Precompute embeddings using model.encode()
embeddings = model.encode([doc.page_content for doc in documents], normalize_embeddings=True)

# 3. Build FAISS manually
import faiss
import numpy as np

dimension = embeddings.shape[1]  # Example: 384
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings).astype('float32'))

# 4. Create docstore
docstore = InMemoryDocstore({str(i): documents[i] for i in range(len(documents))})
index_to_docstore_id = {i: str(i) for i in range(len(documents))}

# 5. Final FAISS vectorstore
vectorstore = FAISS(
    embedding_function=model.encode,
    index=index,
    docstore=docstore,
    index_to_docstore_id=index_to_docstore_id
)

# 6. Create retriever
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
# Ground truth queries and expected answer substrings
ground_truth = [
    {
        "query": "Find adventure movies released after 2000",
        "expected": ["Adventure"]   # Look for word 'Adventure' in the answer triplets
    },
    {
        "query": "Who directed Jurassic Park?",
        "expected": ["Steven Spielberg directed Jurassic Park"]
    },
    {
        "query": "Find movies acted by Tim Allen",
        "expected": ["Tim Allen acted in"]
    },
    {
        "query": "Movies produced in USA",
        "expected": ["was produced in USA"]
    },
    {
        "query": "Find movies rated greater than 4 by any user",
        "expected": ["rated", "4.0"]
    }
]

# %%
def evaluate_recall_at_k(ground_truth, retriever, model, k=5):
    total = len(ground_truth)
    hits = 0

    for example in ground_truth:
        query = example["query"]
        expected_answers = example["expected"]

        # Use retriever properly in new LangChain
        results = retriever.get_relevant_documents(query)
        retrieved_sentences = [doc.page_content for doc in results]

        # Check if any expected answer is present
        found = False
        for expected in expected_answers:
            for sentence in retrieved_sentences[:k]:  # manually take top-k
                if expected.lower() in sentence.lower():
                    found = True
                    break
            if found:
                break

        if found:
            hits += 1

    recall_at_k = hits / total
    print(f"✅ Recall@{k}: {recall_at_k:.2f} ({hits}/{total} queries matched)")
    return recall_at_k

# %%
evaluate_recall_at_k(
    ground_truth=ground_truth,
    retriever=retriever,    # correct retriever object
    model=model,
    k=5
)
# Out:
# ✅ Recall@5: 0.80 (4/5 queries matched)
# 0.8

# %% [markdown]
# # FINAL APPROACH

# %%
kg.query("CALL db.labels()")
# Out:
# [{'label': 'Movie'},
#  {'label': 'Genre'},
#  {'label': 'User'},
#  {'label': 'Actor'},
#  {'label': 'Director'},
#  {'label': 'Person'},
#  {'label': '_Bloom_Perspective_'},
#  {'label': '_Bloom_Scene_'}]

# %%
kg.query("CALL db.relationshipTypes()")
# Out:
# [{'relationshipType': 'IN_GENRE'},
#  {'relationshipType': 'RATED'},
#  {'relationshipType': 'ACTED_IN'},
#  {'relationshipType': 'DIRECTED'},
#  {'relationshipType': '_Bloom_HAS_SCENE_'}]

# %%
kg.query("CALL db.propertyKeys()")
# Out:
# [{'propertyKey': 'movieId'},
#  {'propertyKey': 'name'},
#  {'propertyKey': 'userId'},
#  {'propertyKey': 'imdbId'},
#  {'propertyKey': 'title'},
#  {'propertyKey': 'rating'},
#  {'propertyKey': 'timestamp'},
#  {'propertyKey': 'tmdbId'},
#  {'propertyKey': 'year'},
#  {'propertyKey': 'countries'},
#  {'propertyKey': 'languages'},
#  {'propertyKey': 'plot'},
#  {'propertyKey': 'imdbRating'},
#  {'propertyKey': 'imdbVotes'},
#  {'propertyKey': 'released'},
#  {'propertyKey': 'runtime'},
#  {'propertyKey': 'poster'},
#  {'propertyKey': 'revenue'},
#  {'propertyKey': 'budget'},
#  {'propertyKey': 'tagline'},
#  {'propertyKey': 'role'},
#  {'propertyKey': 'born'},
#  {'propertyKey': 'died'},
#  {'propertyKey': 'bornIn'},
#  {'propertyKey': 'bio'},
#  {'propertyKey': 'url'},
#  {'propertyKey': 'plotEmbedding'},
#  {'propertyKey': 'posterEmbedding'},
#  {'propertyKey': 'id'},
#  {'propertyKey': 'data'},
#  {'propertyKey': 'nodes'},
#  {'propertyKey': 'relationships'},
#  {'propertyKey': 'style'},
#  {'propertyKey': 'visualisation'},
#  {'propertyKey': 'version'},
#  {'propertyKey': 'roles'},
#  {'propertyKey': 'numOfNodes'},
#  {'propertyKey': 'numOfRels'},
#  {'propertyKey': 'createdBy'},
#  {'propertyKey': 'createdAt'},
#  {'propertyKey': 'lastModified'},
#  {'propertyKey': 'filters'},
#  {'propertyKey': 'ranges'},
#  {'propertyKey': 'gds'}]

# %%
kg.query("""
MATCH (a:Actor)-[r:ACTED_IN]->(m:Movie)
RETURN a.name AS actor, m.title AS movie
LIMIT 10
""")
# Out:
# [{'actor': 'Jim Varney', 'movie': 'Toy Story'},
#  {'actor': 'Tim Allen', 'movie': 'Toy Story'},
#  {'actor': 'Tom Hanks', 'movie': 'Toy Story'},
#  {'actor': 'Don Rickles', 'movie': 'Toy Story'},
#  {'actor': 'Robin Williams', 'movie': 'Jumanji'},
#  {'actor': 'Bradley Pierce', 'movie': 'Jumanji'},
#  {'actor': 'Kirsten Dunst', 'movie': 'Jumanji'},
#  {'actor': 'Jonathan Hyde', 'movie': 'Jumanji'},
#  {'actor': 'Walter Matthau', 'movie': 'Grumpier Old Men'},
#  {'actor': 'Ann-Margret', 'movie': 'Grumpier Old Men'}]

# %%
kg.query("""
MATCH (m:Movie)-[r:IN_GENRE]->(g:Genre)
RETURN m.title AS movie, g.name AS genre
LIMIT 10
""")
# Out:
# [{'movie': 'Boxtrolls, The', 'genre': 'Adventure'},
#  {'movie': 'The Book of Life', 'genre': 'Adventure'},
#  {'movie': 'Teenage Mutant Ninja Turtles', 'genre': 'Adventure'},
#  {'movie': 'Jupiter Ascending', 'genre': 'Adventure'},
#  {'movie': 'Planes: Fire & Rescue', 'genre': 'Adventure'},
#  {'movie': 'Transformers: Age of Extinction', 'genre': 'Adventure'},
#  {'movie': 'Hercules', 'genre': 'Adventure'},
#  {'movie': 'The Expendables 3', 'genre': 'Adventure'},
#  {'movie': 'Guardians of the Galaxy', 'genre': 'Adventure'},
#  {'movie': 'Maleficent', 'genre': 'Adventure'}]

# %%
kg.query("""
MATCH (u:User)-[r:RATED]->(m:Movie)
RETURN u.userId AS user, m.title AS movie, r.rating AS rating
LIMIT 10
""")
# Out:
# [{'user': '1', 'movie': 'Antz', 'rating': 2.0},
#  {'user': '1', 'movie': 'Fly, The', 'rating': 2.5},
#  {'user': '1', 'movie': 'Time Bandits', 'rating': 1.0},
#  {'user': '1', 'movie': 'Blazing Saddles', 'rating': 3.0},
#  {'user': '1', 'movie': 'French Connection, The', 'rating': 4.0},
#  {'user': '1', 'movie': 'Tron', 'rating': 4.0},
#  {'user': '1', 'movie': 'Gods Must Be Crazy, The', 'rating': 3.0},
#  {'user': '1', 'movie': 'Willow', 'rating': 2.0},
#  {'user': '1', 'movie': 'Sleepers', 'rating': 3.0},
#  {'user': '1', 'movie': 'Escape from New York', 'rating': 2.0}]

# %%
kg.query("""
MATCH (d:Director)-[r:DIRECTED]->(m:Movie)
RETURN d.name AS director, m.title AS movie
LIMIT 10
""")
# Out:
# [{'director': 'Harold Lloyd', 'movie': 'Kid Brother, The'},
#  {'director': 'Paul Wegener',
#   'movie': 'Golem, The (Golem, wie er in die Welt kam, Der)'},
#  {'director': 'Buster Keaton', 'movie': 'Cameraman, The'},
#  {'director': 'Buster Keaton', 'movie': 'Boat, The'},
#  {'director': 'Buster Keaton', 'movie': 'Play House, The'},
#  {'director': 'Buster Keaton', 'movie': 'Haunted House, The'},
#  {'director': 'Buster Keaton', 'movie': 'College'},
#  {'director': 'Buster Keaton', 'movie': 'Steamboat Bill, Jr.'},
#  {'director': 'Buster Keaton', 'movie': 'Cops'},
#  {'director': 'Buster Keaton', 'movie': 'Navigator, The'}]

# %% [markdown]
# #### Pull movies, genres, actors, directors, users

# %%
# 1. Movies Basic Info
movies = kg.query("""
MATCH (m:Movie)
RETURN m.title AS title, m.year AS year, m.runtime AS runtime, m.budget AS budget,
       m.revenue AS revenue, m.imdbRating AS imdbRating, m.countries AS countries,
       m.languages AS languages
""")

# 2. Movies and Genres
movie_genres = kg.query("""
MATCH (m:Movie)-[:IN_GENRE]->(g:Genre)
RETURN m.title AS movie, g.name AS genre
""")

# 3. Actors and Movies
acted_in = kg.query("""
MATCH (a:Actor)-[:ACTED_IN]->(m:Movie)
RETURN a.name AS actor, m.title AS movie
""")

# 4. Directors and Movies
directed = kg.query("""
MATCH (d:Director)-[:DIRECTED]->(m:Movie)
RETURN d.name AS director, m.title AS movie
""")

# 5. Users and Ratings
user_ratings = kg.query("""
MATCH (u:User)-[r:RATED]->(m:Movie)
RETURN u.userId AS userId, m.title AS movie, r.rating AS rating
""")

print("All data retrieved!")
# Out:
# All data retrieved!

# %% [markdown]
# ## Build Triplets from the Retrieved Data

# %%
triplets = []

# 1. Movie properties
for row in movies:
    title = row['title']
    if title is None:
        continue
    if row['year'] is not None:
        triplets.append((title, "was released in year", str(int(row['year']))))
    if row['runtime'] is not None:
        triplets.append((title, "has a runtime of", f"{int(row['runtime'])} minutes"))
    if row['budget'] is not None and row['budget'] > 0:
        triplets.append((title, "had a budget of", f"${int(row['budget'])}"))
    if row['revenue'] is not None and row['revenue'] > 0:
        triplets.append((title, "earned revenue of", f"${int(row['revenue'])}"))
    if row['imdbRating'] is not None:
        triplets.append((title, "has IMDb rating", str(row['imdbRating'])))
    if row['countries'] is not None:
        for country in row['countries']:
            triplets.append((title, "was produced in", country))
    if row['languages'] is not None:
        for language in row['languages']:
            triplets.append((title, "is in language", language))

# 2. Genres
for row in movie_genres:
    movie = row['movie']
    genre = row['genre']
    if movie and genre:
        triplets.append((movie, "is in genre", genre))

# 3. Actors
for row in acted_in:
    actor = row['actor']
    movie = row['movie']
    if actor and movie:
        triplets.append((actor, "acted in", movie))

# 4. Directors
for row in directed:
    director = row['director']
    movie = row['movie']
    if director and movie:
        triplets.append((director, "directed", movie))

# 5. User Ratings
for row in user_ratings:
    user = row['userId']
    movie = row['movie']
    rating = row['rating']
    if user and movie and rating is not None:
        triplets.append((f"User {user}", f"rated {movie}", str(rating)))

# Confirm
print(f"Total Triplets Created: {len(triplets)}")
for t in triplets[:10]:
    print(t)
# Out:
# Total Triplets Created: 229894
# ('Toy Story', 'was released in year', '1995')
# ('Toy Story', 'has a runtime of', '81 minutes')
# ('Toy Story', 'had a budget of', '$30000000')
# ('Toy Story', 'earned revenue of', '$373554033')
# ('Toy Story', 'has IMDb rating', '8.3')
# ('Toy Story', 'was produced in', 'USA')
# ('Toy Story', 'is in language', 'English')
# ('Jumanji', 'was released in year', '1995')
# ('Jumanji', 'has a runtime of', '104 minutes')
# ('Jumanji', 'had a budget of', '$65000000')

# %% [markdown]
# #### Turn these triplets into plain English sentences

# %%
triplet_sentences = []
for subj, rel, obj in triplets:
    sentence = f"{subj} {rel} {obj}"
    triplet_sentences.append(sentence)

print(f"Total Sentences: {len(triplet_sentences)}")
for s in triplet_sentences[:10]:
    print(s)
# Out:
# Total Sentences: 229894
# Toy Story was released in year 1995
# Toy Story has a runtime of 81 minutes
# Toy Story had a budget of $30000000
# Toy Story earned revenue of $373554033
# Toy Story has IMDb rating 8.3
# Toy Story was produced in USA
# Toy Story is in language English
# Jumanji was released in year 1995
# Jumanji has a runtime of 104 minutes
# Jumanji had a budget of $65000000

# %% [markdown]
# ## Encode Sentences into Embeddings

# %%
from sentence_transformers import SentenceTransformer

# Load local sentence embedding model
encoder_model = SentenceTransformer('all-MiniLM-L6-v2')

# Encode all sentences
triplet_embeddings = encoder_model.encode(triplet_sentences, batch_size=64, show_progress_bar=True)

print(f"Shape of embeddings: {triplet_embeddings.shape}")
# Out:
# Batches: 100%|██████████| 3593/3593 [01:08<00:00, 52.76it/s]
# Shape of embeddings: (229894, 384)

# %% [markdown]
# ## Create the FAISS index

# %%
import faiss
import numpy as np

dimension = triplet_embeddings.shape[1]  # 384
index = faiss.IndexFlatL2(dimension)
index.add(np.array(triplet_embeddings).astype('float32'))

print(f"FAISS Index Created. Total vectors: {index.ntotal}")
# Out:
# FAISS Index Created. Total vectors: 229894

# %% [markdown]
# ## Build a simple Retriever function to search inside FAISS

# %%
# Define retrieval function
def retrieve_triplets(query, model, index, sentences, top_k=20):
    query_embedding = model.encode([query])
    D, I = index.search(np.array(query_embedding).astype('float32'), top_k)
    results = []
    for idx, dist in zip(I[0], D[0]):
        if idx < len(sentences):
            results.append((sentences[idx], dist))
    return results

# %% [markdown]
# #### Updated retrieval function with re-ranking

# %%
from sentence_transformers import util  # Make sure you import this!

model = SentenceTransformer('all-MiniLM-L6-v2')

def retrieve_triplets(query, model, index, sentences, top_k=20):
    # Step 1: Encode the query
    query_embedding = model.encode([query])

    # Step 2: Search FAISS index
    D, I = index.search(np.array(query_embedding).astype('float32'), top_k)

    # Step 3: Collect initial results
    initial_results = []
    for idx, dist in zip(I[0], D[0]):
        if idx < len(sentences):
            initial_results.append((sentences[idx], dist))
    
    # Step 4: Re-rank based on cosine similarity (optional but improves quality)
    if initial_results:
        triplet_texts = [r[0] for r in initial_results]
        triplet_embeddings = model.encode(triplet_texts)
        similarities = util.cos_sim(query_embedding, triplet_embeddings)[0]  # shape: (top_k,)
        
        # Pair triplets with similarity and sort
        triplet_similarity_pairs = list(zip(triplet_texts, similarities.tolist()))
        triplet_similarity_pairs.sort(key=lambda x: x[1], reverse=True)  # Higher similarity first
        
        reranked_results = [(t, s) for t, s in triplet_similarity_pairs]
        return reranked_results

    return initial_results

# %% [markdown]
# #### test the retriever

# %%
# Sample queries to test
sample_queries = [
    "Movies released after 2010",
    "Movies directed by Steven Spielberg",
    "Movies in English language",
    "Movies acted by Tom Hanks",
    "Adventure movies produced in USA",
    "Movies rated 5.0 by User 1"
]

# Test retrieval
for query in sample_queries:
    print(f"\nQuery: {query}")
    results = retrieve_triplets(query, model, index, triplet_sentences, top_k=10)
    for sentence, dist in results:
        print(f" - {sentence} (Distance: {dist:.4f})")
# Out:
# Query: Movies released after 2010
#  - Another Year was released in year 2010 (Distance: 0.7014)
#  - 2012 was released in year 2009 (Distance: 0.6826)
#  - Other Guys, The was released in year 2010 (Distance: 0.6793)
#  - Role/Play was released in year 2010 (Distance: 0.6672)
#  - Next Three Days, The was released in year 2010 (Distance: 0.6546)
#  - 10 Years was released in year 2011 (Distance: 0.6462)
#  - Tourist, The was released in year 2010 (Distance: 0.6450)
#  - Trip, The was released in year 2010 (Distance: 0.6315)
#  - American, The was released in year 2010 (Distance: 0.6252)
#  - Losers, The was released in year 2010 (Distance: 0.6178)
#
# Query: Movies directed by Steven Spielberg
#  - Steven Spielberg directed 1941 (Distance: 0.8560)
#  - Steven Spielberg directed Munich (Distance: 0.7906)
#  - Steven Spielberg directed Always (Distance: 0.7799)
#  - Steven Spielberg directed Duel (Distance: 0.7725)
#  - Steven Spielberg directed Jurassic Park (Distance: 0.7662)
#  - Steven Spielberg directed Lincoln (Distance: 0.7614)
#  - Steven Spielberg directed Jaws (Distance: 0.7606)
#  - Steven Spielberg directed War of the Worlds (Distance: 0.7572)
#  - Steven Spielberg directed Terminal, The (Distance: 0.7503)
#  - Steven Spielberg directed Schindler's List (Distance: 0.7455)
#
# Query: Movies in English language
#  - American Movie is in language English (Distance: 0.7894)
#  - Date Movie is in language English (Distance: 0.7840)
#  - Left Behind: The Movie is in language English (Distance: 0.7616)
#  - Inbetweeners Movie, The is in language English (Distance: 0.7587)
#  - Hello Ladies: The Movie is in language English (Distance: 0.7582)
#  - This Film Is Not Yet Rated is in language English (Distance: 0.7490)
#  - Tales from the Darkside: The Movie is in language English (Distance: 0.7453)
#  - Epic Movie is in language English (Distance: 0.7376)
#  - Scary Movie is in language English (Distance: 0.7364)
#  - Jackass: The Movie is in language English (Distance: 0.7362)
#
# Query: Movies acted by Tom Hanks
#  - Tom Hanks acted in Philadelphia (Distance: 0.8423)
#  - Tom Hanks acted in Forrest Gump (Distance: 0.8292)
#  - Tom Hanks acted in Volunteers (Distance: 0.8095)
#  - Tom Hanks acted in Big (Distance: 0.8091)
#  - Tom Hanks acted in Da Vinci Code, The (Distance: 0.8059)
#  - Tom Hanks acted in Terminal, The (Distance: 0.8052)
#  - Tom Hanks acted in Toy Story (Distance: 0.7920)
#  - Tom Hanks acted in Punchline (Distance: 0.7755)
#  - Tom Hanks acted in League of Their Own, A (Distance: 0.7701)
#  - Tom Hanks acted in Apollo 13 (Distance: 0.7555)
#
# Query: Adventure movies produced in USA
#  - Adventureland was produced in USA (Distance: 0.7463)
#  - Remo Williams: The Adventure Begins was produced in USA (Distance: 0.7098)
#  - Poseidon Adventure, The was produced in USA (Distance: 0.6981)
#  - American Movie was produced in USA (Distance: 0.6836)
#  - Wild America is in genre Adventure (Distance: 0.6789)
#  - Pee-wee's Big Adventure was produced in USA (Distance: 0.6725)
#  - Beyond the Poseidon Adventure was produced in USA (Distance: 0.6502)
#  - Pride and Prejudice and Zombies was produced in USA (Distance: 0.6480)
#  - Awfully Big Adventure, An was produced in UK (Distance: 0.6407)
#  - Free Willy 2: The Adventure Home was produced in  USA (Distance: 0.6390)
#
# Query: Movies rated 5.0 by User 1
#  - User 15 rated Movie 43 0.5 (Distance: 0.7980)
#  - User 102 rated American Movie 5.0 (Distance: 0.7973)
#  - User 304 rated This Film Is Not Yet Rated 5.0 (Distance: 0.7928)
#  - User 509 rated American Movie 5.0 (Distance: 0.7881)
#  - User 33 rated American Movie 5.0 (Distance: 0.7832)
#  - User 15 rated This Film Is Not Yet Rated 4.0 (Distance: 0.7627)
#  - User 547 rated This Film Is Not Yet Rated 3.5 (Distance: 0.7557)
#  - User 353 rated Date Movie 2.0 (Distance: 0.7480)
#  - User 460 rated American Movie 3.5 (Distance: 0.7470)
#  - User 520 rated Not Another Teen Movie 1.0 (Distance: 0.7432)

# %%
# Sample queries to test
sample_queries = [
    "Movies released after 2010",
    "Movies directed by Steven Spielberg",
    "Movies in English language",
    "Movies acted by Tom Hanks",
    "Adventure movies produced in USA",
    "Movies rated 5.0 by User 1"
]

# Test retrieval
for query in sample_queries:
    print(f"\nQuery: {query}")
    results = retrieve_triplets(query, model, index, triplet_sentences, top_k=5)
    for sentence, dist in results:
        print(f" - {sentence} (Distance: {dist:.4f})")
# Out:
# Query: Movies released after 2010
#  - Another Year was released in year 2010 (Distance: 0.7014)
#  - 2012 was released in year 2009 (Distance: 0.6826)
#  - Other Guys, The was released in year 2010 (Distance: 0.6793)
#  - Role/Play was released in year 2010 (Distance: 0.6672)
#  - Next Three Days, The was released in year 2010 (Distance: 0.6546)
#
# Query: Movies directed by Steven Spielberg
#  - Steven Spielberg directed 1941 (Distance: 0.8560)
#  - Steven Spielberg directed Munich (Distance: 0.7906)
#  - Steven Spielberg directed Always (Distance: 0.7799)
#  - Steven Spielberg directed Duel (Distance: 0.7725)
#  - Steven Spielberg directed Jurassic Park (Distance: 0.7662)
#
# Query: Movies in English language
#  - American Movie is in language English (Distance: 0.7894)
#  - Date Movie is in language English (Distance: 0.7840)
#  - Left Behind: The Movie is in language English (Distance: 0.7616)
#  - Inbetweeners Movie, The is in language English (Distance: 0.7587)
#  - Hello Ladies: The Movie is in language English (Distance: 0.7582)
#
# Query: Movies acted by Tom Hanks
#  - Tom Hanks acted in Philadelphia (Distance: 0.8423)
#  - Tom Hanks acted in Forrest Gump (Distance: 0.8292)
#  - Tom Hanks acted in Volunteers (Distance: 0.8095)
#  - Tom Hanks acted in Big (Distance: 0.8091)
#  - Tom Hanks acted in Da Vinci Code, The (Distance: 0.8059)
#
# Query: Adventure movies produced in USA
#  - Adventureland was produced in USA (Distance: 0.7463)
#  - Remo Williams: The Adventure Begins was produced in USA (Distance: 0.7098)
#  - Poseidon Adventure, The was produced in USA (Distance: 0.6981)
#  - American Movie was produced in USA (Distance: 0.6836)
#  - Wild America is in genre Adventure (Distance: 0.6789)
#
# Query: Movies rated 5.0 by User 1
#  - User 15 rated Movie 43 0.5 (Distance: 0.7980)
#  - User 102 rated American Movie 5.0 (Distance: 0.7973)
#  - User 304 rated This Film Is Not Yet Rated 5.0 (Distance: 0.7928)
#  - User 509 rated American Movie 5.0 (Distance: 0.7881)
#  - User 33 rated American Movie 5.0 (Distance: 0.7832)

# %% [markdown]
# #### RAG CHAIN

# %% [markdown]
# test new method

# %%
from langchain_groq import ChatGroq
from langchain.vectorstores import FAISS
from langchain.docstore import InMemoryDocstore
from langchain.schema import Document
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

import faiss
import numpy as np

# 1. Setup LLM
llm = ChatGroq(
    temperature=0,
    model_name="llama3-70b-8192",
    groq_api_key="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"
)

# 2. Build FAISS
dimension = triplet_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(triplet_embeddings).astype('float32'))

index_to_docstore_id = {i: str(i) for i in range(len(triplet_sentences))}
docstore = InMemoryDocstore({str(i): Document(page_content=triplet_sentences[i]) for i in range(len(triplet_sentences))})
vectorstore = FAISS(embedding_function=model.encode, index=index, docstore=docstore, index_to_docstore_id=index_to_docstore_id)

retriever = vectorstore.as_retriever(search_kwargs={"k": 500})

# 3. Build Prompt
prompt_template = PromptTemplate.from_template("""
You are a movie recommendation expert.

Facts:
{context}

Question:
{question}

Answer:
""")

# 4. Build RetrievalQA Chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="stuff",
    chain_type_kwargs={"prompt": prompt_template}
)
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
# 5. Query Example
query = "List adventure movies released after 2000"
result = qa_chain.invoke({"query": query})
print("Answer:", result['result'])
# Out:
# Answer: Here is the list of adventure movies released after 2000:
#
# 1. Jurassic Park III (2001)
# 2. The Lord of the Rings: The Two Towers (2002)
# 3. The Lord of the Rings: The Return of the King (2003)
# 4. Pirates of the Caribbean: The Curse of the Black Pearl (2003)
# 5. Shrek 2 (2004)
# 6. The Incredibles (2004)
# 7. Batman Begins (2005)
# 8. Superman Returns (2006)
# 9. Pirates of the Caribbean: Dead Man's Chest (2006)
# 10. Casino Royale (2006)
# 11. The Bourne Ultimatum (2007)
# 12. National Treasure: Book of Secrets (2007)
# 13. Indiana Jones and the Kingdom of the Crystal Skull (2008)
# 14. The Dark Knight (2008)
# 15. Kung Fu Panda (2008)
# 16. Madagascar: Escape 2 Africa (2008)
# 17. Avatar (2009)
# 18. The A-Team (2010)
# 19. The Last Airbender (2010)
# 20. Pirates of the Caribbean: On Stranger Tides (2011)
# 21. The Adventures of Tintin (2011)
# 22. The Avengers (2012)
# 23. The Dark Knight Rises (2012)
# 24. The Hobbit: An Unexpected Journey (2012)
# 25. Iron Man 3 (2013)
# 26. The Hunger Games: Catching Fire (2013)
# 27. The Hobbit: The Desolation of Smaug (2013)
# 28. Guardians of the Galaxy (2014)
# 29. The Hunger Games: Mockingjay - Part 1 (2014)
# 30. Avengers: Age of Ultron (2015)
# 31. Jurassic World (2015)
# 32. The Hunger Games: Mockingjay - Part 2 (2015)
# 33. The Jungle Book (2016)
# 34. Captain America: Civil War (2016)
# 35. The Legend of Tarzan (2016)
# 36. Doctor Strange (2016)
# 37. Guardians of the Galaxy Vol. 2 (2017)
# 38. Spider-Man: Homecoming (2017)
# 39. Thor: Ragnarok (2017)
# 40. Black Panther (2018)
# 41. Avengers: Infinity War (2018)
# 42. Ant-Man and the Wasp (2018)
# 43. Captain Marvel (2019)
# 44. Avengers: Endgame (2019)
# 45. Spider-Man: Far From Home (2019)
#
# Note: This is not an exhaustive list, but it includes many popular adventure movies released after 2000.

# %%
result = kg.query("""
MATCH (m:Movie)-[:IN_GENRE]->(g:Genre)
WHERE g.name = "Adventure" AND m.year > 2000
RETURN m.title AS title, m.year AS year
ORDER BY m.year ASC
""")
result
# Out:
# [{'title': 'Spy Kids', 'year': 2001},
#  {'title': 'Joe Dirt', 'year': 2001},
#  {'title': 'Mummy Returns, The', 'year': 2001},
#  {'title': 'Shrek', 'year': 2001},
#  {'title': 'Atlantis: The Lost Empire', 'year': 2001},
#  {'title': 'Lara Croft: Tomb Raider', 'year': 2001},
#  {'title': 'A.I. Artificial Intelligence', 'year': 2001},
#  {'title': 'Final Fantasy: The Spirits Within', 'year': 2001},
#  {'title': 'Jurassic Park III', 'year': 2001},
#  {'title': 'Planet of the Apes', 'year': 2001},
#  {'title': 'Jay and Silent Bob Strike Back', 'year': 2001},
#  {'title': 'Musketeer, The', 'year': 2001},
#  {'title': 'Extreme Days', 'year': 2001},
#  {'title': 'Joy Ride', 'year': 2001},
#  {'title': 'Monsters, Inc.', 'year': 2001},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001},
#  {'title': 'Black Knight', 'year': 2001},
#  {'title': 'Baran', 'year': 2001},
#  {'title': 'Jimmy Neutron: Boy Genius', 'year': 2001},
#  {'title': 'Lord of the Rings: The Fellowship of the Ring, The', 'year': 2001},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)', 'year': 2001},
#  {'title': 'Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie)', 'year': 2001},
#  {'title': 'Suriyothai (a.k.a. Legend of Suriyothai, The)', 'year': 2001},
#  {'title': 'Samsara', 'year': 2001},
#  {'title': 'Musa the Warrior (Musa)', 'year': 2001},
#  {'title': 'Zenon: The Zequel', 'year': 2001},
#  {'title': 'Snow Dogs', 'year': 2002},
#  {'title': 'The Count of Monte Cristo', 'year': 2002},
#  {'title': 'Return to Never Land', 'year': 2002},
#  {'title': 'Time Machine, The', 'year': 2002},
#  {'title': 'Ice Age', 'year': 2002},
#  {'title': 'The Scorpion King', 'year': 2002},
#  {'title': 'Spider-Man', 'year': 2002},
#  {'title': 'Star Wars: Episode II - Attack of the Clones', 'year': 2002},
#  {'title': 'Spirit: Stallion of the Cimarron', 'year': 2002},
#  {'title': 'Scooby-Doo', 'year': 2002},
#  {'title': 'Lilo & Stitch', 'year': 2002},
#  {'title': 'Rabbit-Proof Fence', 'year': 2002},
#  {'title': 'Hey Arnold! The Movie', 'year': 2002},
#  {'title': 'Crocodile Hunter: Collision Course, The', 'year': 2002},
#  {'title': 'Reign of Fire', 'year': 2002},
#  {'title': 'K-19: The Widowmaker', 'year': 2002},
#  {'title': 'Spy Kids 2: The Island of Lost Dreams', 'year': 2002},
#  {'title': 'Adventures of Pluto Nash, The', 'year': 2002},
#  {'title': 'Blue Crush', 'year': 2002},
#  {'title': 'Four Feathers, The', 'year': 2002},
#  {'title': 'I Spy', 'year': 2002},
#  {'title': 'Harry Potter and the Chamber of Secrets', 'year': 2002},
#  {'title': 'Die Another Day', 'year': 2002},
#  {'title': 'Extreme Ops', 'year': 2002},
#  {'title': 'Treasure Planet', 'year': 2002},
#  {'title': 'Lord of the Rings: The Two Towers, The', 'year': 2002},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002},
#  {'title': 'Gerry', 'year': 2002},
#  {'title': 'In This World', 'year': 2002},
#  {'title': 'Interstate 60', 'year': 2002},
#  {'title': 'Hero (Ying xiong)', 'year': 2002},
#  {'title': 'Cat Returns, The (Neko no ongaeshi)', 'year': 2002},
#  {'title': 'Shanghai Knights', 'year': 2003},
#  {'title': 'Bulletproof Monk', 'year': 2003},
#  {'title': 'Holes', 'year': 2003},
#  {'title': 'X2: X-Men United', 'year': 2003},
#  {'title': 'Matrix Reloaded, The', 'year': 2003},
#  {'title': 'Finding Nemo', 'year': 2003},
#  {'title': "Charlie's Angels: Full Throttle", 'year': 2003},
#  {'title': 'Hulk', 'year': 2003},
#  {'title': 'Sinbad: Legend of the Seven Seas', 'year': 2003},
#  {'title': 'Terminator 3: Rise of the Machines', 'year': 2003},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003},
#  {'title': 'Lara Croft Tomb Raider: The Cradle of Life', 'year': 2003},
#  {'title': 'Spy Kids 3-D: Game Over', 'year': 2003},
#  {'title': 'Agent Cody Banks', 'year': 2003},
#  {'title': 'Once Upon a Time in Mexico', 'year': 2003},
#  {'title': 'Rundown, The', 'year': 2003},
#  {'title': 'Brother Bear', 'year': 2003},
#  {'title': 'Matrix Revolutions, The', 'year': 2003},
#  {'title': 'Master and Commander: The Far Side of the World', 'year': 2003},
#  {'title': 'Missing, The', 'year': 2003},
#  {'title': 'Timeline', 'year': 2003},
#  {'title': 'Last Samurai, The', 'year': 2003},
#  {'title': 'Lord of the Rings: The Return of the King, The', 'year': 2003},
#  {'title': 'Peter Pan', 'year': 2003},
#  {'title': 'Touching the Void', 'year': 2003},
#  {'title': 'Kaena: The Prophecy (Kaena: La prophétie)', 'year': 2003},
#  {'title': 'Tokyo Godfathers', 'year': 2003},
#  {'title': 'Warriors of Heaven and Earth (Tian di ying xiong)', 'year': 2003},
#  {'title': 'Interstella 5555: The 5tory of the 5ecret 5tar 5ystem',
#   'year': 2003},
#  {'title': 'Saints and Soldiers', 'year': 2003},
#  {'title': 'Snow Walker, The', 'year': 2003},
#  {'title': 'EuroTrip', 'year': 2004},
#  {'title': 'Hidalgo', 'year': 2004},
#  {'title': 'Scooby-Doo 2: Monsters Unleashed', 'year': 2004},
#  {'title': 'Hellboy', 'year': 2004},
#  {'title': 'New York Minute', 'year': 2004},
#  {'title': 'Van Helsing', 'year': 2004},
#  {'title': 'Troy', 'year': 2004},
#  {'title': 'Shrek 2', 'year': 2004},
#  {'title': 'Day After Tomorrow, The', 'year': 2004},
#  {'title': 'Harry Potter and the Prisoner of Azkaban', 'year': 2004},
#  {'title': 'Around the World in 80 Days', 'year': 2004},
#  {'title': 'Two Brothers (Deux frères)', 'year': 2004},
#  {'title': 'Spider-Man 2', 'year': 2004},
#  {'title': 'King Arthur', 'year': 2004},
#  {'title': 'I, Robot', 'year': 2004},
#  {'title': 'Harold and Kumar Go to White Castle', 'year': 2004},
#  {'title': 'Yu-Gi-Oh!', 'year': 2004},
#  {'title': 'Anacondas: The Hunt for the Blood Orchid', 'year': 2004},
#  {'title': 'Sky Captain and the World of Tomorrow', 'year': 2004},
#  {'title': 'Motorcycle Diaries, The (Diarios de motocicleta)', 'year': 2004},
#  {'title': 'Team America: World Police', 'year': 2004},
#  {'title': 'Incredibles, The', 'year': 2004},
#  {'title': 'Polar Express, The', 'year': 2004},
#  {'title': 'After the Sunset', 'year': 2004},
#  {'title': 'National Treasure', 'year': 2004},
#  {'title': 'SpongeBob SquarePants Movie, The', 'year': 2004},
#  {'title': 'Alexander', 'year': 2004},
#  {'title': "Lemony Snicket's A Series of Unfortunate Events", 'year': 2004},
#  {'title': 'Flight of the Phoenix', 'year': 2004},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004},
#  {'title': "Howl's Moving Castle (Hauru no ugoku shiro)", 'year': 2004},
#  {'title': 'Palindromes', 'year': 2004},
#  {'title': 'Mind Game', 'year': 2004},
#  {'title': 'G.O.R.A.', 'year': 2004},
#  {'title': 'Dead Leaves', 'year': 2004},
#  {'title': "'Hellboy': The Seeds of Creation", 'year': 2004},
#  {'title': 'Zenon: Z3', 'year': 2004},
#  {'title': 'Charlie and the Chocolate Factory', 'year': 2005},
#  {'title': 'Elektra', 'year': 2005},
#  {'title': 'Robots', 'year': 2005},
#  {'title': 'Miss Congeniality 2: Armed and Fabulous', 'year': 2005},
#  {'title': 'Sahara', 'year': 2005},
#  {'title': "Hitchhiker's Guide to the Galaxy, The", 'year': 2005},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith', 'year': 2005},
#  {'title': 'Madagascar', 'year': 2005},
#  {'title': 'Sisterhood of the Traveling Pants, The', 'year': 2005},
#  {'title': 'Mr. & Mrs. Smith', 'year': 2005},
#  {'title': 'Adventures of Sharkboy and Lavagirl 3-D, The', 'year': 2005},
#  {'title': 'Herbie: Fully Loaded', 'year': 2005},
#  {'title': 'War of the Worlds', 'year': 2005},
#  {'title': 'Fantastic Four', 'year': 2005},
#  {'title': 'Sky High', 'year': 2005},
#  {'title': 'Stealth', 'year': 2005},
#  {'title': 'Serenity', 'year': 2005},
#  {'title': 'Dukes of Hazzard, The', 'year': 2005},
#  {'title': 'Valiant', 'year': 2005},
#  {'title': 'Cave, The', 'year': 2005},
#  {'title': 'Family Guy Presents Stewie Griffin: The Untold Story',
#   'year': 2005},
#  {'title': 'Final Fantasy VII: Advent Children', 'year': 2005},
#  {'title': 'Into the Blue', 'year': 2005},
#  {'title': 'MirrorMask', 'year': 2005},
#  {'title': 'Wallace & Gromit in The Curse of the Were-Rabbit', 'year': 2005},
#  {'title': 'Legend of Zorro, The', 'year': 2005},
#  {'title': 'Chicken Little', 'year': 2005},
#  {'title': 'Descent, The', 'year': 2005},
#  {'title': 'Harry Potter and the Goblet of Fire', 'year': 2005},
#  {'title': 'Zathura', 'year': 2005},
#  {'title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#   'year': 2005},
#  {'title': 'King Kong', 'year': 2005},
#  {'title': 'Three Burials of Melquiades Estrada, The', 'year': 2005},
#  {'title': 'Transamerica', 'year': 2005},
#  {'title': 'Cheaper by the Dozen 2', 'year': 2005},
#  {'title': 'Casanova', 'year': 2005},
#  {'title': 'New World, The', 'year': 2005},
#  {'title': 'Fullmetal Alchemist the Movie: Conqueror of Shamballa (Gekijô-ban hagane no renkinjutsushi: Shanbara wo yuku mono)',
#   'year': 2005},
#  {'title': 'Jack-Jack Attack', 'year': 2005},
#  {'title': 'Survival Island (Three)', 'year': 2005},
#  {'title': 'Pink Panther, The', 'year': 2006},
#  {'title': 'Curious George', 'year': 2006},
#  {'title': 'Eight Below', 'year': 2006},
#  {'title': 'Ice Age 2: The Meltdown', 'year': 2006},
#  {'title': 'Mission: Impossible III', 'year': 2006},
#  {'title': 'RV', 'year': 2006},
#  {'title': 'Over the Hedge', 'year': 2006},
#  {'title': 'Poseidon', 'year': 2006},
#  {'title': 'Click', 'year': 2006},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest", 'year': 2006},
#  {'title': 'Superman Returns', 'year': 2006},
#  {'title': 'Little Miss Sunshine', 'year': 2006},
#  {'title': 'Ant Bully, The', 'year': 2006},
#  {'title': 'Zoom', 'year': 2006},
#  {'title': 'Idiocracy', 'year': 2006},
#  {'title': "Everyone's Hero", 'year': 2006},
#  {'title': 'Apocalypto', 'year': 2006},
#  {'title': 'Flyboys', 'year': 2006},
#  {'title': 'Open Season', 'year': 2006},
#  {'title': 'Children of Men', 'year': 2006},
#  {'title': 'Casino Royale', 'year': 2006},
#  {'title': 'Happy Feet', 'year': 2006},
#  {'title': 'Tenacious D in The Pick of Destiny', 'year': 2006},
#  {'title': 'Turistas', 'year': 2006},
#  {'title': 'Blood Diamond', 'year': 2006},
#  {'title': 'Eragon', 'year': 2006},
#  {'title': "Librarian: Return to King Solomon's Mines, The", 'year': 2006},
#  {'title': 'Rescue Dawn', 'year': 2006},
#  {'title': 'Tekkonkinkreet (Tekkon kinkurîto)', 'year': 2006},
#  {'title': 'Fall, The', 'year': 2006},
#  {'title': 'Death Note', 'year': 2006},
#  {'title': 'Asterix and the Vikings (Astérix et les Vikings)', 'year': 2006},
#  {'title': 'Bridge to Terabithia', 'year': 2007},
#  {'title': 'Epic Movie', 'year': 2007},
#  {'title': 'Wild Hogs', 'year': 2007},
#  {'title': 'Last Mimzy, The', 'year': 2007},
#  {'title': 'TMNT (Teenage Mutant Ninja Turtles)', 'year': 2007},
#  {'title': 'Meet the Robinsons', 'year': 2007},
#  {'title': 'Sunshine', 'year': 2007},
#  {'title': 'Pathfinder', 'year': 2007},
#  {'title': 'Aqua Teen Hunger Force Colon Movie Film for Theaters',
#   'year': 2007},
#  {'title': 'Condemned, The', 'year': 2007},
#  {'title': 'Spider-Man 3', 'year': 2007},
#  {'title': 'Shrek the Third', 'year': 2007},
#  {'title': "Pirates of the Caribbean: At World's End", 'year': 2007},
#  {'title': 'Fantastic Four: Rise of the Silver Surfer', 'year': 2007},
#  {'title': 'Nancy Drew', 'year': 2007},
#  {'title': 'Death Proof', 'year': 2007},
#  {'title': 'Live Free or Die Hard', 'year': 2007},
#  {'title': 'Harry Potter and the Order of the Phoenix', 'year': 2007},
#  {'title': 'Stardust', 'year': 2007},
#  {'title': 'Hunting Party, The', 'year': 2007},
#  {'title': 'Into the Wild', 'year': 2007},
#  {'title': 'Seeker: The Dark Is Rising, The', 'year': 2007},
#  {'title': 'Darjeeling Limited, The', 'year': 2007},
#  {'title': 'Silk', 'year': 2007},
#  {'title': 'Beowulf', 'year': 2007},
#  {'title': 'Enchanted', 'year': 2007},
#  {'title': 'Golden Compass, The', 'year': 2007},
#  {'title': 'National Treasure: Book of Secrets', 'year': 2007},
#  {'title': 'Water Horse: Legend of the Deep, The', 'year': 2007},
#  {'title': 'D-War (Dragon Wars)', 'year': 2007},
#  {'title': 'In the Name of the King: A Dungeon Siege Tale', 'year': 2007},
#  {'title': 'Rogue', 'year': 2007},
#  {'title': 'Shrek the Halls', 'year': 2007},
#  {'title': 'Sword of the Stranger (Sutorejia: Mukô hadan)', 'year': 2007},
#  {'title': 'Terra (a.k.a. Battle for Terra)', 'year': 2007},
#  {'title': 'Afro Samurai', 'year': 2007},
#  {'title': 'Hellboy II: The Golden Army', 'year': 2008},
#  {'title': "Fool's Gold", 'year': 2008},
#  {'title': 'Jumper', 'year': 2008},
#  {'title': 'Spiderwick Chronicles, The', 'year': 2008},
#  {'title': '10,000 BC', 'year': 2008},
#  {'title': 'Horton Hears a Who!', 'year': 2008},
#  {'title': "Nim's Island", 'year': 2008},
#  {'title': 'Harold & Kumar Escape from Guantanamo Bay', 'year': 2008},
#  {'title': 'Forbidden Kingdom, The', 'year': 2008},
#  {'title': 'Iron Man', 'year': 2008},
#  {'title': 'Chronicles of Narnia: Prince Caspian, The', 'year': 2008},
#  {'title': 'Indiana Jones and the Kingdom of the Crystal Skull', 'year': 2008},
#  {'title': 'WALL·E', 'year': 2008},
#  {'title': 'Hancock', 'year': 2008},
#  {'title': 'Journey to the Center of the Earth', 'year': 2008},
#  {'title': 'Meet Dave', 'year': 2008},
#  {'title': 'Space Chimps', 'year': 2008},
#  {'title': 'Mummy: Tomb of the Dragon Emperor, The', 'year': 2008},
#  {'title': 'Red Cliff (Chi bi)', 'year': 2008},
#  {'title': 'Sisterhood of the Traveling Pants 2, The', 'year': 2008},
#  {'title': 'Tropic Thunder', 'year': 2008},
#  {'title': 'Star Wars: The Clone Wars', 'year': 2008},
#  {'title': 'Mutant Chronicles', 'year': 2008},
#  {'title': 'Death Race', 'year': 2008},
#  {'title': 'Babylon A.D.', 'year': 2008},
#  {'title': 'City of Ember', 'year': 2008},
#  {'title': "Futurama: Bender's Game", 'year': 2008},
#  {'title': 'Madagascar: Escape 2 Africa', 'year': 2008},
#  {'title': 'Quantum of Solace', 'year': 2008},
#  {'title': 'Beverly Hills Chihuahua', 'year': 2008},
#  {'title': 'Australia', 'year': 2008},
#  {'title': 'Bolt', 'year': 2008},
#  {'title': 'Transporter 3', 'year': 2008},
#  {'title': 'Bedtime Stories', 'year': 2008},
#  {'title': 'Ponyo (Gake no ue no Ponyo)', 'year': 2008},
#  {'title': 'Tale of Despereaux, The', 'year': 2008},
#  {'title': 'Inkheart', 'year': 2008},
#  {'title': 'Outlander', 'year': 2008},
#  {'title': 'Good, the Bad, the Weird, The (Joheunnom nabbeunnom isanghannom)',
#   'year': 2008},
#  {'title': 'Far Cry', 'year': 2008},
#  {'title': 'Were the World Mine', 'year': 2008},
#  {'title': 'Brothers Bloom, The', 'year': 2008},
#  {'title': 'Librarian, The: The Curse of the Judas Chalice', 'year': 2008},
#  {'title': 'Dragon Hunters (Chasseurs de dragons)', 'year': 2008},
#  {'title': 'North Face (Nordwand)', 'year': 2008},
#  {'title': '24: Redemption', 'year': 2008},
#  {'title': 'BURN-E', 'year': 2008},
#  {'title': 'The Scorpion King: Rise of a Warrior', 'year': 2008},
#  {'title': 'Road, The', 'year': 2009},
#  {'title': 'Pink Panther 2, The', 'year': 2009},
#  {'title': 'Dragonball Evolution', 'year': 2009},
#  {'title': 'Star Trek', 'year': 2009},
#  {'title': 'Fanboys', 'year': 2009},
#  {'title': 'Terminator Salvation', 'year': 2009},
#  {'title': 'Up', 'year': 2009},
#  {'title': 'Dead Snow (Død snø)', 'year': 2009},
#  {'title': 'Land of the Lost', 'year': 2009},
#  {'title': 'Year One', 'year': 2009},
#  {'title': 'Transformers: Revenge of the Fallen', 'year': 2009},
#  {'title': 'Ice Age: Dawn of the Dinosaurs', 'year': 2009},
#  {'title': 'Watchmen: Tales of the Black Freighter', 'year': 2009},
#  {'title': 'Harry Potter and the Half-Blood Prince', 'year': 2009},
#  {'title': 'Aliens in the Attic', 'year': 2009},
#  {'title': 'Race to Witch Mountain', 'year': 2009},
#  {'title': 'G.I. Joe: The Rise of Cobra', 'year': 2009},
#  {'title': 'G-Force', 'year': 2009},
#  {'title': '9', 'year': 2009},
#  {'title': 'Where the Wild Things Are', 'year': 2009},
#  {'title': "Cirque du Freak: The Vampire's Assistant", 'year': 2009},
#  {'title': 'Fantastic Mr. Fox', 'year': 2009},
#  {'title': 'Battlestar Galactica: The Plan', 'year': 2009},
#  {'title': 'Planet 51', 'year': 2009},
#  {'title': 'Avatar', 'year': 2009},
#  {'title': 'Agora', 'year': 2009},
#  {'title': 'Bunny and the Bull', 'year': 2009},
#  {'title': 'Summer Wars (Samâ wôzu)', 'year': 2009},
#  {'title': 'One Piece Film: Strong World', 'year': 2009},
#  {'title': 'Wonder Woman', 'year': 2009},
#  {'title': 'Book of Eli, The', 'year': 2010},
#  {'title': 'Percy Jackson & the Olympians: The Lightning Thief', 'year': 2010},
#  {'title': 'Alice in Wonderland', 'year': 2010},
#  {'title': 'How to Train Your Dragon', 'year': 2010},
#  {'title': 'Clash of the Titans', 'year': 2010},
#  {'title': 'Losers, The', 'year': 2010},
#  {'title': 'Iron Man 2', 'year': 2010},
#  {'title': 'Robin Hood', 'year': 2010},
#  {'title': 'Prince of Persia: The Sands of Time', 'year': 2010},
#  {'title': 'Toy Story 3', 'year': 2010},
#  {'title': 'Shrek Forever After (a.k.a. Shrek: The Final Chapter)',
#   'year': 2010},
#  {'title': 'Last Airbender, The', 'year': 2010},
#  {'title': "Sorcerer's Apprentice, The", 'year': 2010},
#  {'title': 'Expendables, The', 'year': 2010},
#  {'title': 'Centurion', 'year': 2010},
#  {'title': 'Machete', 'year': 2010},
#  {'title': "Legend of the Guardians: The Owls of Ga'Hoole", 'year': 2010},
#  {'title': 'Secretariat', 'year': 2010},
#  {'title': 'Rubber', 'year': 2010},
#  {'title': 'Black Death', 'year': 2010},
#  {'title': '127 Hours', 'year': 2010},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1', 'year': 2010},
#  {'title': 'Chronicles of Narnia: The Voyage of the Dawn Treader, The',
#   'year': 2010},
#  {'title': 'Tron: Legacy', 'year': 2010},
#  {'title': "Gulliver's Travels", 'year': 2010},
#  {'title': 'Disappearance of Haruhi Suzumiya, The (Suzumiya Haruhi no shôshitsu)',
#   'year': 2010},
#  {'title': 'The Pacific', 'year': 2010},
#  {'title': 'Season of the Witch', 'year': 2011},
#  {'title': 'All-Star Superman', 'year': 2011},
#  {'title': 'Gnomeo & Juliet', 'year': 2011},
#  {'title': 'Paul', 'year': 2011},
#  {'title': 'Rango', 'year': 2011},
#  {'title': 'Eagle, The', 'year': 2011},
#  {'title': 'Mars Needs Moms', 'year': 2011},
#  {'title': 'Hobo with a Shotgun', 'year': 2011},
#  {'title': 'Hanna', 'year': 2011},
#  {'title': 'Rio', 'year': 2011},
#  {'title': 'Thor', 'year': 2011},
#  {'title': 'African Cats', 'year': 2011},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides', 'year': 2011},
#  {'title': 'Kung Fu Panda 2', 'year': 2011},
#  {'title': 'X-Men: First Class', 'year': 2011},
#  {'title': 'Green Lantern', 'year': 2011},
#  {'title': 'Transformers: Dark of the Moon', 'year': 2011},
#  {'title': 'Your Highness', 'year': 2011},
#  {'title': 'Cars 2', 'year': 2011},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2', 'year': 2011},
#  {'title': 'Captain America: The First Avenger', 'year': 2011},
#  {'title': 'Colombiana', 'year': 2011},
#  {'title': 'Inbetweeners Movie, The', 'year': 2011},
#  {'title': 'Three Musketeers, The', 'year': 2011},
#  {'title': 'Johnny English Reborn', 'year': 2011},
#  {'title': 'Puss in Boots', 'year': 2011},
#  {'title': 'Twilight Saga: Breaking Dawn - Part 1, The', 'year': 2011},
#  {'title': 'Sherlock Holmes: A Game of Shadows', 'year': 2011},
#  {'title': 'Mission: Impossible - Ghost Protocol', 'year': 2011},
#  {'title': 'Fullmetal Alchemist: The Sacred Star of Milos', 'year': 2011},
#  {'title': 'Avengers, The', 'year': 2012},
#  {'title': 'Expendables 2, The', 'year': 2012},
#  {'title': 'The Hunger Games', 'year': 2012},
#  {'title': 'Dark Knight Rises, The', 'year': 2012},
#  {'title': 'Bourne Legacy, The', 'year': 2012},
#  {'title': 'Red Tails', 'year': 2012},
#  {'title': 'Journey 2: The Mysterious Island', 'year': 2012},
#  {'title': 'John Carter', 'year': 2012},
#  {'title': 'Wrath of the Titans', 'year': 2012},
#  {'title': 'Mirror Mirror', 'year': 2012},
#  {'title': 'Snow White and the Huntsman', 'year': 2012},
#  {'title': 'Pirates! Band of Misfits, The', 'year': 2012},
#  {'title': "Madagascar 3: Europe's Most Wanted", 'year': 2012},
#  {'title': 'Brave', 'year': 2012},
#  {'title': 'Amazing Spider-Man, The', 'year': 2012},
#  {'title': 'Ice Age 4: Continental Drift', 'year': 2012},
#  {'title': 'Skyfall', 'year': 2012},
#  {'title': 'ParaNorman', 'year': 2012},
#  {'title': 'Kon-Tiki', 'year': 2012},
#  {'title': 'Life of Pi', 'year': 2012},
#  {'title': 'Rise of the Guardians', 'year': 2012},
#  {'title': 'Hobbit: An Unexpected Journey, The', 'year': 2012},
#  {'title': 'Maximum Conviction', 'year': 2012},
#  {'title': 'Dark Tide', 'year': 2012},
#  {'title': 'Mud', 'year': 2012},
#  {'title': 'One Piece Film Z', 'year': 2012},
#  {'title': 'Jack the Giant Slayer', 'year': 2013},
#  {'title': 'G.I. Joe: Retaliation', 'year': 2013},
#  {'title': 'Oz the Great and Powerful', 'year': 2013},
#  {'title': 'Croods, The', 'year': 2013},
#  {'title': 'Host, The', 'year': 2013},
#  {'title': 'Oblivion', 'year': 2013},
#  {'title': 'Star Trek Into Darkness', 'year': 2013},
#  {'title': 'Epic', 'year': 2013},
#  {'title': 'After Earth', 'year': 2013},
#  {'title': 'Man of Steel', 'year': 2013},
#  {'title': 'Monsters University', 'year': 2013},
#  {'title': 'Pacific Rim', 'year': 2013},
#  {'title': 'Lone Ranger, The', 'year': 2013},
#  {'title': 'Justice League: The Flashpoint Paradox', 'year': 2013},
#  {'title': 'Turbo', 'year': 2013},
#  {'title': 'Wolverine, The', 'year': 2013},
#  {'title': 'Percy Jackson: Sea of Monsters', 'year': 2013},
#  {'title': 'Planes', 'year': 2013},
#  {'title': 'Mortal Instruments: City of Bones, The', 'year': 2013},
#  {'title': 'Nebraska', 'year': 2013},
#  {'title': 'Crystal Fairy & the Magical Cactus and 2012', 'year': 2013},
#  {'title': 'Captain Phillips', 'year': 2013},
#  {'title': 'All Is Lost', 'year': 2013},
#  {'title': "Ender's Game", 'year': 2013},
#  {'title': 'Thor: The Dark World', 'year': 2013},
#  {'title': 'The Hunger Games: Catching Fire', 'year': 2013},
#  {'title': 'Hobbit: The Desolation of Smaug, The', 'year': 2013},
#  {'title': '47 Ronin', 'year': 2013},
#  {'title': 'Frozen', 'year': 2013},
#  {'title': 'Secret Life of Walter Mitty, The', 'year': 2013},
#  {'title': 'Other Shore, The', 'year': 2013},
#  {'title': 'Knights of Badassdom', 'year': 2013},
#  {'title': 'Centenarian Who Climbed Out the Window and Vanished, The (Hundraåringen som klev ut genom fönstret och försvann)',
#   'year': 2013},
#  {'title': 'Divergent', 'year': 2014},
#  {'title': 'The Lego Movie', 'year': 2014},
#  {'title': 'Mr. Peabody & Sherman', 'year': 2014},
#  {'title': 'Captain America: The Winter Soldier', 'year': 2014},
#  {'title': 'Noah', 'year': 2014},
#  {'title': 'Muppets Most Wanted', 'year': 2014},
#  {'title': 'Rio 2', 'year': 2014},
#  {'title': 'X-Men: Days of Future Past', 'year': 2014},
#  {'title': 'Godzilla', 'year': 2014},
#  {'title': 'Maleficent', 'year': 2014},
#  {'title': 'How to Train Your Dragon 2', 'year': 2014},
#  {'title': 'Transformers: Age of Extinction', 'year': 2014},
#  {'title': 'Planes: Fire & Rescue', 'year': 2014},
#  {'title': 'Guardians of the Galaxy', 'year': 2014},
#  {'title': 'The Expendables 3', 'year': 2014},
#  {'title': 'Hercules', 'year': 2014},
#  {'title': 'Teenage Mutant Ninja Turtles', 'year': 2014},
#  {'title': 'Boxtrolls, The', 'year': 2014},
#  {'title': 'The Book of Life', 'year': 2014},
#  {'title': 'The Hunger Games: Mockingjay - Part 1', 'year': 2014},
#  {'title': 'Exodus: Gods and Kings', 'year': 2014},
#  {'title': 'Penguins of Madagascar', 'year': 2014},
#  {'title': 'The Hobbit: The Battle of the Five Armies', 'year': 2014},
#  {'title': 'Kingsman: The Secret Service', 'year': 2014},
#  {'title': 'Night at the Museum: Secret of the Tomb', 'year': 2014},
#  {'title': 'Seventh Son', 'year': 2014},
#  {'title': 'Robot Overlords', 'year': 2014},
#  {'title': 'Mission: Impossible - Rogue Nation', 'year': 2015},
#  {'title': 'Jupiter Ascending', 'year': 2015},
#  {'title': 'Jurassic World', 'year': 2015},
#  {'title': 'Terminator Genisys', 'year': 2015},
#  {'title': 'Mad Max: Fury Road', 'year': 2015},
#  {'title': 'Star Wars: Episode VII - The Force Awakens', 'year': 2015},
#  {'title': 'Avengers: Age of Ultron', 'year': 2015},
#  {'title': 'Ant-Man', 'year': 2015},
#  {'title': 'Fantastic Four', 'year': 2015},
#  {'title': 'Pan', 'year': 2015},
#  {'title': 'Home', 'year': 2015},
#  {'title': 'Last Knights', 'year': 2015},
#  {'title': 'Tomorrowland', 'year': 2015},
#  {'title': 'Sword of Vengeance', 'year': 2015},
#  {'title': 'The Martian', 'year': 2015},
#  {'title': 'Inside Out', 'year': 2015},
#  {'title': 'The Hunger Games: Mockingjay - Part 2', 'year': 2015},
#  {'title': 'The Last Witch Hunter', 'year': 2015},
#  {'title': 'Minions', 'year': 2015},
#  {'title': 'The Good Dinosaur', 'year': 2015},
#  {'title': 'Spectre', 'year': 2015},
#  {'title': 'Vacation', 'year': 2015},
#  {'title': 'The Man from U.N.C.L.E.', 'year': 2015},
#  {'title': 'The Walk', 'year': 2015},
#  {'title': 'The Revenant', 'year': 2015},
#  {'title': 'Everest', 'year': 2015},
#  {'title': 'Goosebumps', 'year': 2015},
#  {'title': 'Peanuts Movie, The', 'year': 2015},
#  {'title': 'The Boy and the Beast', 'year': 2015},
#  {'title': 'Warcraft', 'year': 2016},
#  {'title': 'Deadpool', 'year': 2016},
#  {'title': 'X-Men: Apocalypse', 'year': 2016},
#  {'title': 'Independence Day: Resurgence', 'year': 2016},
#  {'title': 'Star Trek 3', 'year': 2016},
#  {'title': 'Batman v Superman: Dawn of Justice', 'year': 2016},
#  {'title': 'The Jungle Book', 'year': 2016},
#  {'title': 'Kung Fu Panda 3', 'year': 2016},
#  {'title': 'Zootopia', 'year': 2016},
#  {'title': 'Ice Age: The Great Egg-Scapade', 'year': 2016},
#  {'title': "The Huntsman Winter's War", 'year': 2016},
#  {'title': 'Finding Dory', 'year': 2016},
#  {'title': 'Teenage Mutant Ninja Turtles: Out of the Shadows', 'year': 2016},
#  {'title': 'The Legend of Tarzan', 'year': 2016},
#  {'title': 'Sharknado 4: The 4th Awakens', 'year': 2016},
#  {'title': 'Mohenjo Daro', 'year': 2016},
#  {'title': 'Shin Godzilla', 'year': 2016}]

# %%
# 5. Query Example
query = "Find movies acted by Leonardo DiCaprio released after 2000."
result = qa_chain.invoke({"query": query})
print("Answer:", result['result'])
# Out:
# Answer: Based on the provided facts, here are the movies acted by Leonardo DiCaprio released after 2000:
#
# 1. Gangs of New York (2002)
# 2. Catch Me If You Can (2002)
# 3. The Aviator (2004)
# 4. Blood Diamond (2006)
# 5. The Departed (2006)
# 6. Revolutionary Road (2008)
# 7. Inception (2010)
# 8. Django Unchained (2012)
# 9. The Wolf of Wall Street (2013)
# 10. The Revenant (2015)
#
# Note: The list only includes movies released after 2000, as per the question.

# %%
result = kg.query("""
MATCH (p:Person)-[:ACTED_IN]->(m:Movie)
WHERE p.name = "Leonardo DiCaprio" AND m.year > 2000
RETURN m.title AS title, m.year AS year
ORDER BY m.year ASC


""")
result
# Out:
# [{'title': 'Gangs of New York', 'year': 2002},
#  {'title': 'Catch Me If You Can', 'year': 2002},
#  {'title': 'Aviator, The', 'year': 2004},
#  {'title': 'Departed, The', 'year': 2006},
#  {'title': 'Blood Diamond', 'year': 2006},
#  {'title': 'Body of Lies', 'year': 2008},
#  {'title': 'Revolutionary Road', 'year': 2008},
#  {'title': 'Shutter Island', 'year': 2010},
#  {'title': 'Inception', 'year': 2010},
#  {'title': 'J. Edgar', 'year': 2011},
#  {'title': 'Django Unchained', 'year': 2012},
#  {'title': 'Great Gatsby, The', 'year': 2013},
#  {'title': 'Wolf of Wall Street, The', 'year': 2013},
#  {'title': 'The Revenant', 'year': 2015}]

# %%
# 5. Query Example
query = "Find movies rated 5.0 by User 4."
result = qa_chain.invoke({"query": query})
print("Answer:", result['result'])
# Out:
# Answer: Based on the provided data, User 4 has rated the following movies as 5.0:
#
# 1. The Godfather
# 2. Aliens
# 3. Big
# 4. Pulp Fiction
# 5. Only You
# 6. Goodfellas
# 7. Die Hard
# 8. Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)
# 9. Aladdin
# 10. Say Anything...
# 11. The NeverEnding Story
# 12. Psycho
# 13. Star Wars: Episode I - The Phantom Menace

# %%
result = kg.query("""
MATCH (u:User)-[r:RATED]->(m:Movie)
WHERE u.userId = "4" AND r.rating = 5.0
RETURN m.title AS title, r.rating AS rating
ORDER BY m.title



""")
result
# Out:
# [{'title': '101 Dalmatians (One Hundred and One Dalmatians)', 'rating': 5.0},
#  {'title': 'Abyss, The', 'rating': 5.0},
#  {'title': 'Agnes of God', 'rating': 5.0},
#  {'title': 'Airplane!', 'rating': 5.0},
#  {'title': 'Aladdin', 'rating': 5.0},
#  {'title': 'Alice in Wonderland', 'rating': 5.0},
#  {'title': 'Alien', 'rating': 5.0},
#  {'title': 'Aliens', 'rating': 5.0},
#  {'title': 'Amadeus', 'rating': 5.0},
#  {'title': 'Annie Hall', 'rating': 5.0},
#  {'title': 'Apocalypse Now', 'rating': 5.0},
#  {'title': 'Aristocats, The', 'rating': 5.0},
#  {'title': 'Babe', 'rating': 5.0},
#  {'title': 'Back to the Future', 'rating': 5.0},
#  {'title': 'Bambi', 'rating': 5.0},
#  {'title': 'Bedknobs and Broomsticks', 'rating': 5.0},
#  {'title': 'Beetlejuice', 'rating': 5.0},
#  {'title': 'Better Off Dead...', 'rating': 5.0},
#  {'title': 'Big', 'rating': 5.0},
#  {'title': 'Birdcage, The', 'rating': 5.0},
#  {'title': 'Blade Runner', 'rating': 5.0},
#  {'title': 'Blob, The', 'rating': 5.0},
#  {'title': 'Blues Brothers, The', 'rating': 5.0},
#  {'title': 'Breakfast Club, The', 'rating': 5.0},
#  {'title': 'Cape Fear', 'rating': 5.0},
#  {'title': "Cheech and Chong's Up in Smoke", 'rating': 5.0},
#  {'title': 'Christmas Story, A', 'rating': 5.0},
#  {'title': 'Cinderella', 'rating': 5.0},
#  {'title': 'Clear and Present Danger', 'rating': 5.0},
#  {'title': 'Clockwork Orange, A', 'rating': 5.0},
#  {'title': 'Commitments, The', 'rating': 5.0},
#  {'title': 'Dark Crystal, The', 'rating': 5.0},
#  {'title': 'Die Hard', 'rating': 5.0},
#  {'title': 'E.T. the Extra-Terrestrial', 'rating': 5.0},
#  {'title': 'Excalibur', 'rating': 5.0},
#  {'title': 'Fantasia', 'rating': 5.0},
#  {'title': "Ferris Bueller's Day Off", 'rating': 5.0},
#  {'title': 'Few Good Men, A', 'rating': 5.0},
#  {'title': 'Fish Called Wanda, A', 'rating': 5.0},
#  {'title': 'Fisher King, The', 'rating': 5.0},
#  {'title': 'Flight of the Navigator', 'rating': 5.0},
#  {'title': 'Fly, The', 'rating': 5.0},
#  {'title': 'Forrest Gump', 'rating': 5.0},
#  {'title': 'Four Weddings and a Funeral', 'rating': 5.0},
#  {'title': 'Fox and the Hound, The', 'rating': 5.0},
#  {'title': 'French Connection, The', 'rating': 5.0},
#  {'title': 'Full Metal Jacket', 'rating': 5.0},
#  {'title': 'Ghostbusters (a.k.a. Ghost Busters)', 'rating': 5.0},
#  {'title': 'Godfather, The', 'rating': 5.0},
#  {'title': 'Goodfellas', 'rating': 5.0},
#  {'title': 'Goonies, The', 'rating': 5.0},
#  {'title': 'Grease', 'rating': 5.0},
#  {'title': 'Groundhog Day', 'rating': 5.0},
#  {'title': 'Hard-Boiled (Lat sau san taam)', 'rating': 5.0},
#  {'title': 'Indiana Jones and the Last Crusade', 'rating': 5.0},
#  {'title': 'Indiana Jones and the Temple of Doom', 'rating': 5.0},
#  {'title': 'Jaws', 'rating': 5.0},
#  {'title': 'Jerk, The', 'rating': 5.0},
#  {'title': 'Jungle Book, The', 'rating': 5.0},
#  {'title': 'Jurassic Park', 'rating': 5.0},
#  {'title': 'Lady and the Tramp', 'rating': 5.0},
#  {'title': 'Lethal Weapon', 'rating': 5.0},
#  {'title': 'Lion King, The', 'rating': 5.0},
#  {'title': 'Live and Let Die', 'rating': 5.0},
#  {'title': 'Maltese Falcon, The', 'rating': 5.0},
#  {'title': 'Mary Poppins', 'rating': 5.0},
#  {'title': 'Meatballs', 'rating': 5.0},
#  {'title': 'Men in Black (a.k.a. MIB)', 'rating': 5.0},
#  {'title': 'Monty Python and the Holy Grail', 'rating': 5.0},
#  {'title': "Monty Python's And Now for Something Completely Different",
#   'rating': 5.0},
#  {'title': 'Mr. Nice Guy (Yat goh ho yan)', 'rating': 5.0},
#  {'title': 'Mystery Men', 'rating': 5.0},
#  {'title': 'Name of the Rose, The (Name der Rose, Der)', 'rating': 5.0},
#  {'title': 'NeverEnding Story, The', 'rating': 5.0},
#  {'title': 'One Magic Christmas', 'rating': 5.0},
#  {'title': 'Outsiders, The', 'rating': 5.0},
#  {'title': "Pete's Dragon", 'rating': 5.0},
#  {'title': 'Peter Pan', 'rating': 5.0},
#  {'title': 'Pinocchio', 'rating': 5.0},
#  {'title': 'Player, The', 'rating': 5.0},
#  {'title': 'Poltergeist', 'rating': 5.0},
#  {'title': 'Princess Bride, The', 'rating': 5.0},
#  {'title': 'Psycho', 'rating': 5.0},
#  {'title': 'Pulp Fiction', 'rating': 5.0},
#  {'title': 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)',
#   'rating': 5.0},
#  {'title': 'Rain Man', 'rating': 5.0},
#  {'title': 'Reservoir Dogs', 'rating': 5.0},
#  {'title': 'Return from Witch Mountain', 'rating': 5.0},
#  {'title': 'Return of the Pink Panther, The', 'rating': 5.0},
#  {'title': 'Robin Hood', 'rating': 5.0},
#  {'title': 'Rocky', 'rating': 5.0},
#  {'title': 'Roger & Me', 'rating': 5.0},
#  {'title': 'Romancing the Stone', 'rating': 5.0},
#  {'title': 'Rosencrantz and Guildenstern Are Dead', 'rating': 5.0},
#  {'title': 'Rumble in the Bronx (Hont faan kui)', 'rating': 5.0},
#  {'title': 'Shining, The', 'rating': 5.0},
#  {'title': 'Sixteen Candles', 'rating': 5.0},
#  {'title': 'Sleeping Beauty', 'rating': 5.0},
#  {'title': 'Sneakers', 'rating': 5.0},
#  {'title': 'Snow White and the Seven Dwarfs', 'rating': 5.0},
#  {'title': 'Splash', 'rating': 5.0},
#  {'title': 'Star Wars: Episode I - The Phantom Menace', 'rating': 5.0},
#  {'title': 'Star Wars: Episode IV - A New Hope', 'rating': 5.0},
#  {'title': 'Star Wars: Episode V - The Empire Strikes Back', 'rating': 5.0},
#  {'title': 'Star Wars: Episode VI - Return of the Jedi', 'rating': 5.0},
#  {'title': 'Steamboat Willie', 'rating': 5.0},
#  {'title': 'Superman', 'rating': 5.0},
#  {'title': 'Terminator 2: Judgment Day', 'rating': 5.0},
#  {'title': 'Terminator, The', 'rating': 5.0},
#  {'title': 'This Is Spinal Tap', 'rating': 5.0},
#  {'title': 'Time Bandits', 'rating': 5.0},
#  {'title': 'Tommy', 'rating': 5.0},
#  {'title': 'Untouchables, The', 'rating': 5.0},
#  {'title': 'Vertigo', 'rating': 5.0},
#  {'title': 'Who Framed Roger Rabbit?', 'rating': 5.0},
#  {'title': 'Willy Wonka & the Chocolate Factory', 'rating': 5.0},
#  {'title': 'Witness', 'rating': 5.0},
#  {'title': 'Wizard of Oz, The', 'rating': 5.0},
#  {'title': 'Young Frankenstein', 'rating': 5.0}]

# %%
# 5. Query Example
query = "Can you recommend me a recent movie with Adventure genre and rating greater than 5"
result = qa_chain.invoke({"query": query})
print("Answer:", result['result'])
# Out:
# Answer: Based on the data, I recommend "Wild Tales" (2014) which is an Adventure movie with a rating of 8.1.

# %%
result = kg.query("""
MATCH (m:Movie)-[:IN_GENRE]->(g:Genre)
MATCH (u:User)-[r:RATED]->(m)
WHERE g.name = "Adventure" AND r.rating >= 5.0
RETURN m.title AS title, m.year AS year, r.rating AS rating
ORDER BY m.year DESC, r.rating DESC


""")
result
# Out:
# [{'title': 'Cowboy Bebop', 'year': None, 'rating': 5.0},
#  {'title': 'Cowboy Bebop', 'year': None, 'rating': 5.0},
#  {'title': 'Day of the Doctor, The', 'year': None, 'rating': 5.0},
#  {'title': 'Into the Woods', 'year': None, 'rating': 5.0},
#  {'title': 'Clockstoppers', 'year': None, 'rating': 5.0},
#  {'title': 'Ice Age: The Great Egg-Scapade', 'year': 2016, 'rating': 5.0},
#  {'title': 'Zootopia', 'year': 2016, 'rating': 5.0},
#  {'title': 'Zootopia', 'year': 2016, 'rating': 5.0},
#  {'title': 'Zootopia', 'year': 2016, 'rating': 5.0},
#  {'title': 'Finding Dory', 'year': 2016, 'rating': 5.0},
#  {'title': 'Kung Fu Panda 3', 'year': 2016, 'rating': 5.0},
#  {'title': 'Warcraft', 'year': 2016, 'rating': 5.0},
#  {'title': 'Deadpool', 'year': 2016, 'rating': 5.0},
#  {'title': 'Deadpool', 'year': 2016, 'rating': 5.0},
#  {'title': 'Deadpool', 'year': 2016, 'rating': 5.0},
#  {'title': 'Deadpool', 'year': 2016, 'rating': 5.0},
#  {'title': 'Peanuts Movie, The', 'year': 2015, 'rating': 5.0},
#  {'title': 'The Man from U.N.C.L.E.', 'year': 2015, 'rating': 5.0},
#  {'title': 'The Martian', 'year': 2015, 'rating': 5.0},
#  {'title': 'The Martian', 'year': 2015, 'rating': 5.0},
#  {'title': 'The Martian', 'year': 2015, 'rating': 5.0},
#  {'title': 'The Martian', 'year': 2015, 'rating': 5.0},
#  {'title': 'The Martian', 'year': 2015, 'rating': 5.0},
#  {'title': 'The Good Dinosaur', 'year': 2015, 'rating': 5.0},
#  {'title': 'Minions', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Inside Out', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Mad Max: Fury Road', 'year': 2015, 'rating': 5.0},
#  {'title': 'Star Wars: Episode VII - The Force Awakens',
#   'year': 2015,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode VII - The Force Awakens',
#   'year': 2015,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode VII - The Force Awakens',
#   'year': 2015,
#   'rating': 5.0},
#  {'title': 'Ant-Man', 'year': 2015, 'rating': 5.0},
#  {'title': 'Ant-Man', 'year': 2015, 'rating': 5.0},
#  {'title': 'Ant-Man', 'year': 2015, 'rating': 5.0},
#  {'title': 'Avengers: Age of Ultron', 'year': 2015, 'rating': 5.0},
#  {'title': 'Avengers: Age of Ultron', 'year': 2015, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'Guardians of the Galaxy', 'year': 2014, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon 2', 'year': 2014, 'rating': 5.0},
#  {'title': 'Captain America: The Winter Soldier', 'year': 2014, 'rating': 5.0},
#  {'title': 'Captain America: The Winter Soldier', 'year': 2014, 'rating': 5.0},
#  {'title': 'The Lego Movie', 'year': 2014, 'rating': 5.0},
#  {'title': 'The Lego Movie', 'year': 2014, 'rating': 5.0},
#  {'title': 'Kingsman: The Secret Service', 'year': 2014, 'rating': 5.0},
#  {'title': 'The Hunger Games: Mockingjay - Part 1',
#   'year': 2014,
#   'rating': 5.0},
#  {'title': 'The Hobbit: The Battle of the Five Armies',
#   'year': 2014,
#   'rating': 5.0},
#  {'title': 'The Hobbit: The Battle of the Five Armies',
#   'year': 2014,
#   'rating': 5.0},
#  {'title': 'Centenarian Who Climbed Out the Window and Vanished, The (Hundraåringen som klev ut genom fönstret och försvann)',
#   'year': 2013,
#   'rating': 5.0},
#  {'title': 'Secret Life of Walter Mitty, The', 'year': 2013, 'rating': 5.0},
#  {'title': 'Hobbit: The Desolation of Smaug, The',
#   'year': 2013,
#   'rating': 5.0},
#  {'title': 'Hobbit: The Desolation of Smaug, The',
#   'year': 2013,
#   'rating': 5.0},
#  {'title': 'Hobbit: The Desolation of Smaug, The',
#   'year': 2013,
#   'rating': 5.0},
#  {'title': 'Hobbit: The Desolation of Smaug, The',
#   'year': 2013,
#   'rating': 5.0},
#  {'title': 'Hobbit: The Desolation of Smaug, The',
#   'year': 2013,
#   'rating': 5.0},
#  {'title': 'Frozen', 'year': 2013, 'rating': 5.0},
#  {'title': 'The Hunger Games: Catching Fire', 'year': 2013, 'rating': 5.0},
#  {'title': 'The Hunger Games: Catching Fire', 'year': 2013, 'rating': 5.0},
#  {'title': "Ender's Game", 'year': 2013, 'rating': 5.0},
#  {'title': "Ender's Game", 'year': 2013, 'rating': 5.0},
#  {'title': 'Thor: The Dark World', 'year': 2013, 'rating': 5.0},
#  {'title': 'Captain Phillips', 'year': 2013, 'rating': 5.0},
#  {'title': 'Captain Phillips', 'year': 2013, 'rating': 5.0},
#  {'title': 'Wolverine, The', 'year': 2013, 'rating': 5.0},
#  {'title': 'Pacific Rim', 'year': 2013, 'rating': 5.0},
#  {'title': 'Star Trek Into Darkness', 'year': 2013, 'rating': 5.0},
#  {'title': 'Star Trek Into Darkness', 'year': 2013, 'rating': 5.0},
#  {'title': 'Star Trek Into Darkness', 'year': 2013, 'rating': 5.0},
#  {'title': 'Mud', 'year': 2012, 'rating': 5.0},
#  {'title': 'Kon-Tiki', 'year': 2012, 'rating': 5.0},
#  {'title': 'Life of Pi', 'year': 2012, 'rating': 5.0},
#  {'title': 'Hobbit: An Unexpected Journey, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Hobbit: An Unexpected Journey, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Brave', 'year': 2012, 'rating': 5.0},
#  {'title': 'Brave', 'year': 2012, 'rating': 5.0},
#  {'title': 'Amazing Spider-Man, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Amazing Spider-Man, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Amazing Spider-Man, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Skyfall', 'year': 2012, 'rating': 5.0},
#  {'title': 'Skyfall', 'year': 2012, 'rating': 5.0},
#  {'title': 'Skyfall', 'year': 2012, 'rating': 5.0},
#  {'title': 'The Hunger Games', 'year': 2012, 'rating': 5.0},
#  {'title': 'The Hunger Games', 'year': 2012, 'rating': 5.0},
#  {'title': 'The Hunger Games', 'year': 2012, 'rating': 5.0},
#  {'title': 'The Hunger Games', 'year': 2012, 'rating': 5.0},
#  {'title': 'The Hunger Games', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Dark Knight Rises, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'Avengers, The', 'year': 2012, 'rating': 5.0},
#  {'title': 'All-Star Superman', 'year': 2011, 'rating': 5.0},
#  {'title': 'Thor', 'year': 2011, 'rating': 5.0},
#  {'title': 'Sherlock Holmes: A Game of Shadows', 'year': 2011, 'rating': 5.0},
#  {'title': 'Sherlock Holmes: A Game of Shadows', 'year': 2011, 'rating': 5.0},
#  {'title': 'Sherlock Holmes: A Game of Shadows', 'year': 2011, 'rating': 5.0},
#  {'title': 'Sherlock Holmes: A Game of Shadows', 'year': 2011, 'rating': 5.0},
#  {'title': 'Mission: Impossible - Ghost Protocol',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Kung Fu Panda 2', 'year': 2011, 'rating': 5.0},
#  {'title': 'X-Men: First Class', 'year': 2011, 'rating': 5.0},
#  {'title': 'X-Men: First Class', 'year': 2011, 'rating': 5.0},
#  {'title': 'X-Men: First Class', 'year': 2011, 'rating': 5.0},
#  {'title': 'X-Men: First Class', 'year': 2011, 'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': 2011,
#   'rating': 5.0},
#  {'title': 'Captain America: The First Avenger', 'year': 2011, 'rating': 5.0},
#  {'title': 'Captain America: The First Avenger', 'year': 2011, 'rating': 5.0},
#  {'title': 'The Pacific', 'year': 2010, 'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'year': 2010,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'year': 2010,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'year': 2010,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'year': 2010,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'year': 2010,
#   'rating': 5.0},
#  {'title': 'Secretariat', 'year': 2010, 'rating': 5.0},
#  {'title': '127 Hours', 'year': 2010, 'rating': 5.0},
#  {'title': '127 Hours', 'year': 2010, 'rating': 5.0},
#  {'title': '127 Hours', 'year': 2010, 'rating': 5.0},
#  {'title': 'Losers, The', 'year': 2010, 'rating': 5.0},
#  {'title': 'Iron Man 2', 'year': 2010, 'rating': 5.0},
#  {'title': 'Iron Man 2', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'How to Train Your Dragon', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Toy Story 3', 'year': 2010, 'rating': 5.0},
#  {'title': 'Book of Eli, The', 'year': 2010, 'rating': 5.0},
#  {'title': 'Book of Eli, The', 'year': 2010, 'rating': 5.0},
#  {'title': 'Disappearance of Haruhi Suzumiya, The (Suzumiya Haruhi no shôshitsu)',
#   'year': 2010,
#   'rating': 5.0},
#  {'title': 'One Piece Film: Strong World', 'year': 2009, 'rating': 5.0},
#  {'title': 'Summer Wars (Samâ wôzu)', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Avatar', 'year': 2009, 'rating': 5.0},
#  {'title': 'Star Trek', 'year': 2009, 'rating': 5.0},
#  {'title': 'Star Trek', 'year': 2009, 'rating': 5.0},
#  {'title': 'Star Trek', 'year': 2009, 'rating': 5.0},
#  {'title': 'Star Trek', 'year': 2009, 'rating': 5.0},
#  {'title': 'Star Trek', 'year': 2009, 'rating': 5.0},
#  {'title': 'Terminator Salvation', 'year': 2009, 'rating': 5.0},
#  {'title': 'Harry Potter and the Half-Blood Prince',
#   'year': 2009,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Half-Blood Prince',
#   'year': 2009,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Half-Blood Prince',
#   'year': 2009,
#   'rating': 5.0},
#  {'title': 'Transformers: Revenge of the Fallen', 'year': 2009, 'rating': 5.0},
#  {'title': 'Up', 'year': 2009, 'rating': 5.0},
#  {'title': 'Up', 'year': 2009, 'rating': 5.0},
#  {'title': 'Up', 'year': 2009, 'rating': 5.0},
#  {'title': 'Up', 'year': 2009, 'rating': 5.0},
#  {'title': 'Up', 'year': 2009, 'rating': 5.0},
#  {'title': 'Up', 'year': 2009, 'rating': 5.0},
#  {'title': 'Up', 'year': 2009, 'rating': 5.0},
#  {'title': 'Fantastic Mr. Fox', 'year': 2009, 'rating': 5.0},
#  {'title': 'Fantastic Mr. Fox', 'year': 2009, 'rating': 5.0},
#  {'title': 'Fantastic Mr. Fox', 'year': 2009, 'rating': 5.0},
#  {'title': 'Fantastic Mr. Fox', 'year': 2009, 'rating': 5.0},
#  {'title': 'Fantastic Mr. Fox', 'year': 2009, 'rating': 5.0},
#  {'title': 'Fantastic Mr. Fox', 'year': 2009, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'WALL·E', 'year': 2008, 'rating': 5.0},
#  {'title': 'Bolt', 'year': 2008, 'rating': 5.0},
#  {'title': "Futurama: Bender's Game", 'year': 2008, 'rating': 5.0},
#  {'title': 'Ponyo (Gake no ue no Ponyo)', 'year': 2008, 'rating': 5.0},
#  {'title': 'Ponyo (Gake no ue no Ponyo)', 'year': 2008, 'rating': 5.0},
#  {'title': 'Ponyo (Gake no ue no Ponyo)', 'year': 2008, 'rating': 5.0},
#  {'title': 'Ponyo (Gake no ue no Ponyo)', 'year': 2008, 'rating': 5.0},
#  {'title': 'Ponyo (Gake no ue no Ponyo)', 'year': 2008, 'rating': 5.0},
#  {'title': 'Brothers Bloom, The', 'year': 2008, 'rating': 5.0},
#  {'title': 'Horton Hears a Who!', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Iron Man', 'year': 2008, 'rating': 5.0},
#  {'title': 'Sunshine', 'year': 2007, 'rating': 5.0},
#  {'title': 'Spider-Man 3', 'year': 2007, 'rating': 5.0},
#  {'title': 'Shrek the Third', 'year': 2007, 'rating': 5.0},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'year': 2007,
#   'rating': 5.0},
#  {'title': 'Stardust', 'year': 2007, 'rating': 5.0},
#  {'title': 'Stardust', 'year': 2007, 'rating': 5.0},
#  {'title': 'Stardust', 'year': 2007, 'rating': 5.0},
#  {'title': 'Stardust', 'year': 2007, 'rating': 5.0},
#  {'title': 'Stardust', 'year': 2007, 'rating': 5.0},
#  {'title': 'Live Free or Die Hard', 'year': 2007, 'rating': 5.0},
#  {'title': 'Live Free or Die Hard', 'year': 2007, 'rating': 5.0},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'year': 2007,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'year': 2007,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'year': 2007,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'year': 2007,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'year': 2007,
#   'rating': 5.0},
#  {'title': 'Into the Wild', 'year': 2007, 'rating': 5.0},
#  {'title': 'Into the Wild', 'year': 2007, 'rating': 5.0},
#  {'title': 'Into the Wild', 'year': 2007, 'rating': 5.0},
#  {'title': 'Into the Wild', 'year': 2007, 'rating': 5.0},
#  {'title': 'Darjeeling Limited, The', 'year': 2007, 'rating': 5.0},
#  {'title': 'Darjeeling Limited, The', 'year': 2007, 'rating': 5.0},
#  {'title': 'Darjeeling Limited, The', 'year': 2007, 'rating': 5.0},
#  {'title': 'Enchanted', 'year': 2007, 'rating': 5.0},
#  {'title': 'Enchanted', 'year': 2007, 'rating': 5.0},
#  {'title': 'Children of Men', 'year': 2006, 'rating': 5.0},
#  {'title': 'Children of Men', 'year': 2006, 'rating': 5.0},
#  {'title': 'Children of Men', 'year': 2006, 'rating': 5.0},
#  {'title': 'Casino Royale', 'year': 2006, 'rating': 5.0},
#  {'title': 'Casino Royale', 'year': 2006, 'rating': 5.0},
#  {'title': 'Casino Royale', 'year': 2006, 'rating': 5.0},
#  {'title': 'Casino Royale', 'year': 2006, 'rating': 5.0},
#  {'title': 'Casino Royale', 'year': 2006, 'rating': 5.0},
#  {'title': 'Casino Royale', 'year': 2006, 'rating': 5.0},
#  {'title': 'Casino Royale', 'year': 2006, 'rating': 5.0},
#  {'title': 'Blood Diamond', 'year': 2006, 'rating': 5.0},
#  {'title': 'Blood Diamond', 'year': 2006, 'rating': 5.0},
#  {'title': 'Blood Diamond', 'year': 2006, 'rating': 5.0},
#  {'title': 'Blood Diamond', 'year': 2006, 'rating': 5.0},
#  {'title': 'Rescue Dawn', 'year': 2006, 'rating': 5.0},
#  {'title': 'Tekkonkinkreet (Tekkon kinkurîto)', 'year': 2006, 'rating': 5.0},
#  {'title': 'Fall, The', 'year': 2006, 'rating': 5.0},
#  {'title': 'Fall, The', 'year': 2006, 'rating': 5.0},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'year': 2006,
#   'rating': 5.0},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'year': 2006,
#   'rating': 5.0},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'year': 2006,
#   'rating': 5.0},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'year': 2006,
#   'rating': 5.0},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'year': 2006,
#   'rating': 5.0},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'year': 2006,
#   'rating': 5.0},
#  {'title': 'Mission: Impossible III', 'year': 2006, 'rating': 5.0},
#  {'title': 'Apocalypto', 'year': 2006, 'rating': 5.0},
#  {'title': 'Apocalypto', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Little Miss Sunshine', 'year': 2006, 'rating': 5.0},
#  {'title': 'Jack-Jack Attack', 'year': 2005, 'rating': 5.0},
#  {'title': 'MirrorMask', 'year': 2005, 'rating': 5.0},
#  {'title': 'Serenity', 'year': 2005, 'rating': 5.0},
#  {'title': 'Serenity', 'year': 2005, 'rating': 5.0},
#  {'title': 'Serenity', 'year': 2005, 'rating': 5.0},
#  {'title': 'Serenity', 'year': 2005, 'rating': 5.0},
#  {'title': 'Serenity', 'year': 2005, 'rating': 5.0},
#  {'title': 'Serenity', 'year': 2005, 'rating': 5.0},
#  {'title': 'New World, The', 'year': 2005, 'rating': 5.0},
#  {'title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Transamerica', 'year': 2005, 'rating': 5.0},
#  {'title': 'Transamerica', 'year': 2005, 'rating': 5.0},
#  {'title': 'Descent, The', 'year': 2005, 'rating': 5.0},
#  {'title': 'Harry Potter and the Goblet of Fire', 'year': 2005, 'rating': 5.0},
#  {'title': 'Harry Potter and the Goblet of Fire', 'year': 2005, 'rating': 5.0},
#  {'title': 'Harry Potter and the Goblet of Fire', 'year': 2005, 'rating': 5.0},
#  {'title': 'Harry Potter and the Goblet of Fire', 'year': 2005, 'rating': 5.0},
#  {'title': 'Harry Potter and the Goblet of Fire', 'year': 2005, 'rating': 5.0},
#  {'title': 'Wallace & Gromit in The Curse of the Were-Rabbit',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Wallace & Gromit in The Curse of the Were-Rabbit',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Wallace & Gromit in The Curse of the Were-Rabbit',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Charlie and the Chocolate Factory', 'year': 2005, 'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'rating': 5.0},
#  {'title': 'Madagascar', 'year': 2005, 'rating': 5.0},
#  {'title': 'Madagascar', 'year': 2005, 'rating': 5.0},
#  {'title': "Hitchhiker's Guide to the Galaxy, The",
#   'year': 2005,
#   'rating': 5.0},
#  {'title': "Hitchhiker's Guide to the Galaxy, The",
#   'year': 2005,
#   'rating': 5.0},
#  {'title': "Hitchhiker's Guide to the Galaxy, The",
#   'year': 2005,
#   'rating': 5.0},
#  {'title': "Hitchhiker's Guide to the Galaxy, The",
#   'year': 2005,
#   'rating': 5.0},
#  {'title': "Howl's Moving Castle (Hauru no ugoku shiro)",
#   'year': 2004,
#   'rating': 5.0},
#  {'title': "Howl's Moving Castle (Hauru no ugoku shiro)",
#   'year': 2004,
#   'rating': 5.0},
#  {'title': "Howl's Moving Castle (Hauru no ugoku shiro)",
#   'year': 2004,
#   'rating': 5.0},
#  {'title': "Howl's Moving Castle (Hauru no ugoku shiro)",
#   'year': 2004,
#   'rating': 5.0},
#  {'title': "Howl's Moving Castle (Hauru no ugoku shiro)",
#   'year': 2004,
#   'rating': 5.0},
#  {'title': "Howl's Moving Castle (Hauru no ugoku shiro)",
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Life Aquatic with Steve Zissou, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Palindromes', 'year': 2004, 'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Shrek 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Shrek 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Shrek 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Shrek 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Shrek 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Shrek 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'I, Robot', 'year': 2004, 'rating': 5.0},
#  {'title': 'I, Robot', 'year': 2004, 'rating': 5.0},
#  {'title': 'I, Robot', 'year': 2004, 'rating': 5.0},
#  {'title': 'I, Robot', 'year': 2004, 'rating': 5.0},
#  {'title': 'Spider-Man 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Spider-Man 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Spider-Man 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Spider-Man 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Spider-Man 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Spider-Man 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Spider-Man 2', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'Incredibles, The', 'year': 2004, 'rating': 5.0},
#  {'title': 'National Treasure', 'year': 2004, 'rating': 5.0},
#  {'title': 'Harold and Kumar Go to White Castle', 'year': 2004, 'rating': 5.0},
#  {'title': 'Harold and Kumar Go to White Castle', 'year': 2004, 'rating': 5.0},
#  {'title': 'Motorcycle Diaries, The (Diarios de motocicleta)',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Motorcycle Diaries, The (Diarios de motocicleta)',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Motorcycle Diaries, The (Diarios de motocicleta)',
#   'year': 2004,
#   'rating': 5.0},
#  {'title': 'Troy', 'year': 2004, 'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Return of the King, The',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Last Samurai, The', 'year': 2003, 'rating': 5.0},
#  {'title': 'Last Samurai, The', 'year': 2003, 'rating': 5.0},
#  {'title': 'Last Samurai, The', 'year': 2003, 'rating': 5.0},
#  {'title': 'Matrix Revolutions, The', 'year': 2003, 'rating': 5.0},
#  {'title': 'Master and Commander: The Far Side of the World',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Master and Commander: The Far Side of the World',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Master and Commander: The Far Side of the World',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Touching the Void', 'year': 2003, 'rating': 5.0},
#  {'title': 'Touching the Void', 'year': 2003, 'rating': 5.0},
#  {'title': 'Shanghai Knights', 'year': 2003, 'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'rating': 5.0},
#  {'title': 'Terminator 3: Rise of the Machines', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'Finding Nemo', 'year': 2003, 'rating': 5.0},
#  {'title': 'X2: X-Men United', 'year': 2003, 'rating': 5.0},
#  {'title': 'X2: X-Men United', 'year': 2003, 'rating': 5.0},
#  {'title': 'X2: X-Men United', 'year': 2003, 'rating': 5.0},
#  {'title': 'X2: X-Men United', 'year': 2003, 'rating': 5.0},
#  {'title': 'X2: X-Men United', 'year': 2003, 'rating': 5.0},
#  {'title': 'X2: X-Men United', 'year': 2003, 'rating': 5.0},
#  {'title': 'Matrix Reloaded, The', 'year': 2003, 'rating': 5.0},
#  {'title': 'Matrix Reloaded, The', 'year': 2003, 'rating': 5.0},
#  {'title': 'Matrix Reloaded, The', 'year': 2003, 'rating': 5.0},
#  {'title': 'Hero (Ying xiong)', 'year': 2002, 'rating': 5.0},
#  {'title': 'Hero (Ying xiong)', 'year': 2002, 'rating': 5.0},
#  {'title': 'Hero (Ying xiong)', 'year': 2002, 'rating': 5.0},
#  {'title': 'Hero (Ying xiong)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'City of God (Cidade de Deus)', 'year': 2002, 'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Two Towers, The',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Die Another Day', 'year': 2002, 'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Spider-Man', 'year': 2002, 'rating': 5.0},
#  {'title': 'Ice Age', 'year': 2002, 'rating': 5.0},
#  {'title': 'Ice Age', 'year': 2002, 'rating': 5.0},
#  {'title': 'Ice Age', 'year': 2002, 'rating': 5.0},
#  {'title': 'Ice Age', 'year': 2002, 'rating': 5.0},
#  {'title': 'Ice Age', 'year': 2002, 'rating': 5.0},
#  {'title': 'Ice Age', 'year': 2002, 'rating': 5.0},
#  {'title': 'The Count of Monte Cristo', 'year': 2002, 'rating': 5.0},
#  {'title': 'The Count of Monte Cristo', 'year': 2002, 'rating': 5.0},
#  {'title': 'The Count of Monte Cristo', 'year': 2002, 'rating': 5.0},
#  {'title': 'The Count of Monte Cristo', 'year': 2002, 'rating': 5.0},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002,
#   'rating': 5.0},
#  {'title': 'Rabbit-Proof Fence', 'year': 2002, 'rating': 5.0},
#  {'title': 'Rabbit-Proof Fence', 'year': 2002, 'rating': 5.0},
#  {'title': 'Lilo & Stitch', 'year': 2002, 'rating': 5.0},
#  {'title': 'Lilo & Stitch', 'year': 2002, 'rating': 5.0},
#  {'title': 'Lilo & Stitch', 'year': 2002, 'rating': 5.0},
#  {'title': 'Lilo & Stitch', 'year': 2002, 'rating': 5.0},
#  {'title': 'Lilo & Stitch', 'year': 2002, 'rating': 5.0},
#  {'title': 'Lord of the Rings: The Fellowship of the Ring, The',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Fellowship of the Ring, The',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Lord of the Rings: The Fellowship of the Ring, The',
#   'year': 2001,
# ...
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spirited Away (Sen to Chihiro no kamikakushi)',
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Planet of the Apes', 'year': 2001, 'rating': 5.0},
#  {'title': 'Planet of the Apes', 'year': 2001, 'rating': 5.0},
#  {'title': 'Jay and Silent Bob Strike Back', 'year': 2001, 'rating': 5.0},
#  {'title': 'Jay and Silent Bob Strike Back', 'year': 2001, 'rating': 5.0},
#  {'title': 'Joy Ride', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#   'year': 2001,
#   'rating': 5.0},
#  {'title': 'Spy Kids', 'year': 2001, 'rating': 5.0},
#  {'title': 'Joe Dirt', 'year': 2001, 'rating': 5.0},
#  {'title': 'Mummy Returns, The', 'year': 2001, 'rating': 5.0},
#  {'title': 'Mummy Returns, The', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Shrek', 'year': 2001, 'rating': 5.0},
#  {'title': 'Lara Croft: Tomb Raider', 'year': 2001, 'rating': 5.0},
#  {'title': 'Lara Croft: Tomb Raider', 'year': 2001, 'rating': 5.0},
#  {'title': 'A.I. Artificial Intelligence', 'year': 2001, 'rating': 5.0},
#  {'title': 'A.I. Artificial Intelligence', 'year': 2001, 'rating': 5.0},
#  {'title': "O Auto da Compadecida (Dog's Will, A)",
#   'year': 2000,
#   'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': 'O Brother, Where Art Thou?', 'year': 2000, 'rating': 5.0},
#  {'title': "Emperor's New Groove, The", 'year': 2000, 'rating': 5.0},
#  {'title': "Emperor's New Groove, The", 'year': 2000, 'rating': 5.0},
#  {'title': "Emperor's New Groove, The", 'year': 2000, 'rating': 5.0},
#  {'title': "Emperor's New Groove, The", 'year': 2000, 'rating': 5.0},
#  {'title': "Emperor's New Groove, The", 'year': 2000, 'rating': 5.0},
#  {'title': "Emperor's New Groove, The", 'year': 2000, 'rating': 5.0},
#  {'title': 'Dungeons & Dragons', 'year': 2000, 'rating': 5.0},
#  {'title': 'Vertical Limit', 'year': 2000, 'rating': 5.0},
#  {'title': 'Mission: Impossible II', 'year': 2000, 'rating': 5.0},
#  {'title': 'Mission: Impossible II', 'year': 2000, 'rating': 5.0},
#  {'title': 'Mission: Impossible II', 'year': 2000, 'rating': 5.0},
#  {'title': 'Mission: Impossible II', 'year': 2000, 'rating': 5.0},
#  {'title': 'Shanghai Noon', 'year': 2000, 'rating': 5.0},
#  {'title': 'Shanghai Noon', 'year': 2000, 'rating': 5.0},
#  {'title': 'Dinosaur', 'year': 2000, 'rating': 5.0},
#  {'title': 'Titan A.E.', 'year': 2000, 'rating': 5.0},
#  {'title': 'Titan A.E.', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'X-Men', 'year': 2000, 'rating': 5.0},
#  {'title': 'Beach, The', 'year': 2000, 'rating': 5.0},
#  {'title': 'Beach, The', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Gladiator', 'year': 2000, 'rating': 5.0},
#  {'title': 'Dogma', 'year': 1999, 'rating': 5.0},
#  {'title': 'Dogma', 'year': 1999, 'rating': 5.0},
#  {'title': 'Dogma', 'year': 1999, 'rating': 5.0},
#  {'title': 'Dogma', 'year': 1999, 'rating': 5.0},
#  {'title': 'Dogma', 'year': 1999, 'rating': 5.0},
#  {'title': 'Straight Story, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Straight Story, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Straight Story, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Straight Story, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'Galaxy Quest', 'year': 1999, 'rating': 5.0},
#  {'title': 'World Is Not Enough, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'World Is Not Enough, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Toy Story 2', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Iron Giant, The', 'year': 1999, 'rating': 5.0},
#  {'title': 'Tarzan', 'year': 1999, 'rating': 5.0},
#  {'title': 'Tarzan', 'year': 1999, 'rating': 5.0},
#  {'title': 'Tarzan', 'year': 1999, 'rating': 5.0},
#  {'title': 'Tarzan', 'year': 1999, 'rating': 5.0},
#  {'title': 'Tarzan', 'year': 1999, 'rating': 5.0},
#  {'title': 'Tarzan', 'year': 1999, 'rating': 5.0},
#  {'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999,
#   'rating': 5.0},
#  {'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999,
#   'rating': 5.0},
#  {'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999,
#   'rating': 5.0},
#  {'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999,
#   'rating': 5.0},
#  {'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999,
#   'rating': 5.0},
#  {'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999,
#   'rating': 5.0},
#  ...]

# %%
# 5. Query Example
query = "Can you recommend me a recent movie with Adventure genre and rating greater than 3 with actor leonardo dicaprio"
result = qa_chain.invoke({"query": query})
print("Answer:", result['result'])
# Out:
# Answer: Based on the provided data, I can recommend a recent movie with the Adventure genre and a rating greater than 3 that features Leonardo DiCaprio.
#
# The movie is "The Revenant" (2015), which has an IMDb rating of 8.0 and belongs to the Adventure genre. Leonardo DiCaprio stars in the film, which was directed by Alejandro G. Iñárritu.
#
# Please note that this recommendation is based on the provided data and might not reflect your personal preferences or opinions.

# %%
result = kg.query("""
MATCH (a:Actor)-[:ACTED_IN]->(m:Movie)-[:IN_GENRE]->(g:Genre)
MATCH (u:User)-[r:RATED]->(m)
WHERE g.name = "Adventure"
  AND toLower(a.name) CONTAINS "leonardo dicaprio"
  AND r.rating > 3
RETURN DISTINCT m.title AS title, m.year AS year
ORDER BY m.year DESC
""")
result
# Out:
# [{'title': 'The Revenant', 'year': 2015},
#  {'title': 'Blood Diamond', 'year': 2006},
#  {'title': 'Beach, The', 'year': 2000},
#  {'title': 'Man in the Iron Mask, The', 'year': 1998}]

# %%
result = kg.query("""
MATCH (m:Movie)-[:IN_GENRE]->(g:Genre)
        WHERE g.name = "Comedy"
        RETURN m.title AS title
                  """)
result
# Out:
# [{'title': 'Two Night Stand'},
#  {'title': 'Stretch'},
#  {'title': 'Boxtrolls, The'},
#  {'title': 'This Is Where I Leave You'},
#  {'title': 'Tusk'},
#  {'title': 'St. Vincent'},
#  {'title': 'Rewrite, The'},
#  {'title': 'Big Hero 6'},
#  {'title': 'What We Do in the Shadows'},
#  {'title': "Let's Be Cops"},
#  {'title': 'Inbetweeners 2, The'},
#  {'title': 'Housebound'},
#  {'title': 'Magic in the Moonlight'},
#  {'title': 'Teenage Mutant Ninja Turtles'},
#  {'title': 'The Hundred-Foot Journey'},
#  {'title': 'Dim Sum: A Little Bit of Heart'},
#  {'title': 'Bambi Meets Godzilla'},
#  {'title': 'Laggies'},
#  {'title': 'One I Love, The'},
#  {'title': 'Pride'},
#  {'title': 'Willie & Phil'},
#  {'title': 'Planes: Fire & Rescue'},
#  {'title': 'Tammy'},
#  {'title': 'Frank'},
#  {'title': 'They Came Together'},
#  {'title': 'Think Like a Man Too'},
#  {'title': 'Trip to Italy, The'},
#  {'title': 'Words and Pictures'},
#  {'title': 'Sex Tape'},
#  {'title': 'Premature'},
#  {'title': 'And So It Goes'},
#  {'title': 'Zombeavers'},
#  {'title': 'At Middleton'},
#  {'title': 'Begin Again'},
#  {'title': 'Kelly & Cal'},
#  {'title': 'Love God?, The'},
#  {'title': 'Blended'},
#  {'title': 'Chef'},
#  {'title': 'Birdman: Or (The Unexpected Virtue of Ignorance)'},
#  {'title': '22 Jump Street'},
#  {'title': 'Back in the Day'},
#  {'title': 'Million Dollar Arm'},
#  {'title': 'A Million Ways to Die in the West'},
#  {'title': 'Mistaken for Strangers'},
#  {'title': 'Muppets Most Wanted'},
#  {'title': 'Wetlands (Feuchtgebiete)'},
#  {'title': 'We Are the Best! (Vi är bäst!)'},
#  {'title': 'Calvary'},
#  {'title': 'Witching and Bitching (Brujas de Zugarramurdi, Las)'},
#  {'title': 'Rio 2'},
#  {'title': 'Other Woman, The'},
#  {'title': 'Mulan II'},
#  {'title': 'Centenarian Who Climbed Out the Window and Vanished, The (Hundraåringen som klev ut genom fönstret och försvann)'},
#  {'title': 'Neighbors'},
#  {'title': 'Knights of Badassdom'},
#  {'title': 'Date and Switch'},
#  {'title': 'Gerontophilia'},
#  {'title': 'Someone Marry Barry'},
#  {'title': 'That Awkward Moment'},
#  {'title': 'Grand Budapest Hotel, The'},
#  {'title': 'About Last Night'},
#  {'title': 'Welcome to the Jungle'},
#  {'title': 'Mr. Peabody & Sherman'},
#  {'title': 'Obvious Child'},
#  {'title': 'Cheap Thrills'},
#  {'title': 'Barefoot'},
#  {'title': 'Bad Words'},
#  {'title': 'Veronica Mars'},
#  {'title': 'Ride Along'},
#  {'title': 'Fawlty Towers (1975'},
#  {'title': 'Yeh Jawaani Hai Deewani'},
#  {'title': 'Big Bang Theory, The ('},
#  {'title': 'Same Love, Same Rain (El mismo amor, la misma lluvia)'},
#  {'title': 'Better Living Through Chemistry'},
#  {'title': 'The Lego Movie'},
#  {'title': 'Dead Set'},
#  {'title': 'Secret Life of Walter Mitty, The'},
#  {'title': 'All is Bright'},
#  {'title': 'Anchorman 2: The Legend Continues'},
#  {'title': 'Saving Mr. Banks'},
#  {'title': 'Geography Club'},
#  {'title': 'Grudge Match'},
#  {'title': 'Wrong Cops'},
#  {'title': "Punk's Dead: SLC Punk! 2"},
#  {'title': 'Kidnapping, Caucasian Style (Kavkazskaya plennitsa)'},
#  {'title': 'Frozen'},
#  {'title': 'Wolf of Wall Street, The'},
#  {'title': 'Charlie Countryman'},
#  {'title': 'Delivery Man'},
#  {'title': 'One Piece Film: Strong World'},
#  {'title': 'Last Vegas'},
#  {'title': 'Marc Maron: Thinky Pain'},
#  {'title': 'Philomena'},
#  {'title': "Stephen Tobolowsky's Birthday Party"},
#  {'title': 'Toy Story of Terror'},
#  {'title': 'Jackass Presents: Bad Grandpa'},
#  {'title': 'Just Wright'},
#  {'title': 'Cloudy with a Chance of Meatballs 2'},
#  {'title': 'Filth'},
#  {'title': 'Enough Said'},
#  {'title': 'Don Jon'},
#  {'title': 'Crystal Fairy & the Magical Cactus and 2012'},
#  {'title': 'To Do List, The'},
#  {'title': 'Family, The'},
#  {'title': 'Austenland'},
#  {'title': 'What If'},
#  {'title': 'First Nudie Musical, The'},
#  {'title': 'In a World...'},
#  {'title': 'Planes'},
#  {'title': 'Kick-Ass 2'},
#  {'title': 'Smurfs 2, The'},
#  {'title': 'Alan Partridge: Alpha Papa'},
#  {'title': 'Grown Ups 2'},
#  {'title': "We're the Millers"},
#  {'title': 'Louis C.K.: Oh My God'},
#  {'title': 'Great Beauty, The (Grande Bellezza, La)'},
#  {'title': 'Revenge for Jolly!'},
#  {'title': 'Coffee Town'},
#  {'title': '2 Guns'},
#  {'title': 'Drinking Buddies'},
#  {'title': 'Red 2'},
#  {'title': 'Turbo'},
#  {'title': 'Joker'},
#  {'title': 'R.I.P.D.'},
#  {'title': 'Knot, The'},
#  {'title': 'The Spectacular Now'},
#  {'title': 'Lifeguard, The'},
#  {'title': 'Despicable Me 2'},
#  {'title': "World's End, The"},
#  {'title': 'Heat, The'},
#  {'title': 'Way, Way Back, The'},
#  {'title': 'Kings of Summer, The'},
#  {'title': 'Monsters University'},
#  {'title': 'Not Suitable for Children'},
#  {'title': 'Internship, The'},
#  {'title': 'Ivan Vasilievich: Back to the Future (Ivan Vasilievich menyaet professiyu)'},
#  {'title': 'Hangover Part III, The'},
#  {'title': 'Frances Ha'},
#  {'title': 'This Is the End'},
#  {'title': 'Pain & Gain'},
#  {'title': 'English Teacher, The'},
#  {'title': 'Bill Hicks: Revelations'},
#  {'title': 'Syrup'},
#  {'title': 'First Time, The'},
#  {'title': 'Spring Breakers'},
#  {'title': 'Incredible Burt Wonderstone, The'},
#  {'title': 'Croods, The'},
#  {'title': 'Admission'},
#  {'title': 'Brass Teapot, The'},
#  {'title': 'Oh Boy (A Coffee in Berlin)'},
#  {'title': 'Why Stop Now'},
#  {'title': 'Movie 43'},
#  {'title': 'Sightseers'},
#  {'title': 'Identity Thief'},
#  {'title': 'Stand Up Guys'},
#  {'title': "It's Such a Beautiful Day"},
#  {'title': 'Paul Williams Still Alive'},
#  {'title': 'Ice Age: The Great Egg-Scapade'},
#  {'title': 'Keanu'},
#  {'title': 'Neighbors 2: Sorority Rising'},
#  {'title': 'The Last Days of Emma Blank'},
#  {'title': 'Zootopia'},
#  {'title': 'The Brothers Grimsby'},
#  {'title': 'Now You See Me 2'},
#  {'title': 'Popstar: Never Stop Never Stopping'},
#  {'title': 'Teenage Mutant Ninja Turtles: Out of the Shadows'},
#  {'title': 'Finding Dory'},
#  {'title': 'Daniel Tosh: Completely Serious'},
#  {'title': "Mother's Day"},
#  {'title': 'Ghostbusters'},
#  {'title': 'Central Intelligence'},
#  {'title': 'Mike & Dave Need Wedding Dates'},
#  {'title': 'The Gay Desperado'},
#  {'title': 'The Night Before'},
#  {'title': 'Ashby'},
#  {'title': 'Hotel Transylvania 2'},
#  {'title': 'Strictly Business'},
#  {'title': 'The Dressmaker'},
#  {'title': 'Goosebumps'},
#  {'title': 'Hail, Caesar!'},
#  {'title': "Naomi and Ely's No Kiss List"},
#  {'title': 'Plan B'},
#  {'title': 'Peanuts Movie, The'},
#  {'title': 'Straight-Jacket'},
#  {'title': 'Manson Family Vacation'},
#  {'title': 'Bana Masal Anlatma'},
#  {'title': 'World of Tomorrow'},
#  {'title': 'The Ridiculous 6'},
#  {'title': "Daddy's Home"},
#  {'title': 'How to Be Single'},
#  {'title': 'Zoolander 2'},
#  {'title': 'A Very Murray Christmas'},
#  {'title': 'Pek Yakında'},
#  {'title': 'Schneider vs. Bax'},
#  {'title': 'Pride and Prejudice and Zombies'},
#  {'title': 'Sisters'},
#  {'title': 'A.R.O.G.'},
#  {'title': 'Vacation'},
#  {'title': 'Bad Asses on the Bayou'},
#  {'title': 'Search Party'},
#  {'title': 'Magic Mike XXL'},
#  {'title': '7 Days in Hell'},
#  {'title': 'The Man from U.N.C.L.E.'},
#  {'title': 'Hands in the Air'},
#  {'title': 'The Opposite Sex'},
#  {'title': "Everything's Gonna Be Great"},
#  {'title': 'Anomalisa'},
#  {'title': 'How to Make Love Like an Englishman'},
#  {'title': 'The Intern'},
#  {'title': 'Visit, The'},
#  {'title': "George Carlin: Jammin' in New York"},
#  {'title': 'American Ultra'},
#  {'title': '10 Attitudes'},
#  {'title': '29th and Gay'},
#  {'title': 'Almost Normal'},
#  {'title': 'Long-Term Relationship'},
#  {'title': 'The Big Gay Musical'},
#  {'title': 'The Biggest Fan'},
#  {'title': 'Tangerine'},
#  {'title': 'Joy'},
#  {'title': 'Fashion Victims'},
#  {'title': 'Deathgasm'},
#  {'title': 'The Dress'},
#  {'title': 'Aloha'},
#  {'title': 'Trainwreck'},
#  {'title': 'Entourage'},
#  {'title': "She's Funny That Way"},
#  {'title': 'Kung Fury'},
#  {'title': 'Spy'},
#  {'title': 'Hot Pursuit'},
#  {'title': 'The Lobster'},
#  {'title': 'Pitch Perfect 2'},
#  {'title': 'Just Before I Go'},
#  {'title': 'Ricki and the Flash'},
#  {'title': 'Welcome to Me'},
#  {'title': 'Comedy Central Roast of James Franco'},
#  {'title': 'Danny Collins'},
#  {'title': 'George Carlin: You Are All Diseased'},
#  {'title': 'George Carlin: Back in Town'},
#  {'title': 'The Good Dinosaur'},
#  {'title': 'Minions'},
#  {'title': 'Ted 2'},
#  {'title': 'A Deadly Adoption'},
#  {'title': 'The Secret Life of Pets'},
#  {'title': 'Zenon: Z3'},
#  {'title': 'Zenon: The Zequel'},
#  {'title': 'Zenon: Girl of the 21st Century'},
#  {'title': 'Pixels'},
#  {'title': 'Inside Out'},
#  {'title': 'Unfinished Business'},
#  {'title': 'The Cobbler'},
#  {'title': 'Focus'},
#  {'title': 'Reality'},
#  {'title': 'The Second Best Exotic Marigold Hotel'},
#  {'title': "George Carlin: It's Bad for Ya!"},
#  {'title': 'Stormy Weather'},
#  {'title': 'The Wedding Ringer'},
#  {'title': 'An Evening with Robin Williams'},
#  {'title': 'The Clowns'},
#  {'title': 'The D Train'},
#  {'title': 'Dope'},
#  {'title': 'The Overnight'},
#  {'title': 'People, Places, Things'},
#  {'title': 'Paul Blart: Mall Cop 2'},
#  {'title': 'Lovesick'},
#  {'title': 'Get Hard'},
#  {'title': 'Samba'},
#  {'title': 'George Carlin: Life Is Worth Losing'},
#  {'title': "While We're Young"},
#  {'title': 'Home'},
#  {'title': 'Robin Williams: Weapons of Self Destruction'},
#  {'title': 'Shriek If You Know What I Did Last Friday the Thirteenth'},
#  {'title': 'The Interview'},
#  {'title': 'Kingsman: The Secret Service'},
#  {'title': 'Into the Woods'},
#  {'title': 'Top Five'},
#  {'title': 'Men, Women & Children'},
#  {'title': 'Night at the Museum: Secret of the Tomb'},
#  {'title': 'Comet'},
#  {'title': 'Drunk Stoned Brilliant Dead: The Story of the National Lampoon'},
#  {'title': "I'll See You in My Dreams"},
#  {'title': 'Louis C.K.: Live at The Comedy Store'},
#  {'title': "Operation 'Y' & Other Shurik's Adventures"},
#  {'title': 'The DUFF'},
#  {'title': 'The Passionate Plumber'},
#  {'title': 'Elsa & Fred'},
#  {'title': 'Deadpool'},
#  {'title': 'Inherent Vice'},
#  {'title': 'Sex Ed'},
#  {'title': 'Wild Tales'},
#  {'title': 'Werner - Beinhart!'},
#  {'title': 'Dumb and Dumber To'},
#  {'title': 'The Longest Week'},
#  {'title': 'Simpsons: The Longest Daycare, The'},
#  {'title': 'Life Partners'},
#  {'title': 'Drive Hard'},
#  {'title': 'Playing It Cool'},
#  {'title': 'Bill Hicks: Relentless'},
#  {'title': 'Dear White People'},
#  {'title': 'Hello Ladies: The Movie'},
#  {'title': 'Penguins of Madagascar'},
#  {'title': 'Horrible Bosses 2'},
#  {'title': 'Trailer Park Boys: Live at the North Pole'},
#  {'title': 'The Voices'},
#  {'title': 'Dilemma, The'},
#  {'title': 'Trip, The'},
#  {'title': 'Ricky Gervais Live 4: Science'},
#  {'title': "What Women Want (a.k.a. I Know a Woman's Heart)"},
#  {'title': 'Home Alone 4'},
#  {'title': 'No Strings Attached'},
#  {'title': 'Paul'},
#  {'title': 'Emma'},
#  {'title': 'Cedar Rapids'},
#  {'title': 'Burke and Hare'},
#  {'title': 'Gnomeo & Juliet'},
#  {'title': 'Rare Exports: A Christmas Tale (Rare Exports)'},
#  {'title': 'Last Circus, The (Balada triste de trompeta) (Sad Trumpet Ballad, A)'},
#  {'title': 'Little Fockers'},
#  {'title': "Gulliver's Travels"},
#  {'title': 'Zerophilia'},
#  {'title': 'How Do You Know'},
#  {'title': 'Goat, The'},
#  {'title': 'Made in Dagenham'},
#  {'title': 'Yogi Bear'},
#  {'title': 'Tucker & Dale vs Evil'},
#  {'title': 'Haunted House, The'},
#  {'title': 'Cops'},
#  {'title': 'Play House, The'},
#  {'title': 'Paleface, The'},
#  {'title': 'Green Hornet, The'},
#  {'title': 'Boat, The'},
#  {'title': "Family Guy Presents: It's a Trap"},
#  {'title': 'Win Win'},
#  {'title': 'Boy'},
#  {'title': 'Diary of a Wimpy Kid: Rodrick Rules'},
#  {'title': "Henry's Crime"},
#  {'title': 'Hop'},
#  {'title': 'Arthur'},
#  {'title': 'American: The Bill Hicks Story'},
#  {'title': 'Rio'},
#  {'title': 'Louis C.K.: Chewed Up'},
#  {'title': 'Louis C.K.: Hilarious'},
#  {'title': 'Louis C.K.: Shameless'},
#  {'title': 'Rango'},
#  {'title': 'Take Me Home Tonight'},
#  {'title': 'Hall Pass'},
#  {'title': 'Summer Wars (Samâ wôzu)'},
#  {'title': 'Mars Needs Moms'},
#  {'title': 'Just Go with It'},
#  {'title': 'Super'},
#  {'title': 'Big Mommas: Like Father, Like Son'},
#  {'title': 'Going the Distance'},
#  {'title': 'Machete'},
#  {'title': 'Vampires Suck'},
#  {'title': 'Switch, The'},
#  {'title': "It's Kind of a Funny Story"},
#  {'title': 'Voyeur (Abel)'},
#  {'title': 'Middle Men'},
#  {'title': 'Flipped'},
#  {'title': 'Easy A'},
#  {'title': "I'm Still Here"},
#  {'title': 'Patrik Age 1.5 (Patrik 1,5)'},
#  {'title': 'Dinner for Schmucks'},
#  {'title': 'Northerners, The (De noorderlingen)'},
#  {'title': 'Winnebago Man'},
#  {'title': "No. 1 Ladies' Detective Agency, The"},
#  {'title': 'Kids Are All Right, The'},
#  {'title': 'Knight and Day'},
#  {'title': 'Joneses, The'},
#  {'title': 'Scott Pilgrim vs. the World'},
#  {'title': 'Rebound, The'},
#  {'title': 'Other Guys, The'},
#  {'title': 'First Beautiful Thing, The (La prima cosa bella)'},
#  {'title': 'Megamind'},
#  {'title': 'Morning Glory'},
#  {'title': 'Bunny and the Bull'},
#  {'title': 'Love and Other Drugs'},
#  {'title': 'Tiny Furniture'},
#  {'title': 'Tangled'},
#  {'title': 'Romantics, The'},
#  {'title': 'Rubber'},
#  {'title': 'Kaboom'},
#  {'title': 'Love Is Colder Than Death (Liebe ist kälter als der Tod)'},
#  {'title': 'You Will Meet a Tall Dark Stranger'},
#  {'title': 'You Again'},
#  {'title': 'Life as We Know It'},
#  {'title': 'Due Date'},
#  {'title': 'Red'},
#  {'title': 'Jackass 3D'},
#  {'title': 'Exit Through the Gift Shop'},
#  {'title': 'This Is the Army'},
#  {'title': 'Cyrus'},
#  {'title': 'Four Lions'},
#  {'title': 'Date Night'},
#  {'title': 'Kick-Ass'},
#  {'title': 'Defendor'},
#  {'title': 'Diary of a Wimpy Kid'},
#  {'title': 'Aria'},
#  {'title': 'Death at a Funeral'},
#  {'title': 'Apprenticeship of Duddy Kravitz, The'},
#  {'title': 'Women in Trouble'},
#  {'title': 'Micmacs (Micmacs à tire-larigot)'},
#  {'title': 'Hot Tub Time Machine'},
#  {'title': "Slammin' Salmon, The"},
#  {'title': 'Greenberg'},
#  {'title': "Will Ferrell: You're Welcome America - A Final Night with George W Bush"},
#  {'title': 'Our Family Wedding'},
#  {'title': 'Bounty Hunter, The'},
#  {'title': 'Leaves of Grass'},
#  {'title': "She's Out of My League"},
#  {'title': 'South Park: Imaginationland'},
#  {'title': 'Despicable Me'},
#  {'title': 'Grown Ups'},
#  {'title': "Sorcerer's Apprentice, The"},
#  {'title': 'Shrek Forever After (a.k.a. Shrek: The Final Chapter)'},
#  {'title': 'TiMER'},
#  {'title': 'Get Him to the Greek'},
#  {'title': 'Back-up Plan, The'},
#  {'title': '41-Year-Old Virgin Who Knocked Up Sarah Marshall and Felt Superbad About It, The'},
#  {'title': 'A-Team, The'},
#  {'title': 'Toy Story 3'},
#  {'title': 'Ricky Gervais Live 3: Fame'},
#  {'title': 'Red Chapel, The (Røde kapel, Det)'},
#  {'title': 'Cemetery Junction'},
#  {'title': 'Killers'},
#  {'title': 'Artists and Models'},
#  {'title': 'Please Give'},
#  {'title': 'Sex and the City 2'},
#  {'title': 'Ricky Gervais Live: Animals'},
#  {'title': 'Leap Year'},
#  {'title': 'Youth in Revolt'},
#  {'title': 'American Pie Presents: The Book of Love (American Pie 7: The Book of Love)'},
#  {'title': 'Alvin and the Chipmunks: The Squeakquel'},
#  {'title': 'Looking for Eric'},
#  {'title': "It's Complicated"},
#  {'title': 'Make the Yuletide Gay'},
#  {'title': 'Did You Hear About the Morgans?'},
#  {'title': 'Red Chapel (Røde kapel)'},
#  {'title': 'Old Dogs'},
#  {'title': 'Planet 51'},
#  {'title': 'Fly, The (Légy, A)'},
#  {'title': 'Billy Blazes, Esq.'},
#  {'title': 'Partly Cloudy'},
#  {'title': 'Gentlemen of Fortune (Dzhentlmeny udachi)'},
#  {'title': 'Tooth Fairy'},
#  {'title': 'Room, The'},
#  {'title': 'Shades of Ray'},
#  {'title': 'Cop Out'},
#  {'title': 'Spy Next Door, The'},
#  {'title': "Valentine's Day"},
#  {'title': 'Legend of the Red Dragon (a.k.a. New Legend of Shaolin, The) (Hong Xi Guan: Zhi Shao Lin wu zu)'},
#  {'title': 'I Love You Phillip Morris'},
#  {'title': 'First Day of the Rest of Your Life, The (Le premier jour du reste de ta vie)'},
#  {'title': 'Zach Galifianakis: Live at the Purple Onion'},
#  {'title': 'When in Rome'},
#  {'title': '3 Idiots'},
#  {'title': 'Soul Kitchen'},
#  {'title': 'Piranha 3DD (a.k.a. Piranha DD)'},
#  {'title': 'Sleepwalk with Me'},
#  {'title': 'Conception'},
#  {'title': 'Bachelorette'},
#  {'title': 'Pitch Perfect'},
#  {'title': "That's My Boy"},
#  {'title': 'Robot & Frank'},
#  {'title': 'Lola Versus'},
#  {'title': 'Kismet'},
#  {'title': 'Hotel Transylvania'},
#  {'title': 'Seven Psychopaths'},
#  {'title': 'Liberal Arts'},
#  {'title': "'Hellboy': The Seeds of Creation"},
#  {'title': 'Here Comes the Boom'},
#  {'title': 'Mental'},
#  {'title': 'Wreck-It Ralph'},
#  {'title': 'Silver Linings Playbook'},
#  {'title': 'Jackass 3.5'},
#  {'title': 'Student of the Year'},
#  {'title': '10 Years'},
#  {'title': 'Vamps'},
#  {'title': 'Nature Calls'},
#  {'title': 'Baby Take a Bow'},
#  {'title': 'Rebecca of Sunnybrook Farm'},
#  {'title': 'Fantastic Fear of Everything, A'},
#  {'title': 'Just Around the Corner'},
#  {'title': 'Paperman'},
#  {'title': 'Hyde Park on Hudson'},
#  {'title': 'How to Make Love to a Woman'},
#  {'title': 'Wrong'},
#  {'title': 'Our Little Girl'},
#  {'title': 'Warm Bodies'},
#  {'title': 'Guilt Trip, The'},
#  {'title': 'John Dies at the End'},
#  {'title': 'Parental Guidance'},
#  {'title': 'Stand Up and Cheer!'},
#  {'title': 'Quartet'},
#  {'title': 'Jeff, Who Lives at Home'},
#  {'title': '21 Jump Street'},
#  {'title': 'Casa de mi Padre'},
#  {'title': 'This Means War'},
#  {'title': 'Trailer Park Boys'},
#  {'title': 'Big Year, The'},
#  {'title': 'Goon'},
#  {'title': 'Starbuck'},
#  {'title': 'Mirror Mirror'},
#  {'title': 'Think Like a Man'},
#  {'title': 'Best Exotic Marigold Hotel, The'},
#  {'title': 'Five-Year Engagement, The'},
#  {'title': 'Cabin in the Woods, The'},
#  {'title': 'Iron Sky'},
#  {'title': 'American Reunion (American Pie 4)'},
#  {'title': 'Three Stooges, The'},
#  {'title': 'God Bless America'},
#  {'title': 'Pirates! Band of Misfits, The'},
#  {'title': 'Bernie'},
#  {'title': 'Dark Shadows'},
#  {'title': 'Dictator, The'},
#  {'title': 'Men in Black III (M.III.B.) (M.I.B.³)'},
#  {'title': 'Safety Not Guaranteed'},
#  {'title': "Madagascar 3: Europe's Most Wanted"},
#  {'title': "Your Sister's Sister"},
#  {'title': 'Sound of Noise'},
#  {'title': 'Moonrise Kingdom'},
#  {'title': 'Wanderlust'},
#  {'title': 'Thousand Words, A'},
#  {'title': 'Presto'},
#  {'title': 'Seeking a Friend for the End of the World'},
#  {'title': 'Rock of Ages'},
#  {'title': 'To Rome with Love'},
#  {'title': "What to Expect When You're Expecting"},
#  {'title': 'Ted'},
#  {'title': 'Giant Mechanical Man, The'},
#  {'title': 'One Man Band'},
#  {'title': 'Jack-Jack Attack'},
#  {'title': 'Ruby Sparks'},
#  {'title': 'For the Birds'},
#  {'title': 'Terminal USA'},
#  {'title': '2 Days in New York'},
#  {'title': 'Watch, The'},
#  {'title': 'Ice Age 4: Continental Drift'},
#  {'title': 'Celeste and Jesse Forever (Celeste & Jesse Forever)'},
#  {'title': 'ParaNorman'},
#  {'title': 'Campaign, The'},
#  {'title': 'Immature, The (Immaturi)'},
#  {'title': 'Puss in Boots'},
#  {'title': 'Tower Heist'},
#  {'title': 'Jack and Jill'},
#  {'title': 'Carnage'},
#  {'title': 'Johnny English Reborn'},
#  {'title': "What's Your Number?"},
#  {'title': 'Arthur Christmas'},
#  {'title': 'Descendants, The'},
#  {'title': 'Muppets, The'},
#  {'title': 'Rum Diary, The'},
#  {'title': 'Little Colonel, The'},
#  {'title': 'Asterix and the Vikings (Astérix et les Vikings)'},
#  {'title': 'Sitter, The'},
#  {'title': 'Joyful Noise'},
#  {'title': 'Revenant, The'},
#  {'title': 'Chill Out! (Descongélate!)'},
#  {'title': 'Young Adult'},
#  {'title': "New Year's Eve"},
#  {'title': 'Sherlock Holmes: A Game of Shadows'},
#  {'title': 'Salvation Boulevard'},
#  {'title': 'Friends with Kids'},
#  {'title': 'We Bought a Zoo'},
#  {'title': 'Hearts of the West'},
#  {'title': 'Kokowääh'},
#  {'title': 'Journey 2: The Mysterious Island'},
#  {'title': 'For a Good Time, Call...'},
#  {'title': 'Project X'},
#  {'title': 'Love Wrecked'},
#  {'title': 'Intouchables'},
#  {'title': 'One for the Money'},
#  {'title': 'Louis C.K.: Live at the Beacon Theater'},
#  {'title': 'Dylan Moran Live: What It Is'},
#  {'title': 'Dylan Moran: Monster'},
#  {'title': 'Dylan Moran: Like, Totally'},
#  {'title': 'Kung Fu Panda 2'},
#  {'title': 'Submarine'},
#  {'title': 'Everything Must Go'},
#  {'title': 'Hangover Part II, The'},
#  {'title': 'Attack the Block'},
#  {'title': 'Midnight in Paris'},
#  {'title': 'Something Borrowed'},
#  {'title': 'Bridesmaids'},
#  {'title': 'Cars 2'},
#  {'title': 'Horrible Bosses'},
#  {'title': 'Larry Crowne'},
#  {'title': 'Your Highness'},
#  {'title': 'Bad Teacher'},
#  {'title': "Mr. Popper's Penguins"},
#  {'title': 'Elektra Luxx'},
#  {'title': 'Prom'},
#  {'title': 'Rocky VI ('},
#  {'title': 'Very Harold & Kumar 3D Christmas, A'},
#  {'title': 'Fright Night'},
#  {'title': '30 Minutes or Less'},
#  {'title': 'Change-Up, The'},
#  {'title': 'Dylan Dog: Dead of Night'},
#  {'title': 'Smurfs, The'},
#  {'title': 'Our Idiot Brother'},
#  {'title': 'Friends with Benefits'},
#  {'title': 'Winnie the Pooh'},
#  {'title': "Mike's New Car"},
#  {'title': 'Crazy, Stupid, Love.'},
#  {'title': 'Guard, The'},
#  {'title': 'Footloose'},
#  {'title': 'Myth of the American Sleepover, The'},
#  {'title': 'The Artist'},
#  {'title': '50/50'},
#  {'title': "I Don't Know How She Does It"},
#  {'title': 'April Love'},
#  {'title': 'Chinese Take-Out (Chinese Take-Away) (Un cuento chino)'},
#  {'title': 'Inbetweeners Movie, The'},
#  {'title': "It's the Great Pumpkin, Charlie Brown"},
#  {'title': 'Meet Dave'},
#  {'title': 'Space Chimps'},
#  {'title': 'Step Brothers'},
#  {'title': 'Vicky Cristina Barcelona'},
#  {'title': 'Absolute Giganten'},
#  {'title': 'Pineapple Express'},
#  {'title': 'Flesh Gordon'},
#  {'title': "You Don't Mess with the Zohan"},
#  {'title': 'Chaos Theory'},
#  {'title': 'Hancock'},
#  {'title': 'Get Smart'},
#  {'title': 'Young People Fucking (a.k.a. YPF)'},
#  {'title': 'Wackness, The'},
#  {'title': 'Futurama: The Beast with a Billion Backs'},
#  {'title': 'Mamma Mia!'},
#  {'title': 'How to Lose Friends & Alienate People'},
#  {'title': 'Six Shooter'},
#  {'title': "Nick and Norah's Infinite Playlist"},
#  {'title': 'Ghost Town'},
#  {'title': 'FLCL'},
#  {'title': 'Dead Leaves'},
#  {'title': 'Zack and Miri Make a Porno'},
#  {'title': 'Magicians'},
#  {'title': 'Synecdoche, New York'},
#  {'title': 'Angus, Thongs and Perfect Snogging'},
#  {'title': 'Tropic Thunder'},
#  {'title': 'High School Musical 2'},
#  {'title': 'Sisterhood of the Traveling Pants 2, The'},
#  {'title': 'Disaster Movie'},
#  {'title': 'Burn After Reading'},
#  {'title': 'House Bunny, The'},
#  {'title': 'Spirit, The'},
#  {'title': 'Onion Movie, The'},
#  {'title': 'Women, The'},
#  {'title': 'Igor'},
#  {'title': 'Shrek the Halls'},
#  {'title': 'Friend of Mine, A (Ein Freund von mir)'},
#  {'title': "Wallace and Gromit in 'A Matter of Loaf and Death'"},
#  {'title': 'Bolt'},
#  {'title': 'Four Christmases'},
#  {'title': 'Waiter (Ober)'},
#  {'title': 'Gypsy'},
#  {'title': 'Role Models'},
#  {'title': 'Madagascar: Escape 2 Africa'},
#  {'title': "Futurama: Bender's Game"},
#  {'title': 'Beverly Hills Chihuahua'},
#  {'title': 'Camp Rock'},
#  {'title': 'Sex Drive'},
#  {'title': 'Soul Men'},
#  {'title': "He's Just Not That Into You"},
#  {'title': 'Paul Blart: Mall Cop'},
#  {'title': "Tyler Perry's Madea Goes to Jail"},
#  {'title': 'Away We Go'},
#  {'title': 'Funny People'},
#  {'title': 'Mystery Team'},
#  {'title': 'My Name Is Bruce'},
#  {'title': 'Numbskull Emptybrook (Uuno Turhapuro)'},
#  {'title': 'Futurama: Into the Wild Green Yonder'},
#  {'title': "Blackadder's Christmas Carol"},
#  {'title': 'Blackadder Back & Forth'},
#  {'title': 'Bedtime Stories'},
#  {'title': 'Choke'},
#  {'title': 'Yes Man'},
#  {'title': 'Bride Wars'},
#  {'title': 'Tale of Despereaux, The'},
#  {'title': 'Poultrygeist: Night of the Chicken Dead'},
#  {'title': 'Marley & Me'},
#  {'title': 'Great Buck Howard, The'},
#  {'title': 'Night at the Museum: Battle of the Smithsonian'},
#  {'title': 'Fanboys'},
#  {'title': 'Pirate Radio'},
#  {'title': '17 Again'},
#  {'title': 'In the Loop'},
#  {'title': 'Crank: High Voltage'},
#  {'title': 'Sunshine Cleaning'},
#  {'title': 'Kung Fu Panda: Secrets of the Furious Five'},
#  {'title': 'Confessions of a Shopaholic'},
#  {'title': 'Adventureland'},
#  {'title': 'Observe and Report'},
#  {'title': 'Good, the Bad, the Weird, The (Joheunnom nabbeunnom isanghannom)'},
#  {'title': 'Pink Panther 2, The'},
#  {'title': "Dr. Horrible's Sing-Along Blog"},
#  {'title': 'I Love You, Man'},
#  {'title': '(500) Days of Summer'},
#  {'title': 'Hood of Horror'},
#  {'title': 'Daria: Is It College Yet?'},
#  {'title': 'Brüno (Bruno)'},
#  {'title': 'Ice Age: Dawn of the Dinosaurs'},
#  {'title': 'Ghosts of Girlfriends Past'},
#  {'title': 'Whatever Works'},
#  {'title': 'New in Town'},
#  {'title': 'Dead Snow (Død snø)'},
#  {'title': 'Fired Up'},
#  {'title': 'Hangover, The'},
#  {'title': 'Year One'},
#  {'title': 'Proposal, The'},
#  {'title': 'Land of the Lost'},
#  {'title': 'Clique, The'},
#  {'title': "Shall We Kiss? (Un baiser s'il vous plait)"},
#  {'title': 'Brothers Bloom, The'},
#  {'title': 'Dance Flick'},
#  {'title': 'Drag Me to Hell'},
#  {'title': 'Men Who Stare at Goats, The'},
#  {'title': "Jennifer's Body"},
#  {'title': 'Extract'},
#  {'title': 'Informant!, The'},
#  {'title': 'Frequently Asked Questions About Time Travel'},
#  {'title': 'Curiosity of Chance, The'},
#  {'title': 'Bronson'},
#  {'title': 'Taking Woodstock'},
#  {'title': 'Post Grad'},
#  {'title': "To Each His Own Cinema (Chacun son cinéma ou Ce petit coup au coeur quand la lumière s'éteint et que le film commence)"},
#  {'title': 'Goods: Live Hard, Sell Hard, The'},
#  {'title': 'Deal, The'},
#  {'title': 'Gigantic'},
#  {'title': 'I Love You, Beth Cooper'},
#  {'title': 'Cold Souls'},
#  {'title': 'Julie & Julia'},
#  {'title': 'Ugly Truth, The'},
#  {'title': 'High Hopes'},
#  {'title': 'Fantastic Mr. Fox'},
#  {'title': 'Gentlemen Broncos'},
#  {'title': 'Big Fan'},
#  {'title': 'Good Hair'},
#  {'title': 'Black Dynamite'},
#  {'title': "Cirque du Freak: The Vampire's Assistant"},
#  {'title': 'Vampire Girl vs. Frankenstein Girl (Kyûketsu Shôjo tai Shôjo Furanken)'},
#  {'title': 'Monsters vs Aliens: Mutant Pumpkins from Outer Space'},
#  {'title': 'Mary and Max'},
#  {'title': 'Reckless'},
#  {'title': 'Couples Retreat'},
#  {'title': 'I Sell the Dead'},
#  {'title': 'Zombieland'},
#  {'title': 'A-Haunting We Will Go'},
#  {'title': 'Next Day Air'},
#  {'title': 'Haunted World of El Superbeasto, The'},
#  {'title': 'Invention of Lying, The'},
#  {'title': 'Whip It'},
#  {'title': 'City Island'},
#  {'title': 'Serious Man, A'},
#  {'title': "World's Greatest Dad"},
#  {'title': 'Sleeping Dogs Lie (a.k.a. Stay)'},
#  {'title': 'Santa Clause 3: The Escape Clause, The'},
#  {'title': 'Flushed Away'},
#  {'title': 'Happy Feet'},
#  {'title': 'For Your Consideration'},
#  {'title': 'Tenacious D in The Pick of Destiny'},
#  {'title': 'Holiday, The'},
#  {'title': '10 Items or Less'},
#  {'title': "Charlotte's Web"},
#  {'title': "National Lampoon's Van Wilder: The Rise of Taj"},
#  {'title': 'History Boys, The'},
#  {'title': 'Bothersome Man, The (Brysomme mannen, Den)'},
#  {'title': 'Decameron, The (Decameron, Il)'},
#  {'title': 'American Pie Presents The Naked Mile (American Pie 5: The Naked Mile)'},
#  {'title': 'Linda Linda Linda'},
#  {'title': 'House (Hausu)'},
#  {'title': 'Kenny'},
#  {'title': 'Catch and Release'},
#  {'title': 'Waitress'},
#  {'title': 'Epic Movie'},
#  {'title': 'Norbit'},
#  {'title': 'Because I Said So'},
#  {'title': 'Boss of It All, The (Direktøren for det hele)'},
#  {'title': 'Magical Mystery Tour'},
#  {'title': "It's a Boy Girl Thing"},
#  {'title': 'Reno 911!: Miami'},
#  {'title': 'Music and Lyrics'},
#  {'title': 'Gray Matters'},
#  {'title': 'Street Trash'},
#  {'title': 'Hot Fuzz'},
#  {'title': 'Canterbury Tales, The (I racconti di Canterbury)'},
#  {'title': 'Wild Hogs'},
#  {'title': 'Host, The (Gwoemul)'},
#  {'title': 'Priceless (Hors de prix)'},
#  {'title': 'Meet the Robinsons'},
#  {'title': 'Blades of Glory'},
#  {'title': 'TMNT (Teenage Mutant Ninja Turtles)'},
#  {'title': 'Puccini for Beginners'},
#  {'title': 'Aqua Teen Hunger Force Colon Movie Film for Theaters'},
#  {'title': 'How the Grinch Stole Christmas!'},
#  {'title': "It's a Very Merry Muppet Christmas Movie"},
#  {'title': 'In the Land of Women'},
#  {'title': "Mr. Bean's Holiday"},
#  {'title': 'Woman on the Beach (Haebyeonui yeoin)'},
#  {'title': 'Big Nothing'},
#  {'title': 'Shrek the Third'},
#  {'title': 'Hairspray'},
#  {'title': 'Knocked Up'},
#  {'title': 'Sylvia Scarlett'},
#  {'title': 'Cashback'},
#  {'title': "Surf's Up"},
#  {'title': "Pirates of the Caribbean: At World's End"},
#  {'title': 'Eagle vs Shark'},
#  {'title': 'O Lucky Man!'},
#  {'title': 'Fido'},
#  {'title': 'I Now Pronounce You Chuck and Larry'},
#  {'title': 'Dorian Blues'},
#  {'title': 'Sterile Cuckoo, The'},
#  {'title': 'Stardust'},
#  {'title': 'Hot Rod'},
#  {'title': 'Death at a Funeral'},
#  {'title': 'Evan Almighty'},
#  {'title': 'License to Wed'},
#  {'title': '12:08 East of Bucharest (A fost sau n-a fost?)'},
#  {'title': 'Superbad'},
#  {'title': 'Rush Hour 3'},
#  {'title': 'Balls of Fury'},
#  {'title': 'No Reservations'},
#  {'title': 'Simpsons Movie, The'},
#  {'title': 'Charlie Bartlett'},
#  {'title': 'Bratz: The Movie'},
#  {'title': 'You Kill Me'},
#  {'title': 'My Best Friend (Mon meilleur ami)'},
#  {'title': 'Evening with Kevin Smith, An'},
#  {'title': "Shoot 'Em Up"},
#  {'title': 'I Could Never Be Your Woman'},
#  {'title': 'Hunting Party, The'},
#  {'title': 'Nanny Diaries, The'},
#  {'title': 'Sydney White'},
#  {'title': 'Rocket Science'},
#  {'title': 'Daddy Day Camp'},
#  {'title': 'Behind the Mask: The Rise of Leslie Vernon'},
#  {'title': 'Weirdsville'},
#  {'title': 'Lars and the Real Girl'},
#  {'title': "Tyler Perry's Why Did I Get Married?"},
#  {'title': 'The Jane Austen Book Club'},
#  {'title': 'Game Plan, The'},
#  {'title': 'Good Luck Chuck'},
#  {'title': 'Cashback'},
#  {'title': 'Darjeeling Limited, The'},
#  {'title': 'Dan in Real Life'},
#  {'title': 'Heartbreak Kid, The'},
#  {'title': 'Southland Tales'},
#  {'title': "Mr. Magorium's Wonder Emporium"},
#  {'title': 'Murder Party'},
#  {'title': 'Smiley Face'},
#  {'title': 'Martian Child'},
#  {'title': 'Chilly Scenes of Winter (Head Over Heels)'},
#  {'title': 'Bee Movie'},
#  {'title': 'Be Kind Rewind'},
#  {'title': 'Bucket List, The'},
#  {'title': 'Juno'},
#  {'title': 'Walk Hard: The Dewey Cox Story'},
#  {'title': "Charlie Wilson's War"},
#  {'title': 'Enchanted'},
#  {'title': 'Alvin and the Chipmunks'},
#  {'title': "Futurama: Bender's Big Score"},
#  {'title': 'Savages, The'},
#  {'title': 'Meet the Spartans'},
#  {'title': 'In Bruges'},
#  {'title': 'Arranged'},
#  {'title': 'Girl Who Leapt Through Time, The (Toki o kakeru shôjo)'},
#  {'title': "Band's Visit, The (Bikur Ha-Tizmoret)"},
#  {'title': '27 Dresses'},
#  {'title': 'P.S. I Love You'},
#  {'title': 'Dedication'},
#  {'title': 'Drained (O cheiro do Ralo)'},
#  {'title': 'Penelope'},
#  {'title': 'Love Guru, The'},
#  {'title': 'Horton Hears a Who!'},
#  {'title': 'Witless Protection'},
#  {'title': 'Semi-Pro'},
#  {'title': 'Definitely, Maybe'},
#  {'title': 'Art of Negative Thinking, The (Kunsten å tenke negativt)'},
#  {'title': "Fool's Gold"},
#  {'title': 'Teeth'},
#  {'title': 'Caramel (Sukkar banat)'},
#  {'title': 'Forbidden Kingdom, The'},
#  {'title': 'Happy-Go-Lucky'},
#  {'title': 'Religulous'},
#  {'title': 'Son of Rambow'},
#  {'title': 'Super High Me'},
#  {'title': "Nim's Island"},
#  {'title': 'Forgetting Sarah Marshall'},
#  {'title': 'Superhero Movie'},
#  {'title': 'Harold & Kumar Escape from Guantanamo Bay'},
#  {'title': 'Leatherheads'},
#  {'title': 'What Just Happened'},
#  {'title': 'Drillbit Taylor'},
#  {'title': 'Grand, The'},
#  {'title': 'Sex and the City'},
#  {'title': 'Ex Drummer'},
#  {'title': 'Kung Fu Panda'},
#  {'title': 'War, Inc.'},
#  {'title': 'Indiana Jones and the Kingdom of the Crystal Skull'},
#  {'title': 'American Pie Presents Beta House (American Pie 6: Beta House)'},
#  {'title': 'What Happens in Vegas...'},
#  {'title': 'Delirious'},
#  {'title': 'Baby Mama'},
#  {'title': 'Mister Lonely'},
#  {'title': 'Made of Honor'},
#  {'title': 'Man, The'},
#  {'title': 'Waiting...'},
#  {'title': 'Go West'},
#  {'title': '200 Motels'},
#  {'title': 'Family Guy Presents Stewie Griffin: The Untold Story'},
#  {'title': 'Corpse Bride'},
#  {'title': 'Valiant'},
#  {'title': 'Asterix & Obelix vs. Caesar (Astérix et Obélix contre César)'},
#  {'title': '40-Year-Old Virgin, The'},
#  {'title': 'Everything Is Illuminated'},
#  {'title': 'Just Like Heaven'},
#  {'title': 'Brothers Grimm, The'},
#  {'title': 'Bad News Bears'},
#  {'title': 'Sky High'},
#  {'title': 'Must Love Dogs'},
#  {'title': 'Aristocrats, The'},
#  {'title': 'Wedding Crashers'},
#  {'title': 'Happy Endings'},
#  {'title': 'Russian Dolls (Les poupées russes)'},
#  {'title': 'Junebug'},
#  {'title': 'The Chumscrubber'},
#  {'title': 'Dukes of Hazzard, The'},
#  {'title': 'Deuce Bigalow: European Gigolo'},
#  {'title': 'This Is My Life'},
#  {'title': 'Georgy Girl'},
#  {'title': 'Sholay'},
#  {'title': 'Broken Flowers'},
#  {'title': 'Saint Ralph'},
#  {'title': 'Lords of Dogtown'},
#  {'title': 'Sisterhood of the Traveling Pants, The'},
#  {'title': 'Mr. & Mrs. Smith'},
#  {'title': 'At the Circus'},
#  {'title': 'Room Service'},
#  {'title': 'Unmarried Woman, An'},
#  {'title': 'Rebound'},
#  {'title': 'Bewitched'},
#  {'title': 'Herbie: Fully Loaded'},
#  {'title': 'Edukators, The (Die Fetten Jahre sind vorbei)'},
#  {'title': 'Me and You and Everyone We Know'},
#  {'title': 'Keeping Mum'},
#  {'title': 'Casanova'},
#  {'title': 'Ringer, The'},
#  {'title': 'Richard Pryor: Live in Concert'},
#  {'title': 'Hoodwinked!'},
#  {'title': 'Looking for Comedy in the Muslim World'},
#  {'title': "Grandma's Boy"},
#  {'title': 'Last Holiday'},
#  {'title': 'Little Manhattan'},
#  {'title': 'On Probation (Tiempo de Valientes)'},
#  {'title': 'Cul-de-sac'},
#  {'title': "Project A ('A' gai waak)"},
#  {'title': 'Ice Harvest, The'},
#  {'title': 'Sarah Silverman: Jesus Is Magic'},
#  {'title': 'Family Stone, The'},
#  {'title': 'Slim Susie (Smala Sussie)'},
#  {'title': 'Matador, The'},
#  {'title': 'Mozart and the Whale'},
#  {'title': 'Dona Flor and Her Two Husbands (Dona Flor e Seus Dois Maridos)'},
#  {'title': 'Cheaper by the Dozen 2'},
#  {'title': 'Fun with Dick and Jane'},
#  {'title': 'Rumor Has It...'},
#  {'title': 'Producers, The'},
#  {'title': 'Transamerica'},
#  {'title': "Love on the Run (Amour en fuite, L')"},
#  {'title': 'Wild Zero'},
#  {'title': 'Chicken Little'},
#  {'title': 'Match Factory Girl, The (Tulitikkutehtaan tyttö)'},
#  {'title': 'Just Friends'},
#  {'title': 'One-Way Ticket to Mombasa (Menolippu Mombasaan)'},
#  {'title': 'Dinner with Friends'},
#  {'title': 'Kiss Kiss Bang Bang'},
#  {'title': 'Wallace & Gromit in The Curse of the Were-Rabbit'},
#  {'title': 'In Her Shoes'},
#  {'title': 'Hail the Conquering Hero'},
#  {'title': 'Star Wreck: In the Pirkinning'},
#  {'title': 'Squid and the Whale, The'},
#  {'title': 'Elizabethtown'},
#  {'title': 'C.S.A.: The Confederate States of America'},
#  {'title': 'Kids in America'},
#  {'title': 'Shopgirl'},
#  {'title': 'Weather Man, The'},
#  {'title': 'After School Special (a.k.a. Barely Legal)'},
#  {'title': 'Life is a Miracle (Zivot je cudo)'},
#  {'title': 'American Pie Presents: Band Camp (American Pie 4: Band Camp)'},
#  {'title': 'Career Opportunities'},
#  {'title': 'My Super Ex-Girlfriend'},
#  {'title': 'Clerks II'},
#  {'title': 'You, Me and Dupree'},
#  {'title': 'Devil Wears Prada, The'},
#  {'title': 'Click'},
#  {'title': 'Nacho Libre'},
#  {'title': 'Wassup Rockers'},
#  {'title': 'Cars'},
#  {'title': 'Break-Up, The'},
#  ...]

# %%
# 5. Query Example
query = "Find comedy movies produced in USA"
result = qa_chain.invoke({"query": query})
print("Answer:", result['result'])
# Out:
# Answer: Here are the comedy movies produced in the USA:
#
# 1. Airplane!
# 2. American Pie
# 3. American Pie 2
# 4. American Reunion (American Pie 4)
# 5. American Splendor
# 6. American Wedding (American Pie 3)
# 7. Analyze That
# 8. Another Stakeout
# 9. Are We There Yet?
# 10. Around the World in 80 Days
# 11. Associate, The
# 12. Author! Author!
# 13. Bad Company
# 14. Barbershop
# 15. Beavis and Butt-Head Do America
# 16. Beerfest
# 17. Benchwarmers, The
# 18. Bewitched
# 19. Big Hit, The
# 20. Big Lebowski, The
# 21. Big Picture, The
# 22. Black Dynamite
# 23. Blue Collar Comedy Tour: The Movie
# 24. Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan
# 25. Broadcast News
# 26. Bucket List, The
# 27. Bull Durham
# 28. Bunny and the Bull
# 29. Butch Cassidy and the Sundance Kid
# 30. Cage aux Folles, La
# 31. California Split
# 32. Campaign, The
# 33. Career Opportunities
# 34. Cars
# 35. Cast Away
# 36. Catch and Release
# 37. Cedar Rapids
# 38. Celebrity
# 39. Chances Are
# 40. Chicago
# 41. Cops and Robbersons
# 42. Crash
# 43. Crocodile Dundee in Los Angeles
# 44. Date Movie
# 45. Deadpool
# 46. Deadpool was produced in Canada
# 47. Death at a Funeral
# 48. Death at a Funeral
# 49. Dazed and Confused
# 50. Dead Poets Society
# 51. Deadpool
# 52. Deadpool was produced in Canada
# 176. Paris, France
# 177. People, Places, Things
# 178. Philadelphia Story, The
# 179. Planes
# 180. Planes: Fire & Rescue
# 181. Play Misty for Me
# 182. Please Give
# 183. Poetic Justice
# 184. Pulp Fiction
# 185. Punch-Drunk Love
# 186. Punchline
# 187. Raising Arizona
# 188. Re-Animator
# 189. Reno 911!: Miami
# 190. Return of the Killer Tomatoes!
# 191. Rio
# 192. Road to Singapore
# 193. Role Models
# 194. Role/Play
# 195. Sabrina
# 196. Sahara
# 197. Scary Movie
# 198. Scary Movie 2
# 199. Scary Movie 3
# 200. Scary Movie 4
# 201. Scream
# 202. Screamers
# 203. Search Party
# 204. Seeking a Friend for the End of the World
# 205. Sex and the City
# 206. Shakes the Clown
# 207. Shanghai Noon
# 208. Sidewalks of New York
# 209. Sightseers
# 210. Singles
# 211. Sleuth
# 212. Slums of Beverly Hills
# 213. Some Like It Hot
# 214. Specials, The
# 215. Stardom
# 216. State and Main
# 217. Steal This Movie!
# 218. Story of Us, The
# 219. Storytelling
# 220. Straight Outta Compton
# 221. SubUrbia
# 222. Summer Rental
# 223. Superbad
# 224. Superhero Movie
# 225. Swingers
# 226. Synecdoche, New York
# 227. Tales from the Darkside: The Movie
# 228. Team America: World Police
# 229. The Artist
# 230. The Big Lebowski
# 231. The Bucket List
# 232. The Campaign
# 233. The Clowns
# 234. The Internship
# 235. The Lego Movie
# 236. The Man from U.N.C.L.E.
# 237. The Voices
# 238. There's Something About Mary
# 239. Three Fugitives
# 240. To Do List, The
# 241. Toy Story
# 242. Trading Places
# 243. Trip to Italy, The
# 244. True Stories
# 245. Twilight
# 246. Two Days in New York
# 247. Two of a Kind
# 248. Unaccompanied Minors
# 249. Used Cars
# 250. Vacation
# 251. V for Vendetta
# 252. View from the Top
# 253. Volunteers
# 254. War, Inc.
# 255. Wayne's World
# 256. Weirdsville
# 257. What Just Happened
# 258. What Planet Are You From?
# 259. What Women Want
# 260. What's Up, Doc?
# 261. When Harry Met Sally
# 262. Where the Boys Are
# 263. While You Were Sleeping
# 264. Wild America
# 265. Wild Tales
# 266. Will Ferrell: You're Welcome America - A Final Night with George W Bush
# 267. Woman on Top
# 268. Women, The
# 269. World According to Garp, The
# 270. World's End, The

# %% [markdown]
# # VALIDATION AND ACCURACY OF MODEL

# %% [markdown]
# #### Sample 5 queries

# %%
sample_queries = [
    "List adventure movies released after 2000",
    "Find movies acted by Leonardo DiCaprio released after 2000"
    ]

# %% [markdown]
# #### RAG Predictions (LLM output)

# %%
rag_results = {}

for query in sample_queries:
    print(f"\nQuery: {query}")
    result = qa_chain.invoke({"query": query})
    print("RAG Answer:", result['result'])
    rag_results[query] = result['result']
# Out:
# Query: List adventure movies released after 2000
# RAG Answer: Here is the list of adventure movies released after 2000:
#
# 1. Jurassic Park III (2001)
# 2. The Lord of the Rings: The Two Towers (2002)
# 3. The Lord of the Rings: The Return of the King (2003)
# 4. Pirates of the Caribbean: The Curse of the Black Pearl (2003)
# 5. Shrek 2 (2004)
# 6. The Incredibles (2004)
# 7. Batman Begins (2005)
# 8. Superman Returns (2006)
# 9. Pirates of the Caribbean: Dead Man's Chest (2006)
# 10. Casino Royale (2006)
# 11. The Bourne Ultimatum (2007)
# 12. National Treasure: Book of Secrets (2007)
# 13. Indiana Jones and the Kingdom of the Crystal Skull (2008)
# 14. The Dark Knight (2008)
# 15. Kung Fu Panda (2008)
# 16. Madagascar: Escape 2 Africa (2008)
# 17. Avatar (2009)
# 18. The A-Team (2010)
# 19. The Last Airbender (2010)
# 20. Pirates of the Caribbean: On Stranger Tides (2011)
# 21. The Adventures of Tintin (2011)
# 22. The Avengers (2012)
# 23. The Dark Knight Rises (2012)
# 24. The Hobbit: An Unexpected Journey (2012)
# 25. Iron Man 3 (2013)
# 26. The Hunger Games: Catching Fire (2013)
# 27. The Hobbit: The Desolation of Smaug (2013)
# 28. Guardians of the Galaxy (2014)
# 29. The Hunger Games: Mockingjay - Part 1 (2014)
# 30. Avengers: Age of Ultron (2015)
# 31. Jurassic World (2015)
# 32. The Hunger Games: Mockingjay - Part 2 (2015)
# 33. The Jungle Book (2016)
# 34. Captain America: Civil War (2016)
# 35. The Legend of Tarzan (2016)
# 36. Doctor Strange (2016)
# 37. Guardians of the Galaxy Vol. 2 (2017)
# 38. Spider-Man: Homecoming (2017)
# 39. Thor: Ragnarok (2017)
# 40. Black Panther (2018)
# 41. Avengers: Infinity War (2018)
# 42. Ant-Man and the Wasp (2018)
# 43. Captain Marvel (2019)
# 44. Avengers: Endgame (2019)
# 45. Spider-Man: Far From Home (2019)
#
# Note: This is not an exhaustive list, but it includes many popular adventure movies released after 2000.
#
# Query: Find movies acted by Leonardo DiCaprio released after 2000
# RAG Answer: Based on the provided facts, here are the movies acted by Leonardo DiCaprio released after 2000:
#
# 1. Gangs of New York (2002)
# 2. Catch Me If You Can (2002)
# 3. The Aviator (2004)
# 4. Blood Diamond (2006)
# 5. The Departed (2006)
# 6. Shutter Island (2010)
# 7. Inception (2010)
# 8. J. Edgar (2011)
# 9. Django Unchained (2012)
# 10. The Wolf of Wall Street (2013)
# 11. The Revenant (2015)
#
# Note: The list only includes movies released after 2000, as per the question.

# %% [markdown]
# #### Manual KG Queries

# %%
kg_queries = {
    "List adventure movies released after 2000": """
        MATCH (m:Movie)-[:IN_GENRE]->(g:Genre)
        WHERE g.name = "Adventure" AND m.year > 2000
        RETURN m.title AS title
    """,
    "Find movies acted by Leonardo DiCaprio released after 2000": """
        MATCH (p:Person)-[:ACTED_IN]->(m:Movie)
        WHERE p.name = "Leonardo DiCaprio" AND m.year > 2000
        RETURN m.title AS title, m.year AS year
        ORDER BY m.year ASC
    """
}



ground_truth_results = {}

for query, cypher in kg_queries.items():
    output = kg.query(cypher)
    titles = [item['title'] for item in output]
    ground_truth_results[query] = titles

# %% [markdown]
# #### Normalize function

# %%
import re

def normalize_titles(title_list):
    normalized = []
    for title in title_list:
        title = title.lower()
        title = re.sub(r'[^a-z0-9 ]', '', title)  # Remove punctuations
        title = title.strip()
        normalized.append(title)
    return normalized

# %% [markdown]
# #### Extraction helper (parse LLM text)

# %%
def extract_titles_from_rag_output(text):
    lines = text.split('\n')
    titles = []
    for line in lines:
        match = re.search(r"\d+\.\s*(.+?)\s*(\(|$)", line.strip())
        if match:
            titles.append(match.group(1))
    return titles

# %% [markdown]
# #### Evaluation Metrics

# %%
# Update your metric function first
def compute_precision_recall_f1(predictions, ground_truth, k=10):
    pred_set = set(predictions[:k])
    gt_set = set(ground_truth)

    intersection = pred_set.intersection(gt_set)
    
    precision = len(intersection) / k if k > 0 else 0
    recall = len(intersection) / len(gt_set) if len(gt_set) > 0 else 0

    if precision + recall == 0:
        f1 = 0
    else:
        f1 = 2 * (precision * recall) / (precision + recall)

    return precision, recall, f1

# %%
for query in sample_queries:
    print(f"\nEvaluating Query: {query}")

    rag_titles = extract_titles_from_rag_output(rag_results[query])
    rag_titles_norm = normalize_titles(rag_titles)

    # Check if ground truth available
    if query not in ground_truth_results:
        print("Ground truth not available for this query. Skipping...")
        continue

    ground_truth_titles_norm = normalize_titles(ground_truth_results[query])

    precision, recall, f1 = compute_precision_recall_f1(
        rag_titles_norm, ground_truth_titles_norm, k=10
    )

    print(f"Precision@10: {precision:.2f}")
    print(f"Recall@10: {recall:.2f}")
    print(f"F1-score@10: {f1:.2f}")
# Out:
# Evaluating Query: List adventure movies released after 2000
# Precision@10: 0.60
# Recall@10: 0.01
# F1-score@10: 0.02
#
# Evaluating Query: Find movies acted by Leonardo DiCaprio released after 2000
# Precision@10: 0.70
# Recall@10: 0.50
# F1-score@10: 0.58

# %%
# Initialize accumulators
total_precision = 0
total_recall = 0
total_f1 = 0
count = 0  # Number of queries evaluated

for query in sample_queries:
    print(f"\nEvaluating Query: {query}")

    rag_titles = extract_titles_from_rag_output(rag_results[query])
    rag_titles_norm = normalize_titles(rag_titles)

    if query not in ground_truth_results:
        print("Ground truth not available for this query. Skipping...")
        continue

    ground_truth_titles_norm = normalize_titles(ground_truth_results[query])

    precision, recall, f1 = compute_precision_recall_f1(
        rag_titles_norm, ground_truth_titles_norm, k=10
    )

    print(f"Precision@10: {precision:.2f}")
    print(f"Recall@10: {recall:.2f}")
    print(f"F1-score@10: {f1:.2f}")

    total_precision += precision
    total_recall += recall
    total_f1 += f1
    count += 1

# Compute overall averages
if count > 0:
    avg_precision = total_precision / count
    avg_recall = total_recall / count
    avg_f1 = total_f1 / count

    print("\n===========================")
    print(f"Overall RAG System Performance ")
    print(f"Average Precision@10: {avg_precision:.2f}")
    print(f"Average Recall@10: {avg_recall:.2f}")
    print(f"Average F1-score@10: {avg_f1:.2f}")
    print("===========================")
else:
    print("\nNo queries evaluated!")
# Out:
# Evaluating Query: List adventure movies released after 2000
# Precision@10: 0.60
# Recall@10: 0.01
# F1-score@10: 0.02
#
# Evaluating Query: Find movies acted by Leonardo DiCaprio released after 2000
# Precision@10: 0.70
# Recall@10: 0.50
# F1-score@10: 0.58
#
# ===========================
# Overall RAG System Performance
# Average Precision@10: 0.65
# Average Recall@10: 0.26
# Average F1-score@10: 0.30
# ===========================
